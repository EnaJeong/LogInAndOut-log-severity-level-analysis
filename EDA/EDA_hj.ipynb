# %%
import pandas as pd
import re
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
train_df = pd.read_csv('./data/train.csv', index_col=0)
train_df
# Out:
#         level                                           full_log
# id
# 0           0  Sep 24 10:02:22 localhost kibana: {"type":"err...
# 1           0  Feb  8 16:21:00 localhost logstash: [2021-02-0...
# 2           0  Jan 13 01:50:40 localhost kibana: {"type":"err...
# 3           0  Jan  4 10:18:31 localhost kibana: {"type":"err...
# 4           1  type=SYSCALL msg=audit(1603094402.016:52981): ...
# ...       ...                                                ...
# 472967      0  Feb 28 10:10:06 localhost logstash: 7738   error:
# 472968      1  type=SYSCALL msg=audit(1611890993.458:321827):...
# 472969      0  Oct 12 02:20:29 localhost kibana: {"type":"log...
# 472970      0  Jan 15 09:02:43 localhost kibana: {"type":"err...
# 472971      0  Oct 12 04:27:47 localhost kibana: {"type":"err...
#
# [472972 rows x 2 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 472972 entries, 0 to 472971
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   level     472972 non-null  int64
#  1   full_log  472972 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 10.8+ MB

# %%
train_df['level'].value_counts()
# Out:
# 0    334065
# 1    132517
# 3      4141
# 5      2219
# 2        12
# 4        10
# 6         8
# Name: level, dtype: int64

# %% [markdown]
# ## 첫번째 단어

# %%
train_df['full_log'].str.extract('^([^ ]+)(?: |$)')
# Out:
#                    0
# id
# 0                Sep
# 1                Feb
# 2                Jan
# 3                Jan
# 4       type=SYSCALL
# ...              ...
# 472967           Feb
# 472968  type=SYSCALL
# 472969           Oct
# 472970           Jan
# 472971           Oct
#
# [472972 rows x 1 columns]

# %%
train_df.head()
# Out:
#     level                                           full_log
# id
# 0       0  Sep 24 10:02:22 localhost kibana: {"type":"err...
# 1       0  Feb  8 16:21:00 localhost logstash: [2021-02-0...
# 2       0  Jan 13 01:50:40 localhost kibana: {"type":"err...
# 3       0  Jan  4 10:18:31 localhost kibana: {"type":"err...
# 4       1  type=SYSCALL msg=audit(1603094402.016:52981): ...

# %%
train_df['first_word'] = train_df['full_log'].str.extract('^([^ ]+)(?: |$)')

# %%
train_df['first_word'].nunique()
# Out:
# 26

# %%
train_df['first_word'].value_counts()
# Out:
# Jan              207025
# type=SYSCALL     116496
# Feb               35544
# Dec               25882
# Oct               23883
# Sep               23193
# Nov               21875
# Mar               12174
# level              2331
# ossec:             1318
# File                822
# System              820
# error:              459
# type=AVC            369
# oscap:              366
# E:                  297
# NTFS                 25
# 2021                 22
# Trojaned             15
# Windows              13
# --MARK--:            12
# The                  11
# 2020                  9
# juniper               5
# type=USER_AVC         3
# OpenSCAP              3
# Name: first_word, dtype: int64

# %%
train_df['first_word'].value_counts().index
# Out:
# Index(['Jan', 'type=SYSCALL', 'Feb', 'Dec', 'Oct', 'Sep', 'Nov', 'Mar',
#        'level', 'ossec:', 'File', 'System', 'error:', 'type=AVC', 'oscap:',
#        'E:', 'NTFS', '2021', 'Trojaned', 'Windows', '--MARK--:', 'The', '2020',
#        'juniper', 'type=USER_AVC', 'OpenSCAP'],
#       dtype='object')

# %%
pivot = train_df.pivot_table(values='full_log', index='first_word', columns='level', aggfunc='count', fill_value=0)
pivot = pivot.loc[train_df['first_word'].value_counts().index]
pivot
# Out:
# level               0       1   2     3  4     5  6
# Jan            200574    3019   0  3414  1    14  3
# type=SYSCALL        0  116496   0     0  0     0  0
# Feb             33114    2381   0    44  0     1  4
# Dec             24370    1498   0    14  0     0  0
# Oct             20973    2904   0     6  0     0  0
# Sep             22392     799   1     1  0     0  0
# Nov             18980    2646   0   239  9     1  0
# Mar             11368     804   0     1  0     0  1
# level            1519     736   0    11  0    65  0
# ossec:              0      29   0     0  0  1289  0
# File                0       0   0   181  0   641  0
# System              0     820   0     0  0     0  0
# error:            459       0   0     0  0     0  0
# type=AVC            0     369   0     0  0     0  0
# oscap:              0       0   0   198  0   168  0
# E:                297       0   0     0  0     0  0
# NTFS                0       0   0     0  0    25  0
# 2021                0       0   0    22  0     0  0
# Trojaned            0       0   0     0  0    15  0
# Windows             0      13   0     0  0     0  0
# --MARK--:          12       0   0     0  0     0  0
# The                 0       0  11     0  0     0  0
# 2020                0       0   0     9  0     0  0
# juniper             4       0   0     1  0     0  0
# type=USER_AVC       0       3   0     0  0     0  0
# OpenSCAP            3       0   0     0  0     0  0

# %% [markdown]
# ## 첫번째 단어 기준 그룹 생성

# %%
groups = train_df.groupby('first_word')

# %%
def show_all(first_word):
    for log in groups.get_group(first_word)['full_log']:
        print(log, '\n')

# %% [markdown]
# ## level

# %%
level = train_df[train_df['first_word'] == 'level'].copy()
level
# Out:
#         level                                           full_log first_word
# id
# 562         0  level : 5, log : No mode specified for interfa...      level
# 838         0  level : 5, log : PIC pic-slot in FPC fpc-slot ...      level
# 1076        5      level : 10, log : fru-name#fru-slot - command      level
# 1390        0  level : 5, log : Error getting class usage sta...      level
# 1569        0  level : 5, log : Fabric fc-fabric-name interfa...      level
# ...       ...                                                ...        ...
# 471241      0  level : 3, log : routing socket open error arg...      level
# 471457      0  level : 10, log : Symmetric key generation fai...      level
# 471722      1         level : 3, log : Invalid XML data '\\data'      level
# 471998      0           level : 3, log : pathname: error-message      level
# 472338      1  level : 5, log : function-name: fru-name opera...      level
#
# [2331 rows x 3 columns]

# %%
level['log_level'] = level['full_log'].str.extract('level : (\S+),')
level
# Out:
#         level                                           full_log first_word  \
# id
# 562         0  level : 5, log : No mode specified for interfa...      level
# 838         0  level : 5, log : PIC pic-slot in FPC fpc-slot ...      level
# 1076        5      level : 10, log : fru-name#fru-slot - command      level
# 1390        0  level : 5, log : Error getting class usage sta...      level
# 1569        0  level : 5, log : Fabric fc-fabric-name interfa...      level
# ...       ...                                                ...        ...
# 471241      0  level : 3, log : routing socket open error arg...      level
# 471457      0  level : 10, log : Symmetric key generation fai...      level
# 471722      1         level : 3, log : Invalid XML data '\\data'      level
# 471998      0           level : 3, log : pathname: error-message      level
# 472338      1  level : 5, log : function-name: fru-name opera...      level
#
#        log_level
# id
# 562            5
# 838            5
# 1076          10
# 1390           5
# 1569           5
# ...          ...
# 471241         3
# 471457        10
# 471722         3
# 471998         3
# 472338         5
#
# [2331 rows x 4 columns]

# %%
level['log_level'].isnull().sum()
# Out:
# 0

# %%
pivot_level = level.pivot_table(values='full_log', index='log_level', columns='level', aggfunc='count', fill_value=0)
pivot_level
# Out:
# level            0    1  3   5
# log_level
# %{rule.level}   10    8  0   0
# 10              27   13  0   3
# 2               18    6  0   2
# 3              593  282  7  18
# 4                2    2  0   0
# 5              859  422  4  41
# 7               10    2  0   0
# 8                0    1  0   1

# %% [markdown]
# -> 더 확인

# %% [markdown]
# ## 날짜로 시작하는 로그

# %% [markdown]
# 날짜로 시작하는 로그
# - Jan
# - Feb
# - Dec
# - Oct
# - Sep
# - Nov
# - Mar

# %%
MONTH = {'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'}

# %%
log_time = train_df[train_df['first_word'].isin(MONTH)].copy()
log_time
# Out:
#         level                                           full_log first_word
# id
# 0           0  Sep 24 10:02:22 localhost kibana: {"type":"err...        Sep
# 1           0  Feb  8 16:21:00 localhost logstash: [2021-02-0...        Feb
# 2           0  Jan 13 01:50:40 localhost kibana: {"type":"err...        Jan
# 3           0  Jan  4 10:18:31 localhost kibana: {"type":"err...        Jan
# 6           0  Jan 22 06:28:59 localhost kibana: {"type":"err...        Jan
# ...       ...                                                ...        ...
# 472966      0  Mar  5 20:33:06 localhost logstash: 14312     ...        Mar
# 472967      0  Feb 28 10:10:06 localhost logstash: 7738   error:        Feb
# 472969      0  Oct 12 02:20:29 localhost kibana: {"type":"log...        Oct
# 472970      0  Jan 15 09:02:43 localhost kibana: {"type":"err...        Jan
# 472971      0  Oct 12 04:27:47 localhost kibana: {"type":"err...        Oct
#
# [349576 rows x 3 columns]

# %%
log_time[log_time['full_log'].map(lambda a: not 'localhost' in a)]
# Out:
#         level                                           full_log first_word
# id
# 2806        0  Nov 19 08:55:07 m2datateksolaris SC Alert: [ID...        Nov
# 4841        3  Nov 17 14:29:00 sv260 sshd[6563]: Failed none ...        Nov
# 12837       3  Nov 18 14:02:45 sv260 sshd[8621]: Disconnectin...        Nov
# 12867       3  Nov 17 14:25:07 sv260 sshd[6481]: Disconnectin...        Nov
# 13723       3  Nov 17 17:34:26 sv260 sshd[8537]: Failed passw...        Nov
# ...       ...                                                ...        ...
# 465161      0  Nov 19 09:55:06 m2datateksolaris SC Alert: [ID...        Nov
# 468207      3  Nov 17 14:25:36 sv260 sshd[6506]: Disconnectin...        Nov
# 468491      3  Nov 17 17:31:10 sv260 sshd[8480]: Disconnectin...        Nov
# 469314      3  Nov 17 17:30:17 sv260 sshd[8467]: Failed passw...        Nov
# 472857      3  Nov 17 17:39:08 sv260 sshd[8709]: Failed passw...        Nov
#
# [242 rows x 3 columns]

# %%
log_time_etc = log_time[log_time['full_log'].map(lambda a: not 'localhost' in a)].copy()

# %% [markdown]
# ### localhost

# %%
log_time['localhost'] = log_time['full_log'].str.extract('.+localhost (\S+): ')
log_time
# Out:
#         level                                           full_log first_word  \
# id
# 0           0  Sep 24 10:02:22 localhost kibana: {"type":"err...        Sep
# 1           0  Feb  8 16:21:00 localhost logstash: [2021-02-0...        Feb
# 2           0  Jan 13 01:50:40 localhost kibana: {"type":"err...        Jan
# 3           0  Jan  4 10:18:31 localhost kibana: {"type":"err...        Jan
# 6           0  Jan 22 06:28:59 localhost kibana: {"type":"err...        Jan
# ...       ...                                                ...        ...
# 472966      0  Mar  5 20:33:06 localhost logstash: 14312     ...        Mar
# 472967      0  Feb 28 10:10:06 localhost logstash: 7738   error:        Feb
# 472969      0  Oct 12 02:20:29 localhost kibana: {"type":"log...        Oct
# 472970      0  Jan 15 09:02:43 localhost kibana: {"type":"err...        Jan
# 472971      0  Oct 12 04:27:47 localhost kibana: {"type":"err...        Oct
#
#        localhost
# id
# 0         kibana
# 1       logstash
# 2         kibana
# 3         kibana
# 6         kibana
# ...          ...
# 472966  logstash
# 472967  logstash
# 472969    kibana
# 472970    kibana
# 472971    kibana
#
# [349576 rows x 4 columns]

# %%
log_time['localhost'].nunique()
# Out:
# 1255

# %%
log_time['localhost'].value_counts()
# Out:
# kibana                170237
# logstash              138415
# sudo                   13813
# suricata[1447]          5553
# suricata[1454]          5076
#                        ...
# sshd[27922]                1
# unix_chkpwd[26274]         1
# sshd[6824]                 1
# sshd[26255]                1
# sshd[26919]                1
# Name: localhost, Length: 1255, dtype: int64

# %%
log_time['localhost'].value_counts()[:30]
# Out:
# kibana               170237
# logstash             138415
# sudo                  13813
# suricata[1447]         5553
# suricata[1454]         5076
# esild-ml-start.sh      4383
# suricata[1444]         4125
# systemd                2210
# suricata[1457]         1537
# suricata[1437]          595
# auditd[808]             497
# suricata[1442]          480
# suricata[1434]          398
# kernel                  173
# suricata[1445]          134
# journal                  92
# suricata[1450]           18
# suricata                 14
# yum[26878]               11
# auditd[840]               9
# augenrules                8
# elasticsearch             7
# suricata[1441]            5
# suricata[1456]            5
# auditd[832]               4
# sshd[735]                 4
# sshd[19037]               4
# sshd[13005]               3
# sshd[27462]               3
# sshd[27404]               3
# Name: localhost, dtype: int64

# %% [markdown]
# ### 포트 무시

# %%
log_time['localhost_2'] = log_time['full_log'].str.extract('localhost ([^ \[]+)(?::|\[)')
log_time
# Out:
#         level                                           full_log first_word  \
# id
# 0           0  Sep 24 10:02:22 localhost kibana: {"type":"err...        Sep
# 1           0  Feb  8 16:21:00 localhost logstash: [2021-02-0...        Feb
# 2           0  Jan 13 01:50:40 localhost kibana: {"type":"err...        Jan
# 3           0  Jan  4 10:18:31 localhost kibana: {"type":"err...        Jan
# 6           0  Jan 22 06:28:59 localhost kibana: {"type":"err...        Jan
# ...       ...                                                ...        ...
# 472966      0  Mar  5 20:33:06 localhost logstash: 14312     ...        Mar
# 472967      0  Feb 28 10:10:06 localhost logstash: 7738   error:        Feb
# 472969      0  Oct 12 02:20:29 localhost kibana: {"type":"log...        Oct
# 472970      0  Jan 15 09:02:43 localhost kibana: {"type":"err...        Jan
# 472971      0  Oct 12 04:27:47 localhost kibana: {"type":"err...        Oct
#
#        localhost localhost_2
# id
# 0         kibana      kibana
# 1       logstash    logstash
# 2         kibana      kibana
# 3         kibana      kibana
# 6         kibana      kibana
# ...          ...         ...
# 472966  logstash    logstash
# 472967  logstash    logstash
# 472969    kibana      kibana
# 472970    kibana      kibana
# 472971    kibana      kibana
#
# [349576 rows x 5 columns]

# %%
log_time['localhost_2'].nunique()
# Out:
# 26

# %%
log_time['localhost_2'].value_counts()
# Out:
# kibana               170219
# logstash             138436
# suricata              17949
# sudo                  13813
# esild-ml-start.sh      4383
# systemd                2210
# sshd                   1376
# auditd                  510
# kernel                  173
# unix_chkpwd             122
# journal                  92
# yum                      16
# augenrules                8
# elasticsearch             7
# postfix/master            3
# su                        3
# rc.local                  2
# bluetoothd                2
# mcelog                    2
# polkitd                   2
# pulseaudio                1
# useradd                   1
# dbus-daemon               1
# gnome-session             1
# dbus                      1
# kdumpctl                  1
# Name: localhost_2, dtype: int64

# %%
log_time.pivot_table(values='full_log', index='localhost_2', columns=['level'], aggfunc='count', fill_value=0)
# Out:
# level                   0      1  2     3  4   5  6
# localhost_2
# auditd                510      0  0     0  0   0  0
# augenrules              8      0  0     0  0   0  0
# bluetoothd              2      0  0     0  0   0  0
# dbus                    1      0  0     0  0   0  0
# dbus-daemon             1      0  0     0  0   0  0
# elasticsearch           7      0  0     0  0   0  0
# esild-ml-start.sh    4383      0  0     0  0   0  0
# gnome-session           1      0  0     0  0   0  0
# journal                92      0  0     0  0   0  0
# kdumpctl                1      0  0     0  0   0  0
# kernel                146     22  0     0  0   0  5
# kibana             170219      0  0     0  0   0  0
# logstash           138436      0  0     0  0   0  0
# mcelog                  2      0  0     0  0   0  0
# polkitd                 2      0  0     0  0   0  0
# postfix/master          0      3  0     0  0   0  0
# pulseaudio              1      0  0     0  0   0  0
# rc.local                2      0  0     0  0   0  0
# sshd                    3    210  0  1156  5   0  2
# su                      0      2  0     1  0   0  0
# sudo                    0  13812  1     0  0   0  0
# suricata            17948      0  0     1  0   0  0
# systemd                 0      0  0  2210  0   0  0
# unix_chkpwd             0      0  0   122  0   0  0
# useradd                 0      0  0     0  0   0  1
# yum                     0      0  0     0  0  16  0

# %% [markdown]
# -> 조금 더 확인 필요

# %% [markdown]
# ### localhost가 아닌 경우

# %%
log_time_etc['second'] = log_time_etc['full_log'].str.extract('\d{2}:\d{2}:\d{2} (\S+) ')
log_time_etc
# Out:
#         level                                           full_log first_word  \
# id
# 2806        0  Nov 19 08:55:07 m2datateksolaris SC Alert: [ID...        Nov
# 4841        3  Nov 17 14:29:00 sv260 sshd[6563]: Failed none ...        Nov
# 12837       3  Nov 18 14:02:45 sv260 sshd[8621]: Disconnectin...        Nov
# 12867       3  Nov 17 14:25:07 sv260 sshd[6481]: Disconnectin...        Nov
# 13723       3  Nov 17 17:34:26 sv260 sshd[8537]: Failed passw...        Nov
# ...       ...                                                ...        ...
# 465161      0  Nov 19 09:55:06 m2datateksolaris SC Alert: [ID...        Nov
# 468207      3  Nov 17 14:25:36 sv260 sshd[6506]: Disconnectin...        Nov
# 468491      3  Nov 17 17:31:10 sv260 sshd[8480]: Disconnectin...        Nov
# 469314      3  Nov 17 17:30:17 sv260 sshd[8467]: Failed passw...        Nov
# 472857      3  Nov 17 17:39:08 sv260 sshd[8709]: Failed passw...        Nov
#
#                   second
# id
# 2806    m2datateksolaris
# 4841               sv260
# 12837              sv260
# 12867              sv260
# 13723              sv260
# ...                  ...
# 465161  m2datateksolaris
# 468207             sv260
# 468491             sv260
# 469314             sv260
# 472857             sv260
#
# [242 rows x 4 columns]

# %%
log_time_etc['second'].nunique()
# Out:
# 2

# %%
log_time_etc['second'].value_counts()
# Out:
# sv260               238
# m2datateksolaris      4
# Name: second, dtype: int64

# %% [markdown]
# ### m2datateksolaris

# %%
log_time_etc[log_time_etc['second']=='m2datateksolaris']
# Out:
#         level                                           full_log first_word  \
# id
# 2806        0  Nov 19 08:55:07 m2datateksolaris SC Alert: [ID...        Nov
# 157873      0  Nov 19 08:55:06 m2datateksolaris SC Alert: [ID...        Nov
# 441122      0  Nov 19 08:55:09 m2datateksolaris SC Alert: [ID...        Nov
# 465161      0  Nov 19 09:55:06 m2datateksolaris SC Alert: [ID...        Nov
#
#                   second
# id
# 2806    m2datateksolaris
# 157873  m2datateksolaris
# 441122  m2datateksolaris
# 465161  m2datateksolaris

# %%
for log in log_time_etc[log_time_etc['second']=='m2datateksolaris']['full_log']:
    print(log, '\n')
# Out:
# Nov 19 08:55:07 m2datateksolaris SC Alert: [ID 556868 daemon.error] SC unretrieved msg: [Chassis | major: Hot removal of HDD2]
#
# Nov 19 08:55:06 m2datateksolaris SC Alert: [ID 677427 daemon.error] SC unretrieved msg: [Chassis | major: Hot removal of HDD3]
#
# Nov 19 08:55:09 m2datateksolaris SC Alert: [ID 217180 daemon.error] SC unretrieved msg: [Chassis | major: Host is running]
#
# Nov 19 09:55:06 m2datateksolaris SC Alert: [ID 887218 daemon.error] Chassis | major: System shutdown has been requested via power button.

# %% [markdown]
# ### sv260

# %%
log_time_etc['sv260'] = log_time_etc['full_log'].str.extract('sv260 ([^ \[]+)(?::|\[)')
log_time_etc
# Out:
#         level                                           full_log first_word  \
# id
# 2806        0  Nov 19 08:55:07 m2datateksolaris SC Alert: [ID...        Nov
# 4841        3  Nov 17 14:29:00 sv260 sshd[6563]: Failed none ...        Nov
# 12837       3  Nov 18 14:02:45 sv260 sshd[8621]: Disconnectin...        Nov
# 12867       3  Nov 17 14:25:07 sv260 sshd[6481]: Disconnectin...        Nov
# 13723       3  Nov 17 17:34:26 sv260 sshd[8537]: Failed passw...        Nov
# ...       ...                                                ...        ...
# 465161      0  Nov 19 09:55:06 m2datateksolaris SC Alert: [ID...        Nov
# 468207      3  Nov 17 14:25:36 sv260 sshd[6506]: Disconnectin...        Nov
# 468491      3  Nov 17 17:31:10 sv260 sshd[8480]: Disconnectin...        Nov
# 469314      3  Nov 17 17:30:17 sv260 sshd[8467]: Failed passw...        Nov
# 472857      3  Nov 17 17:39:08 sv260 sshd[8709]: Failed passw...        Nov
#
#                   second sv260
# id
# 2806    m2datateksolaris   NaN
# 4841               sv260  sshd
# 12837              sv260  sshd
# 12867              sv260  sshd
# 13723              sv260  sshd
# ...                  ...   ...
# 465161  m2datateksolaris   NaN
# 468207             sv260  sshd
# 468491             sv260  sshd
# 469314             sv260  sshd
# 472857             sv260  sshd
#
# [242 rows x 5 columns]

# %%
log_time_etc['sv260'].value_counts()
# Out:
# sshd       237
# telnetd      1
# Name: sv260, dtype: int64

# %%
log_time_etc[log_time_etc['sv260']=='telnetd']
# Out:
#         level                                           full_log first_word  \
# id
# 188247      0  Nov 21 12:23:09 sv260 telnetd[20641]: getpid: ...        Nov
#
#        second    sv260
# id
# 188247  sv260  telnetd

# %%
log_sv260 = log_time_etc[log_time_etc['second']=='sv260'].copy()
log_sv260['level'].value_counts()
# Out:
# 3    229
# 4      5
# 0      2
# 1      2
# Name: level, dtype: int64

# %%
for level in (0, 1, 4):
    print(f'level = {level}', '\n')
    for log in log_sv260[log_sv260['level']==level]['full_log']:
        print(log, '\n')
# Out:
# level = 0
#
# Nov 21 12:23:09 sv260 telnetd[20641]: getpid: peer died: Error 0
#
# Nov 17 09:42:12 sv260 sshd[2684]: error: setsockopt SO_KEEPALIVE: Invalid argument
#
# level = 1
#
# Nov 18 13:08:45 sv260 sshd[6969]: Accepted password for root from 61.41.101.142 port 59553 ssh2
#
# Nov 16 11:26:48 sv260 sshd[19238]: Accepted password for root from 61.41.101.142 port 53017 ssh2
#
# level = 4
#
# Nov 29 22:16:32 sv260 sshd[39585]: Did not receive identification string from 211.253.243.66
#
# Nov 21 01:02:56 sv260 sshd[9196]: Did not receive identification string from 211.253.243.66
#
# Nov 27 08:32:12 sv260 sshd[3110]: Did not receive identification string from 192.168.0.195
#
# Nov 19 01:03:09 sv260 sshd[13841]: Did not receive identification string from 192.168.0.195
#
# Nov 8 20:25:42 sv260 sshd[37597]: Did not receive identification string from 192.168.0.181

# %%
log_sv260[log_sv260['level']==3]
# Out:
#         level                                           full_log first_word  \
# id
# 4841        3  Nov 17 14:29:00 sv260 sshd[6563]: Failed none ...        Nov
# 12837       3  Nov 18 14:02:45 sv260 sshd[8621]: Disconnectin...        Nov
# 12867       3  Nov 17 14:25:07 sv260 sshd[6481]: Disconnectin...        Nov
# 13723       3  Nov 17 17:34:26 sv260 sshd[8537]: Failed passw...        Nov
# 23420       3  Nov 17 17:39:20 sv260 sshd[8713]: Failed passw...        Nov
# ...       ...                                                ...        ...
# 463132      3  Nov 17 17:28:45 sv260 sshd[8440]: Failed passw...        Nov
# 468207      3  Nov 17 14:25:36 sv260 sshd[6506]: Disconnectin...        Nov
# 468491      3  Nov 17 17:31:10 sv260 sshd[8480]: Disconnectin...        Nov
# 469314      3  Nov 17 17:30:17 sv260 sshd[8467]: Failed passw...        Nov
# 472857      3  Nov 17 17:39:08 sv260 sshd[8709]: Failed passw...        Nov
#
#        second sv260
# id
# 4841    sv260  sshd
# 12837   sv260  sshd
# 12867   sv260  sshd
# 13723   sv260  sshd
# 23420   sv260  sshd
# ...       ...   ...
# 463132  sv260  sshd
# 468207  sv260  sshd
# 468491  sv260  sshd
# 469314  sv260  sshd
# 472857  sv260  sshd
#
# [229 rows x 5 columns]

# %%
log_sv260['log'] = log_sv260['full_log'].str.extract('\]: (.+)')
log_sv260
# Out:
#         level                                           full_log first_word  \
# id
# 4841        3  Nov 17 14:29:00 sv260 sshd[6563]: Failed none ...        Nov
# 12837       3  Nov 18 14:02:45 sv260 sshd[8621]: Disconnectin...        Nov
# 12867       3  Nov 17 14:25:07 sv260 sshd[6481]: Disconnectin...        Nov
# 13723       3  Nov 17 17:34:26 sv260 sshd[8537]: Failed passw...        Nov
# 23420       3  Nov 17 17:39:20 sv260 sshd[8713]: Failed passw...        Nov
# ...       ...                                                ...        ...
# 463132      3  Nov 17 17:28:45 sv260 sshd[8440]: Failed passw...        Nov
# 468207      3  Nov 17 14:25:36 sv260 sshd[6506]: Disconnectin...        Nov
# 468491      3  Nov 17 17:31:10 sv260 sshd[8480]: Disconnectin...        Nov
# 469314      3  Nov 17 17:30:17 sv260 sshd[8467]: Failed passw...        Nov
# 472857      3  Nov 17 17:39:08 sv260 sshd[8709]: Failed passw...        Nov
#
#        second sv260                                                log
# id
# 4841    sv260  sshd  Failed none for invalid user test from 61.41.1...
# 12837   sv260  sshd  Disconnecting: Too many authentication failure...
# 12867   sv260  sshd  Disconnecting: Too many authentication failure...
# 13723   sv260  sshd  Failed password for root from 61.41.101.142 po...
# 23420   sv260  sshd  Failed password for root from 61.41.101.142 po...
# ...       ...   ...                                                ...
# 463132  sv260  sshd  Failed password for root from 61.41.101.142 po...
# 468207  sv260  sshd  Disconnecting: Too many authentication failure...
# 468491  sv260  sshd  Disconnecting: Too many authentication failure...
# 469314  sv260  sshd  Failed password for root from 61.41.101.142 po...
# 472857  sv260  sshd  Failed password for root from 61.41.101.142 po...
#
# [238 rows x 6 columns]

# %%
log_sv260['log'].value_counts()
# Out:
# Disconnecting: Too many authentication failures for root [preauth]          64
# Invalid user test from 61.41.101.142                                        14
# Disconnecting: Too many authentication failures for test [preauth]          11
# Failed password for root from 61.41.101.142 port 41298 ssh2                  2
# Failed password for root from 61.41.101.142 port 60063 ssh2                  2
#                                                                             ..
# Failed password for invalid user test from 61.41.101.142 port 52388 ssh2     1
# Failed password for root from 61.41.101.142 port 59995 ssh2                  1
# Failed password for root from 61.41.101.142 port 41210 ssh2                  1
# Failed password for invalid user test from 61.41.101.142 port 52416 ssh2     1
# Failed password for root from 61.41.101.142 port 60096 ssh2                  1
# Name: log, Length: 135, dtype: int64

# %%
log_sv260['log'] = log_sv260['full_log'].str.extract('\]: (.+?)(?:port|$)')
log_sv260['log'].value_counts()
# Out:
# Failed password for root from 61.41.101.142                           104
# Disconnecting: Too many authentication failures for root [preauth]     64
# Failed password for invalid user test from 61.41.101.142               25
# Invalid user test from 61.41.101.142                                   14
# Disconnecting: Too many authentication failures for test [preauth]     11
# Failed none for invalid user test from 61.41.101.142                   11
# Did not receive identification string from 192.168.0.195                2
# Accepted password for root from 61.41.101.142                           2
# Did not receive identification string from 211.253.243.66               2
# Did not receive identification string from 192.168.0.181                1
# getpid: peer died: Error 0                                              1
# error: setsockopt SO_KEEPALIVE: Invalid argument                        1
# Name: log, dtype: int64

# %%
log_sv260.pivot_table(values='full_log', index='log', columns='level', aggfunc='count', fill_value=0)
# Out:
# level                                               0  1    3  4
# log
# Accepted password for root from 61.41.101.142       0  2    0  0
# Did not receive identification string from 192....  0  0    0  1
# Did not receive identification string from 192....  0  0    0  2
# Did not receive identification string from 211....  0  0    0  2
# Disconnecting: Too many authentication failures...  0  0   64  0
# Disconnecting: Too many authentication failures...  0  0   11  0
# Failed none for invalid user test from 61.41.10...  0  0   11  0
# Failed password for invalid user test from 61.4...  0  0   25  0
# Failed password for root from 61.41.101.142         0  0  104  0
# Invalid user test from 61.41.101.142                0  0   14  0
# error: setsockopt SO_KEEPALIVE: Invalid argument    1  0    0  0
# getpid: peer died: Error 0                          1  0    0  0

# %% [markdown]
# ## 연도

# %%
groups.get_group('2020')
# Out:
#         level                                           full_log first_word
# id
# 63675       3  2020 Oct 30 08:39:31 WinEvtLog: System: ERROR(...       2020
# 226155      3  2020 Oct 28 13:32:06 WinEvtLog: System: ERROR(...       2020
# 246839      3  2020 Oct 30 09:55:55 WinEvtLog: System: ERROR(...       2020
# 275279      3  2020 Oct 20 09:58:04 WinEvtLog: System: ERROR(...       2020
# 279151      3  2020 Oct 19 10:32:47 WinEvtLog: Application: E...       2020
# 332210      3  2020 Oct 21 17:59:46 WinEvtLog: System: ERROR(...       2020
# 361699      3  2020 Oct 23 08:22:32 WinEvtLog: System: ERROR(...       2020
# 393148      3  2020 Oct 22 09:59:04 WinEvtLog: System: ERROR(...       2020
# 454020      3  2020 Oct 23 08:23:30 WinEvtLog: System: ERROR(...       2020

# %%
groups.get_group('2021')
# Out:
#         level                                           full_log first_word
# id
# 7983        3  2021 Feb 04 17:33:57 WinEvtLog: Application: E...       2021
# 35553       3  2021 Feb 08 10:08:16 WinEvtLog: Application: E...       2021
# 56540       3  2021 Feb 24 16:21:07 WinEvtLog: Application: I...       2021
# 65234       3  2021 Feb 03 17:45:23 WinEvtLog: Application: E...       2021
# 126924      3  2021 Feb 04 15:03:53 WinEvtLog: Application: E...       2021
# 138261      3  2021 Feb 02 12:58:37 WinEvtLog: Application: I...       2021
# 143074      3  2021 Feb 03 15:15:16 WinEvtLog: Application: E...       2021
# 147305      3  2021 Feb 05 10:33:56 WinEvtLog: Application: E...       2021
# 196254      3  2021 Feb 04 13:03:52 WinEvtLog: Application: E...       2021
# 211913      3  2021 Feb 24 16:15:36 WinEvtLog: Application: I...       2021
# 221750      3  2021 Jan 25 09:07:56 WinEvtLog: Application: E...       2021
# 222002      3  2021 Feb 03 16:45:20 WinEvtLog: Application: E...       2021
# 223536      3  2021 Feb 03 17:49:46 WinEvtLog: System: ERROR(...       2021
# 224806      3  2021 Feb 02 11:15:51 WinEvtLog: System: ERROR(...       2021
# 269921      3  2021 Feb 19 18:15:50 WinEvtLog: Application: E...       2021
# 329562      3  2021 Feb 03 14:15:14 WinEvtLog: Application: E...       2021
# 357791      3  2021 Feb 04 10:33:55 WinEvtLog: Application: E...       2021
# 360467      3  2021 Jan 26 09:06:33 WinEvtLog: Application: E...       2021
# 393848      3  2021 Jan 22 16:11:45 WinEvtLog: System: ERROR(...       2021
# 435176      3  2021 Feb 03 17:15:17 WinEvtLog: Application: E...       2021
# 439393      3  2021 Feb 04 10:04:09 WinEvtLog: Application: E...       2021
# 452846      3  2021 Feb 05 11:04:24 WinEvtLog: Application: E...       2021

# %%
show_all('2020')
# Out:
# 2020 Oct 30 08:39:31 WinEvtLog: System: ERROR(10010): DCOM: Laptop: DESKTOP-UDJIJER: DESKTOP-UDJIJER: Microsoft.SkypeApp_15.65.78.0_x86__kzf8qxf38zg5c!App.AppXtwmqn4em5r5dpafgj4t4yyxgjfe0hr50.mca
#
# 2020 Oct 28 13:32:06 WinEvtLog: System: ERROR(10010): DCOM: Laptop: DESKTOP-UDJIJER: DESKTOP-UDJIJER: Microsoft.SkypeApp_15.65.78.0_x86__kzf8qxf38zg5c!App.AppXtwmqn4em5r5dpafgj4t4yyxgjfe0hr50.mca
#
# 2020 Oct 30 09:55:55 WinEvtLog: System: ERROR(10010): DCOM: Laptop: DESKTOP-UDJIJER: DESKTOP-UDJIJER: Microsoft.SkypeApp_15.65.78.0_x86__kzf8qxf38zg5c!App.AppXtwmqn4em5r5dpafgj4t4yyxgjfe0hr50.mca
#
# 2020 Oct 20 09:58:04 WinEvtLog: System: ERROR(10010): DCOM: Laptop: DESKTOP-UDJIJER: DESKTOP-UDJIJER: Microsoft.SkypeApp_15.64.80.0_x86__kzf8qxf38zg5c!App.AppXtwmqn4em5r5dpafgj4t4yyxgjfe0hr50.mca
#
# 2020 Oct 19 10:32:47 WinEvtLog: Application: ERROR(256): DPTF: (no user): no domain: DESKTOP-M1KNS65: Intel(R) Dynamic Platform and Thermal Framework : ESIF(8.3.10207.5567) TYPE: ERROR MODULE: DPTF TIME 795303 ms  DPTF Build Version:  8.3.10207.5567 DPTF Build Date:  Nov  2 2017 14:28:00 Source File:  ..\..\..\..\Sources\Policies\ConfigTdpPolicy\ConfigTdpPolicy.cpp @ line 342 Executing Function:  ConfigTdpPolicy::synchronizeConfigTdpPlatformSettings Message:  ConfigTdp not supported. Policy:  ConfigTDP Policy [0]
#
# 2020 Oct 21 17:59:46 WinEvtLog: System: ERROR(10010): DCOM: SYSTEM: NT AUTHORITY: DESKTOP-M1KNS65: {B91D5831-B1BD-4608-8198-D72E155020F7}
#
# 2020 Oct 23 08:22:32 WinEvtLog: System: ERROR(10010): DCOM: Laptop: DESKTOP-UDJIJER: DESKTOP-UDJIJER: Microsoft.SkypeApp_15.65.78.0_x86__kzf8qxf38zg5c!App.AppXtwmqn4em5r5dpafgj4t4yyxgjfe0hr50.mca
#
# 2020 Oct 22 09:59:04 WinEvtLog: System: ERROR(10010): DCOM: Laptop: DESKTOP-UDJIJER: DESKTOP-UDJIJER: Microsoft.SkypeApp_15.64.80.0_x86__kzf8qxf38zg5c!App.AppXtwmqn4em5r5dpafgj4t4yyxgjfe0hr50.mca
#
# 2020 Oct 23 08:23:30 WinEvtLog: System: ERROR(10010): DCOM: Laptop: DESKTOP-UDJIJER: DESKTOP-UDJIJER: Microsoft.SkypeApp_15.65.78.0_x86__kzf8qxf38zg5c!App.AppXtwmqn4em5r5dpafgj4t4yyxgjfe0hr50.mca

# %%
show_all('2021')
# Out:
# 2021 Feb 04 17:33:57 WinEvtLog: Application: ERROR(1024): MsiInstaller: SYSTEM: NT AUTHORITY: DESKTOP-0011M0V: Dell SupportAssist Dell SupportAssist 1603 (NULL) (NULL) (NULL) ?
#
# 2021 Feb 08 10:08:16 WinEvtLog: Application: ERROR(1024): MsiInstaller: SYSTEM: NT AUTHORITY: DESKTOP-0011M0V: Dell SupportAssist Dell SupportAssist 1603 (NULL) (NULL) (NULL) ?
#
# 2021 Feb 24 16:21:07 WinEvtLog: Application: INFORMATION(11707): MsiInstaller: DATATEK: DESKTOP-QQU2HFQ: DESKTOP-QQU2HFQ: Product: Microsoft Visual C++ 2010  x64 Redistributable - 10.0.30319 -- Installation completed successfully. (NULL) (NULL) (NULL) (NULL) (NULL) ?
#
# 2021 Feb 03 17:45:23 WinEvtLog: Application: ERROR(1024): MsiInstaller: SYSTEM: NT AUTHORITY: DESKTOP-0011M0V: Dell SupportAssist Dell SupportAssist 1603 (NULL) (NULL) (NULL) ?
#
# 2021 Feb 04 15:03:53 WinEvtLog: Application: ERROR(1024): MsiInstaller: SYSTEM: NT AUTHORITY: DESKTOP-0011M0V: Dell SupportAssist Dell SupportAssist 1603 (NULL) (NULL) (NULL) ?
#
# 2021 Feb 02 12:58:37 WinEvtLog: Application: INFORMATION(11707): MsiInstaller: admin: DESKTOP-8SVLRVI: DESKTOP-8SVLRVI: Product: Microsoft Visual C++ 2012 x86 Minimum Runtime - 11.0.61030 -- Installation completed successfully. (NULL) (NULL) (NULL) (NULL) (NULL) ?
#
# 2021 Feb 03 15:15:16 WinEvtLog: Application: ERROR(1024): MsiInstaller: SYSTEM: NT AUTHORITY: DESKTOP-0011M0V: Dell SupportAssist Dell SupportAssist 1603 (NULL) (NULL) (NULL) ?
#
# 2021 Feb 05 10:33:56 WinEvtLog: Application: ERROR(1024): MsiInstaller: SYSTEM: NT AUTHORITY: DESKTOP-0011M0V: Dell SupportAssist Dell SupportAssist 1603 (NULL) (NULL) (NULL) ?
#
# 2021 Feb 04 13:03:52 WinEvtLog: Application: ERROR(1024): MsiInstaller: SYSTEM: NT AUTHORITY: DESKTOP-0011M0V: Dell SupportAssist Dell SupportAssist 1603 (NULL) (NULL) (NULL) ?
#
# 2021 Feb 24 16:15:36 WinEvtLog: Application: INFORMATION(11707): MsiInstaller: DATATEK: DESKTOP-QQU2HFQ: DESKTOP-QQU2HFQ: Product: WiX Toolset v3.11 Native 2010 SDK -- Installation completed successfully. (NULL) (NULL) (NULL) (NULL) (NULL) ?
#
# 2021 Jan 25 09:07:56 WinEvtLog: Application: ERROR(256): DPTF: (no user): no domain: DESKTOP-QQU2HFQ: Intel(R) Dynamic Platform and Thermal Framework : ESIF(8.3.10207.5567) TYPE: ERROR MODULE: DPTF TIME 233597965 ms  DPTF Build Version:  8.3.10207.5567 DPTF Build Date:  Nov  2 2017 14:28:00 Source File:  ..\..\..\..\Sources\Policies\ConfigTdpPolicy\ConfigTdpPolicy.cpp @ line 155 Executing Function:  ConfigTdpPolicy::onBindDomain Message:  ConfigTdp not supported. Participant:  TCPU [0] Domain:  PKG [0] Policy:  ConfigTDP Policy [0]
#
# 2021 Feb 03 16:45:20 WinEvtLog: Application: ERROR(1024): MsiInstaller: SYSTEM: NT AUTHORITY: DESKTOP-0011M0V: Dell SupportAssist Dell SupportAssist 1603 (NULL) (NULL) (NULL) ?
#
# 2021 Feb 03 17:49:46 WinEvtLog: System: ERROR(10010): DCOM: DATATEK: DESKTOP-QQU2HFQ: DESKTOP-QQU2HFQ: {FD06603A-2BDF-4BB1-B7DF-5DC68F353601}
#
# 2021 Feb 02 11:15:51 WinEvtLog: System: ERROR(10010): DCOM: admin: DESKTOP-8SVLRVI: DESKTOP-8SVLRVI: Microsoft.SkypeApp_15.67.99.0_x86__kzf8qxf38zg5c!App.AppXtwmqn4em5r5dpafgj4t4yyxgjfe0hr50.mca
#
# 2021 Feb 19 18:15:50 WinEvtLog: Application: ERROR(256): DPTF: (no user): no domain: DESKTOP-QQU2HFQ: Intel(R) Dynamic Platform and Thermal Framework : ESIF(8.3.10207.5567) TYPE: ERROR MODULE: DPTF TIME 292802053 ms  DPTF Build Version:  8.3.10207.5567 DPTF Build Date:  Nov  2 2017 14:28:00 Source File:  ..\..\..\..\Sources\Policies\ConfigTdpPolicy\ConfigTdpPolicy.cpp @ line 342 Executing Function:  ConfigTdpPolicy::synchronizeConfigTdpPlatformSettings Message:  ConfigTdp not supported. Policy:  ConfigTDP Policy [0]
#
# 2021 Feb 03 14:15:14 WinEvtLog: Application: ERROR(1024): MsiInstaller: SYSTEM: NT AUTHORITY: DESKTOP-0011M0V: Dell SupportAssist Dell SupportAssist 1603 (NULL) (NULL) (NULL) ?
#
# 2021 Feb 04 10:33:55 WinEvtLog: Application: ERROR(1024): MsiInstaller: SYSTEM: NT AUTHORITY: DESKTOP-0011M0V: Dell SupportAssist Dell SupportAssist 1603 (NULL) (NULL) (NULL) ?
#
# 2021 Jan 26 09:06:33 WinEvtLog: Application: ERROR(256): DPTF: (no user): no domain: DESKTOP-QQU2HFQ: Intel(R) Dynamic Platform and Thermal Framework : ESIF(8.3.10207.5567) TYPE: ERROR MODULE: DPTF TIME 319921179 ms  DPTF Build Version:  8.3.10207.5567 DPTF Build Date:  Nov  2 2017 14:28:00 Source File:  ..\..\..\..\Sources\Policies\ConfigTdpPolicy\ConfigTdpPolicy.cpp @ line 155 Executing Function:  ConfigTdpPolicy::onBindDomain Message:  ConfigTdp not supported. Participant:  TCPU [0] Domain:  PKG [0] Policy:  ConfigTDP Policy [0]
#
# 2021 Jan 22 16:11:45 WinEvtLog: System: ERROR(10010): DCOM: DATATEK: DESKTOP-QQU2HFQ: DESKTOP-QQU2HFQ: {FD06603A-2BDF-4BB1-B7DF-5DC68F353601}
#
# 2021 Feb 03 17:15:17 WinEvtLog: Application: ERROR(1024): MsiInstaller: SYSTEM: NT AUTHORITY: DESKTOP-0011M0V: Dell SupportAssist Dell SupportAssist 1603 (NULL) (NULL) (NULL) ?
#
# 2021 Feb 04 10:04:09 WinEvtLog: Application: ERROR(1024): MsiInstaller: SYSTEM: NT AUTHORITY: DESKTOP-0011M0V: Dell SupportAssist Dell SupportAssist 1603 (NULL) (NULL) (NULL) ?
#
# 2021 Feb 05 11:04:24 WinEvtLog: Application: ERROR(1024): MsiInstaller: SYSTEM: NT AUTHORITY: DESKTOP-0011M0V: Dell SupportAssist Dell SupportAssist 1603 (NULL) (NULL) (NULL) ?

# %% [markdown]
# ## OpenSCAP

# %%
groups.get_group('OpenSCAP')
# Out:
#         level                                           full_log first_word
# id
# 145945      0  OpenSCAP Error: Probe with PID=21944 has been ...   OpenSCAP
# 271689      0  OpenSCAP Error: Probe with PID=27844 has been ...   OpenSCAP
# 462254      0  OpenSCAP Error: Probe with PID=7984 has been k...   OpenSCAP

# %%
show_all('OpenSCAP')
# Out:
# OpenSCAP Error: Probe with PID=21944 has been killed with signal 9 [sch_pipe.c:178]
#
# OpenSCAP Error: Probe with PID=27844 has been killed with signal 9 [sch_pipe.c:178]
#
# OpenSCAP Error: Probe with PID=7984 has been killed with signal 9 [sch_pipe.c:178]

# %% [markdown]
# ## juniper

# %%
groups.get_group('juniper')
# Out:
#         level full_log first_word
# id
# 5144        0  juniper    juniper
# 108472      0  juniper    juniper
# 170195      3  juniper    juniper
# 207811      0  juniper    juniper
# 470486      0  juniper    juniper

# %% [markdown]
# ## The

# %%
groups.get_group('The')
# Out:
#         level                                           full_log first_word
# id
# 39057       2  The average number of logs between 10:00 and 1...        The
# 87600       2  The average number of logs between 5:00 and 6:...        The
# 109510      2  The average number of logs between 6:00 and 7:...        The
# 262892      2  The average number of logs between 21:00 and 2...        The
# 294072      2  The average number of logs between 5:00 and 6:...        The
# 294127      2  The average number of logs between 4:00 and 5:...        The
# 343011      2  The average number of logs between 14:00 and 1...        The
# 345903      2  The average number of logs between 15:00 and 1...        The
# 376681      2  The average number of logs between 2:00 and 3:...        The
# 380583      2  The average number of logs between 10:00 and 1...        The
# 400735      2  The average number of logs between 13:00 and 1...        The

# %%
show_all('The')
# Out:
# The average number of logs between 10:00 and 11:00 is 5399. We reached 37090.
#
# The average number of logs between 5:00 and 6:00 is 222. We reached 77946.
#
# The average number of logs between 6:00 and 7:00 is 6420. We reached 28494.
#
# The average number of logs between 21:00 and 22:00 is 5325. We reached 95.
#
# The average number of logs between 5:00 and 6:00 is 8362. We reached 93476.
#
# The average number of logs between 4:00 and 5:00 is 2806. We reached 11476.
#
# The average number of logs between 14:00 and 15:00 is 9734. We reached 26958.
#
# The average number of logs between 15:00 and 16:00 is 4411. We reached 9487.
#
# The average number of logs between 2:00 and 3:00 is 9428. We reached 75572.
#
# The average number of logs between 10:00 and 11:00 is 12612. We reached 31532.
#
# The average number of logs between 13:00 and 14:00 is 2697. We reached 93028.

# %% [markdown]
# - 시간 -> `<TIME>`
# - 숫자 -> `<NUM>`

# %% [markdown]
# ## Windows

# %%
groups.get_group('Windows')
# Out:
#         level                                           full_log first_word
# id
# 4134        1  Windows Audit: Null sessions allowed {PCI_DSS:...    Windows
# 122200      1  Windows Audit: Null sessions allowed {PCI_DSS:...    Windows
# 145433      1  Windows Audit: Null sessions allowed {PCI_DSS:...    Windows
# 150488      1  Windows Audit: Null sessions allowed {PCI_DSS:...    Windows
# 236515      1  Windows Audit: Winpcap packet filter driver fo...    Windows
# 282994      1  Windows Audit: Null sessions allowed {PCI_DSS:...    Windows
# 296413      1  Windows Audit: Null sessions allowed {PCI_DSS:...    Windows
# 318658      1  Windows Audit: Null sessions allowed {PCI_DSS:...    Windows
# 363534      1  Windows Audit: Null sessions allowed {PCI_DSS:...    Windows
# 391901      1  Windows Audit: Null sessions allowed {PCI_DSS:...    Windows
# 424884      1  Windows Audit: Null sessions allowed {PCI_DSS:...    Windows
# 445714      1  Windows Audit: Null sessions allowed {PCI_DSS:...    Windows
# 451296      1  Windows Audit: Null sessions allowed {PCI_DSS:...    Windows

# %%
show_all('Windows')
# Out:
# Windows Audit: Null sessions allowed {PCI_DSS: 11.4}.
#
# Windows Audit: Null sessions allowed {PCI_DSS: 11.4}.
#
# Windows Audit: Null sessions allowed {PCI_DSS: 11.4}.
#
# Windows Audit: Null sessions allowed {PCI_DSS: 11.4}.
#
# Windows Audit: Winpcap packet filter driver found {PCI_DSS: 10.6.1}. File: C:\WINDOWS\Sysnative\drivers\npf.sys.
#
# Windows Audit: Null sessions allowed {PCI_DSS: 11.4}.
#
# Windows Audit: Null sessions allowed {PCI_DSS: 11.4}.
#
# Windows Audit: Null sessions allowed {PCI_DSS: 11.4}.
#
# Windows Audit: Null sessions allowed {PCI_DSS: 11.4}.
#
# Windows Audit: Null sessions allowed {PCI_DSS: 11.4}.
#
# Windows Audit: Null sessions allowed {PCI_DSS: 11.4}.
#
# Windows Audit: Null sessions allowed {PCI_DSS: 11.4}.
#
# Windows Audit: Null sessions allowed {PCI_DSS: 11.4}.

# %% [markdown]
# ## Trojaned

# %%
groups.get_group('Trojaned')
# Out:
#         level                                           full_log first_word
# id
# 4728        5  Trojaned version of file '/bin/netstat' detect...   Trojaned
# 58077       5  Trojaned version of file '/usr/bin/netstat' de...   Trojaned
# 227579      5  Trojaned version of file '/usr/sbin/netstat' d...   Trojaned
# 234605      5  Trojaned version of file '/bin/netstat' detect...   Trojaned
# 269504      5  Trojaned version of file '/usr/bin/netstat' de...   Trojaned
# 305705      5  Trojaned version of file '/usr/sbin/netstat' d...   Trojaned
# 322077      5  Trojaned version of file '/usr/sbin/netstat' d...   Trojaned
# 359733      5  Trojaned version of file '/bin/netstat' detect...   Trojaned
# 367519      5  Trojaned version of file '/usr/bin/netstat' de...   Trojaned
# 383455      5  Trojaned version of file '/usr/sbin/ifconfig' ...   Trojaned
# 388004      5  Trojaned version of file '/usr/sbin/netstat' d...   Trojaned
# 417760      5  Trojaned version of file '/usr/bin/netstat' de...   Trojaned
# 433294      5  Trojaned version of file '/bin/kill' detected....   Trojaned
# 438975      5  Trojaned version of file '/usr/sbin/ifconfig' ...   Trojaned
# 459777      5  Trojaned version of file '/usr/sbin/ifconfig' ...   Trojaned

# %%
show_all('Trojaned')
# Out:
# Trojaned version of file '/bin/netstat' detected. Signature used: 'bash|^/bin/sh|/dev/[^aik]|/prof|grep|addr\.h' (Generic).
#
# Trojaned version of file '/usr/bin/netstat' detected. Signature used: 'bash|^/bin/sh|/dev/[^aik]|/prof|grep|addr\.h' (Generic).
#
# Trojaned version of file '/usr/sbin/netstat' detected. Signature used: 'bash|^/bin/sh|/dev/[^aik]|/prof|grep|addr\.h' (Generic).
#
# Trojaned version of file '/bin/netstat' detected. Signature used: 'bash|^/bin/sh|/dev/[^aik]|/prof|grep|addr\.h' (Generic).
#
# Trojaned version of file '/usr/bin/netstat' detected. Signature used: 'bash|^/bin/sh|/dev/[^aik]|/prof|grep|addr\.h' (Generic).
#
# Trojaned version of file '/usr/sbin/netstat' detected. Signature used: 'bash|^/bin/sh|/dev/[^aik]|/prof|grep|addr\.h' (Generic).
#
# Trojaned version of file '/usr/sbin/netstat' detected. Signature used: 'bash|^/bin/sh|/dev/[^aik]|/prof|grep|addr\.h' (Generic).
#
# Trojaned version of file '/bin/netstat' detected. Signature used: 'bash|^/bin/sh|/dev/[^aik]|/prof|grep|addr\.h' (Generic).
#
# Trojaned version of file '/usr/bin/netstat' detected. Signature used: 'bash|^/bin/sh|/dev/[^aik]|/prof|grep|addr\.h' (Generic).
#
# Trojaned version of file '/usr/sbin/ifconfig' detected. Signature used: 'bash|^/bin/sh|/dev/tux|session.null|/dev/[^cludisopt]' (Generic).
#
# Trojaned version of file '/usr/sbin/netstat' detected. Signature used: 'bash|^/bin/sh|/dev/[^aik]|/prof|grep|addr\.h' (Generic).
#
# Trojaned version of file '/usr/bin/netstat' detected. Signature used: 'bash|^/bin/sh|/dev/[^aik]|/prof|grep|addr\.h' (Generic).
#
# Trojaned version of file '/bin/kill' detected. Signature used: '/dev/[ab,d-k,m-z]|/dev/[F-Z]|/dev/[A-D]|/dev/[0-9]|proc\.h|bash|tmp' (Generic).
#
# Trojaned version of file '/usr/sbin/ifconfig' detected. Signature used: 'bash|^/bin/sh|/dev/tux|session.null|/dev/[^cludisopt]' (Generic).
#
# Trojaned version of file '/usr/sbin/ifconfig' detected. Signature used: 'bash|^/bin/sh|/dev/tux|session.null|/dev/[^cludisopt]' (Generic).

# %% [markdown]
# ## NTFS

# %%
groups.get_group('NTFS')
# Out:
#         level                                           full_log first_word
# id
# 26041       5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 34838       5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 49230       5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 67688       5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 70121       5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 92820       5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 96475       5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 180259      5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 189843      5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 202893      5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 233499      5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 233502      5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 240182      5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 248735      5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 273480      5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 278837      5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 285035      5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 298667      5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 313133      5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 355141      5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 400847      5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 404605      5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 424513      5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 448102      5  NTFS Alternate data stream found: 'C:\Program ...       NTFS
# 453911      5  NTFS Alternate data stream found: 'C:\Program ...       NTFS

# %%
show_all('NTFS')
# Out:
# NTFS Alternate data stream found: 'C:\Program Files/Sublime Text 3:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/rempl:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/Sublime Text 3:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/Sublime Text 3:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/rempl:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/rempl:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/rempl:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/CUAssistant:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/rempl:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/rempl:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/CUAssistant:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/rempl:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/CUAssistant:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/CUAssistant:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/rempl:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/rempl:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/rempl:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/CUAssistant:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/rempl:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/CUAssistant:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/CUAssistant:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/CUAssistant:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/CUAssistant:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/Bandizip:Win32App_1'. Possible hidden content.
#
# NTFS Alternate data stream found: 'C:\Program Files/rempl:Win32App_1'. Possible hidden content.

# %% [markdown]
# ## System

# %%
log_system = groups.get_group('System').copy()
log_system
# Out:
#         level                                           full_log first_word
# id
# 334         1  System Audit: CIS - RHEL7 - 4.1.1 - Network pa...     System
# 482         1  System Audit: CIS - RHEL7 - 1.4.4 - SELinux se...     System
# 622         1  System Audit: SSH Hardening - 3: Root can log ...     System
# 906         1  System Audit: SSH Hardening - 8: Wrong Grace T...     System
# 1563        1  System Audit: CIS - RHEL7 - 1.4.4 - SELinux se...     System
# ...       ...                                                ...        ...
# 469301      1  System Audit: CIS - RHEL7 - 3.2 - Avahi daemon...     System
# 469804      1  System Audit: SSH Hardening - 8: Wrong Grace T...     System
# 470654      1  System Audit: SSH Hardening - 5: Password Auth...     System
# 471334      1  System Audit: CIS - RHEL7 - 1.4.2 - SELinux no...     System
# 472627      1  System Audit: SSH Hardening - 9: Wrong Maximum...     System
#
# [820 rows x 3 columns]

# %%
log_system['full_log'].str.extract('System Audit: (.+)').value_counts()
# Out:
# SSH Hardening - 5: Password Authentication {PCI_DSS: 2.2.4}. File: /etc/ssh/sshd_config. Reference: 5 .                                                                                                                                                                               49
# SSH Hardening - 4: No Public Key authentication {PCI_DSS: 2.2.4}. File: /etc/ssh/sshd_config. Reference: 4 .                                                                                                                                                                          44
# CIS - Testing against the CIS Red Hat Enterprise Linux 7 Benchmark v1.1.0. File: /etc/redhat-release. Reference: https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf .                                                                 43
# SSH Hardening - 6: Empty passwords allowed {PCI_DSS: 2.2.4}. File: /etc/ssh/sshd_config. Reference: 6 .                                                                                                                                                                               42
# SSH Hardening - 7: Rhost or shost used for authentication {PCI_DSS: 2.2.4}. File: /etc/ssh/sshd_config. Reference: 7 .                                                                                                                                                                41
# CIS - RHEL7 - 4.2.2 - Network parameters - ICMP redirects accepted {CIS: 1.1.1 RHEL7} {PCI_DSS: 2.2.4}. File: /proc/sys/net/ipv4/conf/default/accept_redirects. Reference: https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf .       40
# SSH Hardening - 8: Wrong Grace Time {PCI_DSS: 2.2.4}. File: /etc/ssh/sshd_config. Reference: 8 .                                                                                                                                                                                      39
# CIS - RHEL7 - 6.2.5 - SSH Configuration - Set SSH MaxAuthTries to 4 or Less  {CIS - RHEL7 - 6.2.5} {PCI_DSS: 2.2.4}. File: /etc/ssh/sshd_config. Reference: https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf .                      39
# CIS - RHEL7 - 1.4.2 - SELinux not set to enforcing {CIS: 1.4.2 RHEL7} {PCI_DSS: 2.2.4}. File: /etc/selinux/config. Reference: https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf .                                                    39
# CIS - RHEL7 - 6.2.9 - SSH Configuration - Empty passwords permitted {CIS: 6.2.9 RHEL7} {PCI_DSS: 4.1}. File: /etc/ssh/sshd_config. Reference: https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf .                                    37
# SSH Hardening - 3: Root can log in. File: /etc/ssh/sshd_config. Reference: 3 .                                                                                                                                                                                                        37
# CIS - RHEL7 - 3.2 - Avahi daemon not disabled {CIS: 3.3 RHEL7} {PCI_DSS: 2.2.2}. Process: avahi-daemon. Reference: https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf .                                                               37
# CIS - RHEL7 - 4.1.1 - Network parameters - IP Forwarding enabled {CIS: 4.1.1 RHEL7} {PCI_DSS: 2.2.4}. File: /proc/sys/net/ipv4/ip_forward. Reference: https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf .                            37
# CIS - RHEL7 - 4.1.2 - Network parameters - IP send redirects enabled {CIS: 4.1.2 RHEL7} {PCI_DSS: 2.2.4}. File: /proc/sys/net/ipv4/conf/all/send_redirects. Reference: https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf .           37
# CIS - RHEL7 - 4.2.3 - Network parameters - ICMP secure redirects accepted {CIS: 4.2.3 RHEL7} {PCI_DSS: 2.2.4}. File: /proc/sys/net/ipv4/conf/all/secure_redirects. Reference: https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf .    37
# SSH Hardening - 9: Wrong Maximum number of authentication attempts {PCI_DSS: 2.2.4}. File: /etc/ssh/sshd_config. Reference: 9 .                                                                                                                                                       36
# CIS - RHEL7 - 1.4.4 - SELinux setroubleshoot enabled {CIS: 1.4.4 RHEL7} {PCI_DSS: 2.2.4}. File: /usr/share/dbus-1/services/sealert.service. Reference: https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf .                           33
# CIS - RHEL7 - Build considerations - Robust partition scheme - /var is not on its own partition {CIS: 1.1.5 RHEL7}. File: /etc/fstab. Reference: https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf .                                 32
# CIS - RHEL7 - 6.2.8 - SSH Configuration - Root login allowed {CIS: 6.2.8 RHEL7} {PCI_DSS: 4.1}. File: /etc/ssh/sshd_config. Reference: https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf .                                           32
# CIS - RHEL7 - 1.1.10 -  Partition /home without 'nodev' set {CIS: 1.1.10 RHEL7} {PCI_DSS: 2.2.4}. File: /etc/fstab. Reference: https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf .                                                   31
# CIS - RHEL7 - Build considerations - Robust partition scheme - /tmp is not on its own partition. File: /etc/fstab. Reference: https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf .                                                    29
# CIS - RHEL7 - 4.2.4 - Network parameters - martians not logged {CIS: 4.2.4 RHEL7} {PCI_DSS: 2.2.4}. File: /proc/sys/net/ipv4/conf/all/log_martians. Reference: https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf .                   29
# dtype: int64

# %% [markdown]
# ## File

# %%
log_file = groups.get_group('File')
log_file
# Out:
#         level                                           full_log first_word
# id
# 515         3  File 'HKEY_LOCAL_MACHINE\System\CurrentControl...       File
# 794         5  File '/var/www/html_update/management/hashconf...       File
# 1997        3           File '/usr/bin/elasticdump' was added.\n       File
# 2320        3  File 'HKEY_LOCAL_MACHINE\System\CurrentControl...       File
# 2858        5  File 'HKEY_LOCAL_MACHINE\System\CurrentControl...       File
# ...       ...                                                ...        ...
# 471343      5  File 'HKEY_LOCAL_MACHINE\System\CurrentControl...       File
# 471567      5  File '/var/www/html/management/hashbin.txt' is...       File
# 471822      5  File 'HKEY_LOCAL_MACHINE\System\CurrentControl...       File
# 472052      5  File '/var/esild/etc/ossec.conf' checksum chan...       File
# 472322      3  File 'HKEY_LOCAL_MACHINE\System\CurrentControl...       File
#
# [822 rows x 3 columns]

# %%
log_file['level'].value_counts()
# Out:
# 5    641
# 3    181
# Name: level, dtype: int64

# %%
groups.get_group('File')['full_log'].value_counts()
# Out:
# File '/var/www/html/management/ossec.conf' is owned by root and has written permissions to anyone.                                                                                                                                                                                                                                                  38
# File '/var/www/html_update/management/hashbin.txt' is owned by root and has written permissions to anyone.                                                                                                                                                                                                                                          36
# File '/var/www/html_update/management/ossec.conf' is owned by root and has written permissions to anyone.                                                                                                                                                                                                                                           35
# File '/var/www/html/management/hashconf.txt' is owned by root and has written permissions to anyone.                                                                                                                                                                                                                                                35
# File '/var/www/html/management/hashbin.txt' is owned by root and has written permissions to anyone.                                                                                                                                                                                                                                                 29
#                                                                                                                                                                                                                                                                                                                                                     ..
# File 'HKEY_LOCAL_MACHINE\System\CurrentControlSet\Services\DXGKrnl' checksum changed.\nOld md5sum was: 'b62c6655c577700d5626027840f70fae'\nNew md5sum is : '4a4a1b21f85dd15290ecbe9dfc49ddcd'\nOld sha1sum was: '82c47ecae2d9e2af572936bcefea6d4a8504f357'\nNew sha1sum is : '7bdd992d119c1d58ecb93ceb5f174adc02b0652f'\n                            1
# File 'HKEY_LOCAL_MACHINE\System\CurrentControlSet\Services\wuauserv' checksum changed.\nOld md5sum was: '7572fc67165873a1a7f4da64397c3885'\nNew md5sum is : 'fc50af3d63e5891222df700e3601b652'\nOld sha1sum was: 'f1657e7a88c8ca4dfd7f2635e7e4883911e0c0d9'\nNew sha1sum is : 'f9d6ff63148cd6de0e09e6f12a378301224403c6'\n                           1
# File 'HKEY_LOCAL_MACHINE\System\CurrentControlSet\Services\WpnUserService' checksum changed.\nOld md5sum was: 'e5ce7a8e9bad3174164b608cb1e069d7'\nNew md5sum is : 'f695a8fd2ef1284dedca64562253f62a'\nOld sha1sum was: 'a75762b018c7311bdc7dd922a81dba8c3877f645'\nNew sha1sum is : 'ad8f392ce0b59f51ee73104f0242f0cb106cb501'\n                     1
# File 'HKEY_LOCAL_MACHINE\System\CurrentControlSet\Services\EventLog\System\Microsoft-Windows-Hyper-V-Hypervisor' was added.\n                                                                                                                                                                                                                        1
# File 'HKEY_LOCAL_MACHINE\System\CurrentControlSet\Services\buttonconverter\Parameters\Wdf' checksum changed.\nOld md5sum was: 'a0a6f40a90ecdc281d9382e4e8bf1625'\nNew md5sum is : 'bf48aafdcd91e79cac2883a7784fcc6a'\nOld sha1sum was: 'af93cab40403ce053a04f400a4020d434063070f'\nNew sha1sum is : '8adefc70329263ce89bbbdffcdb4aa92942b0715'\n     1
# Name: full_log, Length: 596, dtype: int64

# %% [markdown]
# \<FILE\>

# %%
log_file = groups.get_group('File').copy()

# %%
for log in log_file['full_log'].str.replace("(?<=File )'.+'", "<FILE>", regex=True):
    print(log, '\n')
# Out:
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '6bf8548555a7ab4a34b83436539b6495'
# New md5sum is : '85c899e225e74c712f8e2d2ef32924c0'
# Old sha1sum was: 'c34db755b2af9472d44d2a51e87699991fee9b8e'
# New sha1sum is : 'efdfe108fb55c6a564a3c1821af6b388f9808223'
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old modification time was: 'Mon Nov 16 13:01:41 2020', now it is 'Thu Nov 19 08:55:16 2020'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '664191fb850026c06ea88ed971daa7fd'
# New md5sum is : '9b126e6218876ca57284259416fd8e6e'
# Old sha1sum was: '23f3ae9ce553344e9361e5187e81946162119151'
# New sha1sum is : '52143ce22a06f4d78e7ae83193b02737902169df'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: 'bee03237ea803f91e468ce5404efa622'
# New md5sum is : '2f43dfc7a4f84a246bcfda248e5ab44f'
# Old sha1sum was: 'f591a0f3910caa91e69c116fe9a7091a01c27560'
# New sha1sum is : 'e8c0484ba1276d30bd9f673e47502e2c0eca65e1'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '378a2283ed3e22341b52db576e18e2fb'
# New md5sum is : 'b0471ccb82d1742d269626e8fe722ef2'
# Old sha1sum was: 'b8bf94ded860faec7e2b01e2d03dbebb6ddd0782'
# New sha1sum is : '0ab4355129acf544b688424a5a8325455e0ba090'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'cecc66e3c97b293bb66ccabc231cc4f4'
# New md5sum is : '41d555856a267feaa818b8c95462ef6b'
# Old sha1sum was: '8f040a2f89197154566cd9d292c1e71dc1decb46'
# New sha1sum is : 'af1212dc52e1bbe1839a49c873a077b91862c843'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'd6d08dc9a2fe925a1ef16c9fc9a7d090'
# New md5sum is : '58c920a584447cd35f368851d59e2964'
# Old sha1sum was: '77d0f4340ab7a0a4676e03e7064bd9e496a843ef'
# New sha1sum is : '8a303dfb267090a32dc829f22a0502d63ba2d0b5'
# Old sha256sum was: '4b37ab166e4900a2632c06cf514a5b1625ad3006bbf0f243c974c00ee4f62138'
# New sha256sum is : '755640edb89582ccef4625d16bc31c7adf3d9216794619cb762e68ea7d52c8e2'
# Old modification time was: 'Wed Nov 18 10:42:41 2020', now it is 'Thu Nov 19 05:00:48 2020'
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '8c5c052563ec2655ece2b480a4eb9ecc'
# New md5sum is : 'ea1b12ec433fe04e2dda468dfa7f4d86'
# Old sha1sum was: '08b6fbdb22d97fac0f1eae9cc6d94d55d48f0cc1'
# New sha1sum is : '65e70d786a3bb5f65893265c407237ccbc9874ce'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '93b75a9ecc7420bedd3a84b08768be6f'
# New md5sum is : '15ff3b5198ed1de6a4de36f647107535'
# Old sha1sum was: 'd7bdb298db16987bbb7a8c074a1c3ce9f5754d2e'
# New sha1sum is : '9c436e614adb9f777a20d0310790fd93159b95b0'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '89bb8af56a0d88b3571381074672b372'
# New md5sum is : '1ed4182e212f8d743f94bee937f6ccfd'
# Old sha1sum was: 'f5277095d2bbe4ba0fccafed2d10e938ff07e77a'
# New sha1sum is : '0623e2b5b945b90d8a4303bd8dcb05ead6a34c94'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '9bde9c66418bb263510a6b8ec8d7c786'
# New md5sum is : 'fa96ca2a7f81c155d0b2c9376103fee9'
# Old sha1sum was: 'f9a5a335be412b4b5deda874d655e02bf0eb52ad'
# New sha1sum is : '7542840c3ab159cca2aee43a0120168af82f83dd'
# Old sha256sum was: 'afd6accddc190d00e72d40f42658b4a81d90a73b91bbc4ffc4a5dcd8cd899d28'
# New sha256sum is : 'f1fd788b85783fc96be67de9adff75016b609f0771fedf94477bf8802e688d0b'
# Old modification time was: 'Sat Sep 26 22:24:17 2020', now it is 'Sun Sep 27 11:02:37 2020'
# Old inode was: '406047362', now it is '406047392'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'd754340e730315a1fb25d3eafe6fe92b'
# New md5sum is : '9525c9b8b40d9e73843e395b8b792f8a'
# Old sha1sum was: '72bb898e3263fa325bdd99154b185806ed18a3e1'
# New sha1sum is : '81345f2c9a2185adae7c9a6821653f72abf54a4b'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '4d8d8e2454a9f69421d621ba02e367f7'
# New md5sum is : 'f36015d1d9f9ce2c39cc203b1327fd2d'
# Old sha1sum was: '8baef0b2b45bb437f1914b6f1698b83a14885018'
# New sha1sum is : '644244696426384670da513dca6ecfdbb7114b4c'
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '8b05c0effb6fc3c527d311146454c088'
# New md5sum is : '033653020f7d1b3144fc1472fedde3f3'
# Old sha1sum was: 'c12856bd4922da926b2245593616a922b30595b4'
# New sha1sum is : 'a2f42de4cb490832939ed63d1279204c237c23f4'
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '046326d854d21d3360287187ff502d37'
# New md5sum is : '51c320732606e4be3f767894820ad13f'
# Old sha1sum was: 'd9ffbed68236e39282d79dc92deed96d86f3d8e5'
# New sha1sum is : '6ee89f08ae72548767bf030301eee7758864d719'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'd73e95f89b20db56e30d35b975e15763'
# New md5sum is : 'd66c0cd4b6d817e188f3c0b81a25880f'
# Old sha1sum was: '21d821e612cf371f04cfef8be441a90b3e393425'
# New sha1sum is : '4562bccd88412cf272c30e0b0fa0fd8374614e58'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '196655c889b9d8fd95656e0de6371fb0'
# New md5sum is : 'a28f6aa57b4417d88eefde6ffa2888c8'
# Old sha1sum was: 'ad757265d86b680d134c90614ff8f01fade492c2'
# New sha1sum is : '080ff80c05971975960262a38eb7c12d59a34a3d'
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '0dfbb34c2849d127479767a5e7ab41e4'
# New md5sum is : 'e175a4182b9107b5599758694807fdd8'
# Old sha1sum was: '2877b271d704d2497124e22544874b2bde8d2537'
# New sha1sum is : '480cabfe2928519d394bb3a0e175b5f4645417f0'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '92d2a9ff6761db77e363b507c73937f0'
# New md5sum is : '84ae66b4a3d9221b0151ee4dbb98212d'
# Old sha1sum was: '1c64a42d7ff3dd42443e142c0789297d60a29e7b'
# New sha1sum is : 'fb6e501255084e648f365ef506b4d706e3512d70'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '55446b9d704c9423bb48f56992b75cd6'
# New md5sum is : '2ee9468a872cb325efbd12a0829b07ec'
# Old sha1sum was: 'ab5fc301e09ede97b1cd438c6fe90d496d47e703'
# New sha1sum is : 'fefab49fff2fec30a225fd2df1c1457163ac6497'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'a6a910004e97cbc603280c255badab05'
# New md5sum is : 'f773e3ab3bf68393c242375c7f9c6cfe'
# Old sha1sum was: '302a514fd22484c035011bb9e88d2e80702de0b3'
# New sha1sum is : 'b16711eb18e5478e01d502dca750066055b1631d'
#
#
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '0beffd3573d9215ff89721e736069ded'
# New md5sum is : '48013f8282d9894759f94be0cce8dd61'
# Old sha1sum was: '6cd16ec062716626d59e5cd2d8c9e38455c4dc9d'
# New sha1sum is : 'd1477314739da8ea29ee19cf9ea52e36eaefb16e'
#
#
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '78abee9996698751d1b3f51853b8c414'
# New md5sum is : '4aa56eca7b6cfbb95ba9c9a51dfecef5'
# Old sha1sum was: '2a4bc520d65cebfabedb95ba27649f3bf5ade5a3'
# New sha1sum is : '3f6dc95423e1c7e0d1653596853152fec96cab7a'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: 'eeea5cec917f985f9067259f15c9efbe'
# New md5sum is : 'f20dbb897af22aff20f62d8dce33838a'
# Old sha1sum was: 'd6a873e6f5215f94cbaa49d10c1b6782d086dc39'
# New sha1sum is : 'ebdec0c4f479490f138dc8749965ec97b77c6694'
#
#
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: 'c3cd076b064ae5383bffb76f2c5e6341'
# New md5sum is : '823937ef13b2db729a740cee69ac4949'
# Old sha1sum was: '1eb90355a0c36c94e7de53c2cd34e74d50fc30bc'
# New sha1sum is : 'aef986ad16add8f77f105b08b703119b406e53d2'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '36af13d2a9565d399eeedf25867f9ac3'
# New md5sum is : '15596a92806b48f3be4de9f057284543'
# Old sha1sum was: '04fb3fd21976b9fe3718bdacd566f1bc376b489f'
# New sha1sum is : '36f5638e283a5202c047f73e2c52de736bd42124'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '77055e223da93253cabc62674e932f69'
# New md5sum is : '6239d03dd9734b92a4a0048d52325f81'
# Old sha1sum was: '3384105cde4d44125898816359b5b8e98d5ac3d8'
# New sha1sum is : '266231050a902dd87f08a41d01cc6f3c72a39ee4'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'e983a88ff7e9f5928984e0fe3b6e7736'
# New md5sum is : '7f2dcfbecaa1683dbadf359d1070ada1'
# Old sha1sum was: '60a0708fae5fe37183516e3def7ab597d8dd8b88'
# New sha1sum is : 'eb944c7775cbede6f99591978a5967883da32556'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '29f966f85adbd0acbc12afa7fb5452a9'
# New md5sum is : '0ea4550dd2debf0c12e271cbef949f45'
# Old sha1sum was: 'a7c8eb31ac96d7889d0c99ae1249c6d014e29367'
# New sha1sum is : '26014de5c23f5ed5cd04d5c0ec5dd8689bbf9268'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '0e7fd04755e5577d55c1507efc0d0c80'
# New md5sum is : 'fddf278f9fe78d198f3734743375fa66'
# Old sha1sum was: 'df7769956b593089ed7566c38f1bacad19e1841a'
# New sha1sum is : '435bb927416c99804128e3b92c1741b8654f2143'
#
#
# File <FILE> checksum changed.
# Old modification time was: 'Wed Nov 18 10:42:41 2020', now it is 'Thu Nov 19 05:00:48 2020'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '77055e223da93253cabc62674e932f69'
# New md5sum is : '6239d03dd9734b92a4a0048d52325f81'
# Old sha1sum was: '3384105cde4d44125898816359b5b8e98d5ac3d8'
# New sha1sum is : '266231050a902dd87f08a41d01cc6f3c72a39ee4'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '55168dacb130f92996764eb6d3ee27f4'
# New md5sum is : 'a04bc94755ab19f8556366d1edd9b14b'
# Old sha1sum was: '18fe21c3a95bde8d0e16143c15cc85766306ce62'
# New sha1sum is : '4c1d93de29a21ccd83a347104ffc0e4e91816af1'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '34e2d590a062239e17f374f93ac73fb0'
# New md5sum is : '198ad92ef8c7ce13b0aee180aec19632'
# Old sha1sum was: 'efd0d6629792a6c9931eb3164590be305c3d53fa'
# New sha1sum is : 'b2c7aeb7139f9fb0b98a77979982de351c7ccef9'
#
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '3140bb22768ea07a76c427df3aea2b45'
# New md5sum is : '4cc00ef9ff829469da8aec3a91e1fd91'
# Old sha1sum was: '5ee8e7056652108408ac37bff7ab946163d5b683'
# New sha1sum is : 'b259b23064e25446c3795b1957b0fd360dae2fe8'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '7e6b8cab8ab47b0d8c7a0188cf6a6a8d'
# New md5sum is : 'c999eef55d9b19a3010ed5c1bdacdf77'
# Old sha1sum was: '3b251876c85a005c3f3e06eb1dea6852a7bf89cf'
# New sha1sum is : '38fe34a0edb19ed05d7eccb833329aa167d23775'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '05e974e8cd86889a191d1d7683e912fc'
# New md5sum is : 'f9ec2404b1225acb6fb9b9fea46729f7'
# Old sha1sum was: '51ad772d328e4e1fc96fc7c79dac26296809f088'
# New sha1sum is : 'fd27a53b00057c5943288d6f889ab070c2a49ec9'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '825626fe82285ec1f62112066722a4cb'
# New md5sum is : 'c7535ce53fc8245367cfcdc78c39782c'
# Old sha1sum was: 'bf4828f7c086adf2be95eb9beee66fbba8fabbd7'
# New sha1sum is : '6548a67b172dfafcec95bcd064de0a23d639bfc0'
# Old sha256sum was: 'b1f3e2e91230e97ddfd83810487d2db76193a60f40ba29474cd978c6dca1fd47'
# New sha256sum is : 'e0e3fa2f8c55ba4df4f3f230684d0d4b464a7dff3c938cc1841bf613db1610ed'
# Old modification time was: 'Fri Nov  6 04:00:51 2020', now it is 'Wed Nov 18 04:00:53 2020'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '7572fc67165873a1a7f4da64397c3885'
# New md5sum is : 'fc50af3d63e5891222df700e3601b652'
# Old sha1sum was: 'f1657e7a88c8ca4dfd7f2635e7e4883911e0c0d9'
# New sha1sum is : 'f9d6ff63148cd6de0e09e6f12a378301224403c6'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '8658e8e1b57f4f2738a669e872c731d5'
# New md5sum is : '25f55240c2a413b41b623e4ff52b80f5'
# Old sha1sum was: '41bc764a7bc01db560e3635da572a1bc433f39c6'
# New sha1sum is : 'cd8047bee9fc9d5eb087e96d41cc4b2fdc9b8b60'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '99301dc43c1ca1bbf2300c740a40de1c'
# New md5sum is : 'a783c41db6d0d9d4a01e81e31a3dcd64'
# Old sha1sum was: '69d3701c8508c87f7a2669a2b8ce14d0580cb074'
# New sha1sum is : 'fca9b29c08091c6cad5f9611f3992a0034a0a14b'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '7713818752179528ec44591afb8220a2'
# New md5sum is : '5c88104e8d3b85978b567f457de9ab2c'
# Old sha1sum was: 'e7a79804d8b4e25f94b9e9cdaa68d144d2d5de99'
# New sha1sum is : 'defe89652282f0146377a702ca873117f471038b'
#
#
# File <FILE> checksum changed.
# Old modification time was: 'Mon Nov 16 08:47:37 2020', now it is 'Fri Dec  4 11:18:32 2020'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'be86c0d6df5888ba14e8461aa11aee7d'
# New md5sum is : 'cf903c4d5e58b327aeb3d460c0c317cf'
# Old sha1sum was: 'a041ae4bb7df8dfde27e33085b05fd3193a57168'
# New sha1sum is : '1a6df8c1d65dc9c6076a0d6e910a06405490b39c'
# Old sha256sum was: 'c2ce3480e48ad0ac6db9da11d04d220f24d42500308e7cca5b2356c1e5e47ccd'
# New sha256sum is : 'cde8e796c59ecca2bb54102e95ff32c4bfb8b93756173d50699db473a0ea3719'
# Old modification time was: 'Sun Sep 20 12:47:37 2020', now it is 'Sun Sep 20 20:34:17 2020'
# Old inode was: '403547617', now it is '403557670'
#
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: 'a1df7ed9b5f09be244a92ba792b002cf'
# New md5sum is : '9e1d4e7f23a78157c7e94d660a1ac3dd'
# Old sha1sum was: '1098906e3b6e8052ce5cad65334c118cc299c4ff'
# New sha1sum is : '4a47e8cc91552bc6e5fbb4b3ba0e0ff6876600f8'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'f48717fe3931f8fefe67904ef3ec5316'
# New md5sum is : '4859d522324247f80efb236dd36d57c1'
# Old sha1sum was: '8eaaaf9f714886584357b335f213700e4368b036'
# New sha1sum is : '6cc4867cd45b5a3d4dc2388063acb3af279b5cce'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'f2c712c4e6711cacd1b368d196ef0958'
# New md5sum is : '99301dc43c1ca1bbf2300c740a40de1c'
# Old sha1sum was: 'd89010d5dd911039029068f82f1a7d5a0427fe90'
# New sha1sum is : '69d3701c8508c87f7a2669a2b8ce14d0580cb074'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '238e7b0aff4ae7f98267be8eddf16d8b'
# New md5sum is : 'f0ee49ed949ead5c73eebfe95f22f8a7'
# Old sha1sum was: 'c56a25f11634cf44b78beeb37b330f208b77ee77'
# New sha1sum is : 'f8cc2d317be2ca7bc11c2a7fce999e5962a8eee3'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'dc20fe43e908359f6697b71a7bb4db35'
# New md5sum is : 'cf6708cac3b9a621268bcd335918adfc'
# Old sha1sum was: '3085d4f29870e6696d3c91c010e195b3cf93f946'
# New sha1sum is : 'eb020cfca915923acdd467622794456b11085c0c'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '7f096117ba05a82723032ca61f43f315'
# New md5sum is : '8faf10bd12be7c2ba85ab2fd021d9904'
# Old sha1sum was: 'cf5e1e710831576dda0b4abbb49dd4712b392e79'
# New sha1sum is : 'da0450db9cc3ea6a577ee7e6e54d8518ca77e199'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '25a44cd65896b2f3792adfbf38cb8c4a'
# New md5sum is : 'd039d8934925ca60352ed4bbf7d0c194'
# Old sha1sum was: '4a5078a22f95257953e0815ce5f67298d496faff'
# New sha1sum is : 'ac3e7f22f0d6cc0cbcb952acdb6cc3ffbe6e0acb'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '9e450b9a4b01aadeb3ef2aa1a02aed82'
# New md5sum is : 'ccb747974dc9a836f15c9c6c247b015a'
# Old sha1sum was: 'd603af935e9036401fbe9c1959638b840e36773c'
# New sha1sum is : 'eae513adfd899affab8336e3cb9ebaf87026828b'
# Old sha256sum was: 'bf9a43fafef55060d5b43c1419a826d537ece5b0f5f3c68a7b3481c997a1a28a'
# New sha256sum is : '11c527263ed5d657a73c5e7c6b6f7ce2f0b5da0c43cc9bfb5a2a9d9cd264d27f'
# Old modification time was: 'Wed Nov 18 04:00:54 2020', now it is 'Wed Nov 18 10:42:43 2020'
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'c9c053c3ca7b660480b356a736a1b743'
# New md5sum is : 'c6a6a7ee3f984b75cdb7a2aab2b029b6'
# Old sha1sum was: 'a6b493e7930153654310c3bfcfbe4c1c3fce2c7d'
# New sha1sum is : '8244bc1040d218a97b2179df1bb5c614dbceb504'
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'd6f8ab619284fbe9e6d6d51d9697ef0e'
# New md5sum is : '4483cdf49a611d6b0821637ffec97ff0'
# Old sha1sum was: 'aa82755ea551910008b712f528d33e69eb341023'
# New sha1sum is : '364b14e56976c77a31110e8bd2c394b364a68b80'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '21936477c75fb299f78b3832bea95f7a'
# New md5sum is : '9cd05cbf701048ce263c2c7460147edb'
# Old sha1sum was: 'ecfb6310f7c17f1dd6575affb22c272732f5bb85'
# New sha1sum is : 'c1a7dc368507e750db4bc157f2af2af18e7860fe'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '9ee29b54980bbd5e2e5c952217f91a79'
# New md5sum is : '3d0dda318c9943b532d9b01705b51c53'
# Old sha1sum was: '41f8bea77ea36fffe5d8ec5cba99beceef648893'
# New sha1sum is : 'bec46e950f9f9aa87d73101473e0e3ea0f46c0e8'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '2807d886921e73588b1908fb43ea3cdf'
# New md5sum is : '9b567f5a85688732066d54118229d954'
# Old sha1sum was: '09e22fa7655142d9c70514d617a922750e0f405b'
# New sha1sum is : '8652b04fef1d604e954ea6ff813026265ea7af10'
#
#
# File <FILE> checksum changed.
# Old modification time was: 'Thu Oct 15 10:06:44 2020', now it is 'Fri Oct 16 14:39:12 2020'
#
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '9422c3af6b896736a444ddef062db478'
# New md5sum is : 'd59c1d8391a88388f825fe768513c175'
# Old sha1sum was: '4ff01d6699d61dc85db9370f1245634181bb2bd7'
# New sha1sum is : '3e87dd1852c477e8c89f36e7956c489f7a8a6f7f'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'ddb1029e9ff31caa64f55c24cf320bf8'
# New md5sum is : 'd5965778e5cd0e0c371e1eda9f168c08'
# Old sha1sum was: 'ea721949ee9eb6a595fa4ef9dd2435db8d98e0f8'
# New sha1sum is : '38c6be0299b1898962e2f9fbe08f083dce2f3109'
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '994febdff062ecb3513c43ad29eff989'
# New md5sum is : '8d687838e4f9322936369a334d181dfe'
# Old sha1sum was: '8dadf2ba5718ad37e5c02748fccde0400b274e68'
# New sha1sum is : '02ba1823e7ffb973fe94e5a2084fb808febd7c53'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: 'e20342d4ff67c5c6813a5b0d2de1812e'
# New md5sum is : '9dafd25234df4ccb057cd5a3e7929f25'
# Old sha1sum was: 'bca9084fa6a8a9389361ba717e800decbade9429'
# New sha1sum is : '2359cbc7256fad3a2dc1a8f11a6f72eabd53e558'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '0a68fa8d53a3bb47c79c42db6df73795'
# New md5sum is : '8c41ee60cfec7ae9635bf034b7e70673'
# Old sha1sum was: 'd5dca206e3fb80049227c7c1a2b2e2e4c7babdc8'
# New sha1sum is : '249d11c767ed621f3ab1146b32499a1d07ba0516'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'cdd48d377b5eee53a1ee5df940ae7dd7'
# New md5sum is : '59b81288fc6db620a91635df5e04afd7'
# Old sha1sum was: 'd1f2e1b8d48588195da3b5c131be251f01415eb5'
# New sha1sum is : '8b046a4e2cb95bb599d55eb2ea6a2c7b9e9f6223'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '70ded6c9036c338ce01740e26f5e46ed'
# New md5sum is : '9435b0ddc47a3b9df91545deb5fc69f5'
# Old sha1sum was: '77fee735fdc8688689683a14835c305697de322b'
# New sha1sum is : '83758eb8789725ce6231335cde27942d97a12061'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'e18b3c5a44eaaafcad4fe00ee2ca00e4'
# New md5sum is : 'a91a08787e0b374e99bd29a1ffb501ae'
# Old sha1sum was: 'af33088ed9ce59cb5490f3840fd1661cae658331'
# New sha1sum is : '1106db6e33fc8c4b5c8123e560db4eb2f56b0f17'
# Old sha256sum was: 'b0f0e680ae85336475aa9cc0b7307ae409d99e4492b38f0bfbb0e3c6e35fa70b'
# New sha256sum is : 'e0725c6c6b011e2942981968f5e21414132b0b8c619211492c8ccba7cf36c04d'
# Old modification time was: 'Sun Nov 22 15:35:40 2020', now it is 'Mon Nov 23 12:25:41 2020'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '5a14ed4b5d8e3619523e4bb5b69e2ed1'
# New md5sum is : '930790c0c3932d9ea63a4574ec2fd56c'
# Old sha1sum was: '6f817599762bdce3be510c22500f0f6ab713ac58'
# New sha1sum is : 'a2a0bddb4e0b153063a7b97da1b10b02aaab5708'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: 'ae1365c3244ed29fd7017ab43ba4164e'
# New md5sum is : 'b2fd3b8850555db7c7076977eced3303'
# Old sha1sum was: '2e4c1f16ea31c0c3a0bc2d1ad3cbde6c4a8ba177'
# New sha1sum is : 'b4ec8475a2b6c3e0f74e9bd4597b1988b02fe08c'
# Old sha256sum was: '2e822df0a5e5ca9e6b6a8ec74a6ae85863d871b5c2eeac333b4c4546c5afecbb'
# New sha256sum is : 'e0fd60fa9bc82001e5812ee403d70cad549154abe3d8f3fb2d38d253d4bcdf18'
# Old modification time was: 'Sat Jun 27 15:20:53 2020', now it is 'Wed Nov 18 10:50:03 2020'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '99a42ecca4dca1aacf73074d9b69d7c4'
# New md5sum is : 'b6f73cfc4e464c3527f67bd39c5028ad'
# Old sha1sum was: '97cc00fe36a1ef46141d7dd1cc931ea79099f01b'
# New sha1sum is : 'fb1e3b3901f35f63231232efc06b379c6d4452cf'
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '502a7c5f69e21f20845b56ce0605f447'
# New md5sum is : '9a3588c0ec773afbc69a3d58cee57bd5'
# Old sha1sum was: 'fab10a8a643bb0e5698daadaaa507feb058c8da2'
# New sha1sum is : 'e6778d328808cb945e4d32d958bd6a3c182434a3'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'cb3408a32861b1080ad09a255e0d1a3b'
# New md5sum is : 'f5a79d2bdbb80de4dfd0a0c5206be0a6'
# Old sha1sum was: '4b75c52fe2fb692f898e52be9545a1e32d659a4c'
# New sha1sum is : '2f6d3ba064e59fb174af9a49992ad44b425fb253'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '61fabb70b46c3f848bfb33409edc9d88'
# New md5sum is : '99c8e4d89b7d116286101885e783f806'
# Old sha1sum was: 'a82c0ac16a33e1035f36a249c173208484d53ba1'
# New sha1sum is : '32a3f98f991e952a64d724c93efd9dd98c9f6d29'
#
#
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: 'af68551f9ba4df4beccd3d865a4fae57'
# New md5sum is : '17dc239c56ec2ba693798b7ff4b1c99c'
# Old sha1sum was: 'c1b9d988b35280a6cfd8496706e7ddb37dc1dedb'
# New sha1sum is : 'd8e563b0ac3e1b7c267ede5cace007049e772d51'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'ea2a750a2c0be7d4bc638cb090ea245f'
# New md5sum is : '65966ff89fca047ca8a2d4fa40a23775'
# Old sha1sum was: '820b76124cb537d973af9eb48255793bf2d9a671'
# New sha1sum is : 'fe305a13299e4f9414c51e2f614b135be6d79515'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '7a970982bd78b4da3b322c8f95a867f4'
# New md5sum is : 'bbb6b4634428d4f89be9bbca8a60659a'
# Old sha1sum was: '3bf98e2e2929ca63bcd6d960c5badacde1b31ee6'
# New sha1sum is : 'd96331c81f42abb1d911675f0db24719341e406a'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '7803cb3c1d9999b32e88957455c087db'
# New md5sum is : '9a63fe7870b783ff53dfb37f0db071a5'
# Old sha1sum was: '4c3b947bceffe5179a7a9e3d3ee886632f509046'
# New sha1sum is : '76d3d4a99f08b0aa2d4039ff678ee6d3a219206e'
# Old sha256sum was: 'c93d3fadc58995d5b4cb1f9df095a5207cf12fbc3003f486d5abde9322624563'
# New sha256sum is : 'a1405b3d7df8b0a6fae14be7eb03fcc19044c2ffc94b6e5180961c82832a6a89'
# Old modification time was: 'Thu Sep 24 21:47:37 2020', now it is 'Fri Sep 25 09:27:36 2020'
# Old inode was: '406071289', now it is '403108476'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '29f966f85adbd0acbc12afa7fb5452a9'
# New md5sum is : '0ea4550dd2debf0c12e271cbef949f45'
# Old sha1sum was: 'a7c8eb31ac96d7889d0c99ae1249c6d014e29367'
# New sha1sum is : '26014de5c23f5ed5cd04d5c0ec5dd8689bbf9268'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'aec0389dfe7c784efcb172edca77930d'
# New md5sum is : '1baa75ccdb7f103f80ae23ef09e3d65b'
# Old sha1sum was: '61b7275d6817fa25d77d6b9112dcefbb6c6f5822'
# New sha1sum is : 'bf91e89995348e0da6a98955dcbbfa7b36804d63'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: 'ceff86e0c856d18467c7c8e187fd243a'
# New md5sum is : '0e4db262d4d192c1362f41a815c1d4d5'
# Old sha1sum was: 'c575c8e947ecb0f6b05859d75a8b08afbf990190'
# New sha1sum is : '6953b62a58c843a6abc7987466602c4bd92a551b'
# Old sha256sum was: 'ab26883b7d963cecd77bee361cb34c495ad2423968beabce86f54a5960c794f6'
# New sha256sum is : '77a5bd29ccf29839a8677928908d7636d1c0e95825f5e132666e8e299e713ed3'
# Old modification time was: 'Wed Nov 18 04:00:54 2020', now it is 'Wed Nov 18 10:42:43 2020'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '9ac7703d66ecfbdd6f2b571fe7e012fd'
# New md5sum is : '9b2bf14c57c16c4054cb8b2a2ac10818'
# Old sha1sum was: '01b26cb2c59657628562191c9d06d67da482d64b'
# New sha1sum is : 'ab0067e90fcc12d91e995bc62e4130185d4e7a3d'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '09cdfcb273291e5228e5e678160a769a'
# New md5sum is : 'f178df2005d464815ef6cfffcc1ef649'
# Old sha1sum was: '97dcdf1e7608215ae36910e113204753b45bad87'
# New sha1sum is : '23d77499e794c67ea602d33906c1f49100c04a84'
# Old sha256sum was: 'e85668951a91df4f819b4d1188b68b321fcfbd724f474c0142a41e82a5661fcc'
# New sha256sum is : 'd34bc4e8dc444be21823ac7b6d4a2d39a8c36f9d21503183e05e97ba244cd643'
# Old modification time was: 'Wed Nov 18 04:00:54 2020', now it is 'Wed Nov 18 10:42:43 2020'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'a4bf630a194fe4d1f46a65bd1c163a19'
# New md5sum is : '3735284158ba06235c3d0ef02c1c3cd7'
# Old sha1sum was: '74220aa69ea0ab758364a9d9b6ef42afe74f2d41'
# New sha1sum is : '371eb8a1e1d886ba843abb2e734535671697f8a0'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'e73d8990c900418fae47fee4d06fcfc6'
# New md5sum is : 'b45bb60bccfd5cc3fcc7a72843fda043'
# Old sha1sum was: '2416842442e4d7895433f4b356786fa2d7ffd287'
# New sha1sum is : '908c955c2b84a62281eec0495ef41b3eec0aa953'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'b98d05e8b54e4c78c591c4849cec4ea0'
# New md5sum is : '39a8ee5722d096c48d2cc1277380efd3'
# Old sha1sum was: 'c9b928cc403fe9931074cf003ae2b2ce0cca9088'
# New sha1sum is : 'f4e2f0ca2c89cd2e6869a14ec63274983cc08170'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '4066dcc61967d197ad263e16e5e6da08'
# New md5sum is : 'f449402c110936900d1738b495dd14a9'
# Old sha1sum was: 'befd386bfbdc15dd618e3c67d5e9c27092696a8f'
# New sha1sum is : '564b376be1c0b1c8a7e58c180983aa68471a9679'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '8d74c60d01bf17090606ee90aa944176'
# New md5sum is : 'c1957333fdc1a43e2d9766c7ea28f791'
# Old sha1sum was: '3bca0dbb292bcb71519085236b699c90f945a769'
# New sha1sum is : '77a76e959d5d0a4fcca44c86c2e4f21234f19498'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '2d6d1fa1393f22558197e42d3b0cd793'
# New md5sum is : '019f2cb5a181ad4224d720c3ced62e85'
# Old sha1sum was: '40ec012d5d6b3694c10b4404bf37874335d484fd'
# New sha1sum is : 'b9e743c9f0e073388be78cc3620b30fb90ed2a1b'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'bda3d9b719f0ba25ac453e79164136ae'
# New md5sum is : '0563659f6b27d3f6b548ed9662cdcb8a'
# Old sha1sum was: '22d23ea789fc63735d069b3d8ec3534ac708675e'
# New sha1sum is : '4ad354b66d299011f43c7fb21720483236687264'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '101bc254df0f4deae9654ab140c31388'
# New md5sum is : 'd9484014a54a8e4dae933eeb93574d21'
# Old sha1sum was: '56143bc627ec872ed8f50158ec670b44a216d86e'
# New sha1sum is : '20ba12b5344ba04e2da049a81649578c9b70ad69'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '45400747eb5d752a0e58f37c8f4a35a2'
# New md5sum is : 'a56023711757eeda857e5efb01fe7f4a'
# Old sha1sum was: '88e540f6b940619bd7e5238b24b43133c7bf1369'
# New sha1sum is : '03f03fb0ac3f1241cef0bbe78b16e5c01cd8507e'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'd5006596fe396bfa383170bcbbeb448c'
# New md5sum is : 'bc92b01d04695a8e09d93ac5e2e68fa5'
# Old sha1sum was: 'd87b9b28f60c46c7e75174aed21c5faea27b159d'
# New sha1sum is : '58ece081fa74eb64c02c52b866379c59162dea74'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old inode was: '151', now it is '154'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: 'e409f513f4d7885f68f7eb3e5d17374b'
# New md5sum is : '6acd92198655fcbc24893f58deb82469'
# Old sha1sum was: 'ccf3b56956be5a1cdca26c296a56f2c499f10e79'
# New sha1sum is : '698770cff34aa9b1aed0cab49bdb02a03a5a6c55'
# Old sha256sum was: '833290a9d47527cabc5dd5fd98cc5de8029f93ca82cfc7664d95a3503eddd124'
# New sha256sum is : '3ff4cba9ab1d14c068387492641b2428b3ed6a070f3d9f73bfaf8fc08af97405'
# Old modification time was: 'Tue Nov 17 14:12:43 2020', now it is 'Wed Nov 18 10:34:27 2020'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old modification time was: 'Mon Nov 16 04:00:52 2020', now it is 'Tue Nov 17 04:00:52 2020'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old modification time was: 'Mon Nov 16 08:47:33 2020', now it is 'Fri Dec  4 11:18:28 2020'
# Old inode was: '271931298', now it is '269003749'
#
#
# File <FILE> checksum changed.
# Old inode was: '152', now it is '218'
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'dba0d88b9759881bc6c20d6fe684988d'
# New md5sum is : '623c55f2b4f1bac36416c676e6f1a8f8'
# Old sha1sum was: '15b09b7703716d81f435ba14ae1d62e029fd4b47'
# New sha1sum is : '4de3932c96ea4d22d1e0609945354f11e4dda8d5'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'dfdc8723b7d1a77deff762bd948b006f'
# New md5sum is : '4152faf14d2ada5e463cb1939a224646'
# Old sha1sum was: '1d87fac69635fd9245599f68da66bb2d3576b593'
# New sha1sum is : '3d69c0d0870051befd5d63b95d6ea7df0a66c5fb'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: 'c73c7b971755fbc048d80449f84740c6'
# New md5sum is : 'fc285a0d345acffc917c2c4555d698b6'
# Old sha1sum was: '3c504345c4179ecb7bc3b8e60eb525e65c970cec'
# New sha1sum is : 'cc2994fb6540abcd2756fd69c885b1962ad0a7d3'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old modification time was: 'Thu Nov 19 05:00:48 2020', now it is 'Fri Nov 20 05:00:48 2020'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'c24177054d18bd9ab3cd160def3be046'
# New md5sum is : '85a5304938a42e999c365ab71acc75cc'
# Old sha1sum was: '89c1f46b7bfa218e04c14679023967b6c47ed001'
# New sha1sum is : 'b7b6c287d3275e3771daacc5698338a3ef860ace'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: 'da9ad6dbd20c3888bd77f88fc3be1e7c'
# New md5sum is : '7947e5b33edfdd3e3476721c03d9b8dc'
# Old sha1sum was: 'be222791eccc5cb8f35e64afdbf8da217d5393b1'
# New sha1sum is : '5b5782846e997aa20838758fc8b6d44b5d16686f'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'f09a7e2f5263108d197f9a781409ac8d'
# New md5sum is : 'db96f7690966326739f6ba5ce00b629c'
# Old sha1sum was: 'f6c4b8e9cfce230386229a573f2ce19f90c5036d'
# New sha1sum is : 'f9306d9378b9c59252b0ea76a5563fee0c614c04'
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '8faf10bd12be7c2ba85ab2fd021d9904'
# New md5sum is : '17d5df55c9ca691880767740aa732ce2'
# Old sha1sum was: 'da0450db9cc3ea6a577ee7e6e54d8518ca77e199'
# New sha1sum is : 'edf5f14cc7c36411c0a6be9fb469571c6615d811'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'f97075d5875b6c544887744a09c4057a'
# New md5sum is : '536f30f8d43bd05480310f84a1bfa11a'
# Old sha1sum was: 'e9f522ae48f44aef96d86a195e7a2d4ac0903704'
# New sha1sum is : 'e91c97ea527e47804043eb2ef4d10aa09d047418'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: 'c0d396370350df7b4f089c3a2669d67b'
# New md5sum is : 'f83b37b9b3b1bc6b454a14c00509a941'
# Old sha1sum was: '1d6b0e68d458a46e31bb114c22a8ccc984a45cee'
# New sha1sum is : '3a4b37b259101a84cf4eaa2d07947d24f9356ef4'
# Old sha256sum was: '518338880d9987affa3ce44cae5087cc41b7353601a295be44dfb92bfc802e10'
# New sha256sum is : '05f02edf18bb228f604451a81afe2d01f50dc24075e97c384eade8743e454ab5'
# Old modification time was: 'Fri Sep 25 10:25:57 2020', now it is 'Fri Sep 25 23:04:17 2020'
# Old inode was: '403108481', now it is '406051394'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '364c571366dac9a33acb6c0064267aa0'
# New md5sum is : '5a28af08eaac7d510d3c45bcb3a4a722'
# Old sha1sum was: '1814fe17dc3532bc0755a6099fdbcae464f6672c'
# New sha1sum is : '37ef5061cfd701dbfa7097ca0d51a41194226025'
#
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Permissions changed from 'rw-r--r--' to 'rwxr-xr-x'
# Group ownership was 'root (0)', now it is 'logstash (978)'
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'eb0d3138f283f46865077e7e559ee59a'
# New md5sum is : '961a21dc5a42130e4458ebc20ce08209'
# Old sha1sum was: '74c620f6fce7d775345e11b7f3548cd6dd4c6710'
# New sha1sum is : 'd2ea1228a83c17f65264b1b2860b0a7104c866f1'
#
#
# File <FILE> checksum changed.
# Old modification time was: 'Mon Nov 16 13:01:54 2020', now it is 'Thu Nov 19 08:55:28 2020'
# Old inode was: '143473', now it is '163938'
#
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '28c4e003352efb125e2f202be6e49bfa'
# New md5sum is : '914adfaa3efec472ab8a4f3c79e2d535'
# Old sha1sum was: 'a6038a114b0f6b06da7fa8743e37881ecf0bafb0'
# New sha1sum is : 'd6269f810ec6061e018f8a04a7fca0120863883b'
#
#
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: 'b162b0befc0da3b9bf7ae71dab35b52a'
# New md5sum is : '79b315eaf5a96ae32a05bb395a6207d2'
# Old sha1sum was: 'a706dccf74936339611b6eaa91bd1c3eb25af90f'
# New sha1sum is : '1c81d7c87c2dfc670db29ff84801125325aa43c2'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '9f2d5b314a0fba71082a5064f13fcd1c'
# New md5sum is : '42615923050dd91494be7340769928d2'
# Old sha1sum was: 'b92c3a6a6afaa369d65979799f2d381064d1a8a9'
# New sha1sum is : 'f830b34dde08883187c6a6eed26fd54823348605'
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '2fd11d94b712b602548a66074f03fa81'
# New md5sum is : 'a15a544b64940ee554f56ce22e80e51f'
# Old sha1sum was: 'bc5a9fec0a8ded10ed5ad7e47f18923943b7b184'
# New sha1sum is : '2ee8578956fa562f453258b3dca2c15caa33a343'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'aa5a3a5c531e114e94eab215febd7b3d'
# New md5sum is : 'e23f0b23e53497db1c310125c83dd1f0'
# Old sha1sum was: 'a57ac0f4b5bd7ab022095a2d4d68036db84dcbf1'
# New sha1sum is : '57c1595499c5f2dbd5f03de96fb1a93af35cd2bc'
#
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'a1cebaf52df8023817e311628ad3477b'
# New md5sum is : '1ec345cdd1ce26d2d6fc2609a6f2856e'
# Old sha1sum was: '467b194f5b3acd9fe1f46e64f0c0a71b8096d5d4'
# New sha1sum is : 'd14e3aebee4a161a1b3d01456cced8d16f9ad27b'
#
#
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '959891e4d0ecab54d3943a57b582965d'
# New md5sum is : '04a56246de5c5406d3b96bbbd054d1ef'
# Old sha1sum was: 'f23e4aeb2e5fdf7e3540d922c48082bafe70b56f'
# New sha1sum is : '87f8c4388c12069969d917ae18e77a1bfd04aa99'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'cdc3f9acaf28e4c105c69f579ee6da59'
# New md5sum is : '10ec60bebb6ad7730edbfd3127dffaae'
# Old sha1sum was: '1b85e6cc4d6791c54f8269afe314c0f190ddf71c'
# New sha1sum is : 'af9b2d7cd27922ab7330e5a017d0190539b90208'
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '6f953317f3102ccbf5240356b924d140'
# New md5sum is : 'ab4435fb1641efdf289dce1fff0d9bb5'
# Old sha1sum was: 'd81251583f6c961429322abee16945d62c886405'
# New sha1sum is : '8edd97e42ea53a82f84592b1ea752bc3d3698777'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: 'fabb87094108a26e0de67b2b85765903'
# New md5sum is : 'b12a5f2b7d04bad5dc989375fb002e0c'
# Old sha1sum was: 'a0332b3cc6cb1108e1577b4a1bc7d31d440484cd'
# New sha1sum is : '20e564facef5ee42325049f976f035c43ebd0247'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '779ad9e81573218c15f475dd143e7263'
# New md5sum is : '1fd0dc10ef50bbf663fb64c15e747561'
# Old sha1sum was: '79d8b3c56a3956ba47a5f2065b955c031a7ecde3'
# New sha1sum is : 'f27bd8e798c9ac36d085e24f7cdc5c17745ced30'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: 'e0aa9c448849a0f1d050d1fa2d3ec17f'
# New md5sum is : '2c68d66a0a6f7560f4320ec5b9ce4691'
# Old sha1sum was: '16886fa9bd08fdbecb2bc1ad54bac7d545ccf927'
# New sha1sum is : 'f3aff7bfa9aff0cdaf47a3597e083c9ce1720a59'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'e19ab55d7694529e60d9eaed218aeafb'
# New md5sum is : '65ac5a5ca20ee4235dcd493da7e12f45'
# Old sha1sum was: 'c3f1a2fcce57be9d6a4fbfc1ddf2405968c5d76a'
# New sha1sum is : 'f49b6fa178df984f8bccd0b51bdff42b58348223'
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'b7b0d4efc47d5d12fee8eb836e491bb8'
# New md5sum is : 'ff229111bf616431bde595a3b965862b'
# Old sha1sum was: '756ca44dfbf79d72e9376bf7fc3aee06d70834f4'
# New sha1sum is : '2c3c475b9ed4a458c191977661acfb288735b3a6'
# Old sha256sum was: '6aea7f27dcb1b18208f110ed54bec0d148a4d10790ce16701a298b658270b240'
# New sha256sum is : '89d323c46c3bff0d6d86d6b60d0e3d44a61b6795bf434a0473a5517c7f6d9892'
# Old modification time was: 'Wed Nov 18 04:00:53 2020', now it is 'Wed Nov 18 10:42:41 2020'
#
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '1573f1ed8785f3bf0a61040cd8669399'
# New md5sum is : 'e1b2ddf18adc78cc34449820d343580b'
# Old sha1sum was: 'c1718e9f542741793e86d5ef9206a749cb284e92'
# New sha1sum is : '0bc19ee35b284c6ebbbfb2bec565b4270579ccc9'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '750262af7d3c088d08cb188294db1749'
# New md5sum is : '1ec06016c9ac44cb9bababe5060b94c1'
# Old sha1sum was: 'de3b143ca95866faadd7ee51cdda1b8f20b03ae8'
# New sha1sum is : '40b59da24c7925f3f88a7ab2496972efd81f22c0'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '59d55bad8c2aa50a749541e46c999c38'
# New md5sum is : '18721a8c9baa235ea4b17082c35d1380'
# Old sha1sum was: '748abc1cb80bdcfb75d6cbe0fc6a9d9c1e5a34a7'
# New sha1sum is : '877b8fb593c7fd8debacabb15f642c2b16e97556'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'd737b36ddf6de9e3690dde8bf8af6f01'
# New md5sum is : '4cbe1b8a91b6ed4ab531db994c3a0d4b'
# Old sha1sum was: 'd983e0d116b8476f17efd5649b3c4074558559d7'
# New sha1sum is : 'f69c76579f5c285151ef1c3468b3c82e370655dd'
# Old sha256sum was: '5350ac321a1a7929b2667a19ed068d0644a7bb0dfe6e72a5cd69a94b5b4bd666'
# New sha256sum is : 'b55469d852eade80e55e574b7f4d782174b945696b4a903e472ec95c0204b2b9'
# Old modification time was: 'Wed Nov 18 04:00:54 2020', now it is 'Wed Nov 18 10:42:42 2020'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: 'be79bb698706fa620c85bd73781c602c'
# New md5sum is : '8afdd24d8d1e8a5a58657bd499dcf883'
# Old sha1sum was: '1f059d63d593e7e900aed5a7c10ef9dba7f23470'
# New sha1sum is : '90d4e8567aef34bcd940e7e210c284fd53863259'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '43d5b7b497ef5052a68771b6c1528732'
# New md5sum is : 'd333e5675cccfc34ad4da2e8e7bca0e4'
# Old sha1sum was: '69ed91fca05e2b55a58c5a85f00e95dac5499b23'
# New sha1sum is : '393674df55c53edb1d1c140a0de172eb78cf4ad9'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '112d9dde20722d6d5be3268dfd4bfa91'
# New md5sum is : 'f734affca0f23b876afe3017619f1b20'
# Old sha1sum was: '4f3e1ef01352bd532428b3532dc75f9282f39cfc'
# New sha1sum is : '51a3f85d7861449c6668d3ac2b6749f25c02c342'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '06dbf5ce0adfca27f74fd453e070a5c7'
# New md5sum is : '682584b88a974ddc7798a2cdc16ee000'
# Old sha1sum was: 'e984d5bf4f732f4b1482d569a75d8de70bbd8145'
# New sha1sum is : '502240198420a24b501bcb0944f72b40c6f4430d'
# Old sha256sum was: '8974a9eb3a04c671889a80fb719ad1a6f5fe27ca12cf8bff536f1aa2787c5455'
# New sha256sum is : 'c717ab9ad0accea69b8d734ae8a75532d70ff5e1f843574af6af38c8a91f3a31'
# Old modification time was: 'Mon Nov 16 00:00:13 2020', now it is 'Tue Nov 17 00:00:29 2020'
#
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '91900565c6f456dd456a895dab88ac17'
# New md5sum is : '29cea6a369dbcdf50abb461efab87d50'
# Old sha1sum was: '9b698370f2977b8ee27c9c25ece9c86b5a8c9287'
# New sha1sum is : '055701694b93b98d47baf0ce583f06cde7a6eb9d'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: 'f7b182d651e5064772e483cb5a69ad0a'
# New md5sum is : 'cb95a78b716c32ee2a00fb0c14b7454e'
# Old sha1sum was: '2ee8f01ade0526a8243dec7e6d6f494eb41be86c'
# New sha1sum is : '804c1fd59907351f0f10f0e1fb38142b4bf3b92b'
# Old sha256sum was: '1d21751cf8f1a1ed429b44179f60533eb6554e40e083e1f1265f0d5b88fe6507'
# New sha256sum is : '621e5a1e982d2d884537cf954a72106287dd8f999209a1d7b64bc7b04f725e4f'
# Old modification time was: 'Wed Nov 18 10:42:41 2020', now it is 'Thu Nov 19 05:00:48 2020'
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '0d61a39817fe5f0dbb35ec80bd8ab3ba'
# New md5sum is : '75c43f837ff9412f52cd4ac3fb470773'
# Old sha1sum was: 'f1f516fdb3bb291288c30fd6afbcc4dea05099f3'
# New sha1sum is : '7dba661ea158b381bc20078b6cf380ce8085abb9'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '3b407f5a7390ab4b44ddfe777b1c3f81'
# New md5sum is : '706e86cb5b80d2119ef9559c02195977'
# Old sha1sum was: 'b310484c70a3b6d13f6115dda45c16b1dc81eba2'
# New sha1sum is : '7542810084efc5f53a7899904f96a48c30e6c1fe'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'd5584774f921d44d617406841036fc78'
# New md5sum is : '956aee3e05cdd3cb087bdd463086e7bc'
# Old sha1sum was: '14ad4da4aa4028b9156a37725275b1b2d8b44e77'
# New sha1sum is : '5e5b36b1f1156cee30e2e474fd060ea03e4a0c7d'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '0373e8f5f3390355ef3feb572f5068a9'
# New md5sum is : '3a0ca8abff99652b561d8517ea24ad78'
# Old sha1sum was: 'ff719b84c5960b8e07310a6862da9da67d526880'
# New sha1sum is : '8d1ac075d65e6feae13461ac884afc6ca3a34a4e'
#
#
# File <FILE> checksum changed.
# Old inode was: '140', now it is '208'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '506f176acc0ca7c92ae1b099a96d542c'
# New md5sum is : '21aa2cbe0cde1d1fff558835560673bd'
# Old sha1sum was: 'cc439479704f1fa03f1ed76b1d64ef3926e4a1e8'
# New sha1sum is : '5aadc1b0b5fedbad4bfa41adb5a9223bad75b05d'
# Old sha256sum was: 'f1251f2366cfbd56cadd9db24a8ed74452f5d069973756549ce82271f14dd5c4'
# New sha256sum is : 'ab7585441fa006034a41d641379d3bbb028853505bfb031db86e552af1e30751'
# Old modification time was: 'Wed Nov 18 04:00:53 2020', now it is 'Wed Nov 18 10:42:41 2020'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '0beffd3573d9215ff89721e736069ded'
# New md5sum is : '4f027bbbbee392d5929a76c027623597'
# Old sha1sum was: '6cd16ec062716626d59e5cd2d8c9e38455c4dc9d'
# New sha1sum is : '9cddde96a74ce739b9724ff7243638ce79f10f50'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '30417969f643e29e7c6b766f1b860b6a'
# New md5sum is : 'e75471d827596d79cf60a2bba71d3fc9'
# Old sha1sum was: 'e05828b5ec0bd4c4a39631f5e52efecc21ff7f23'
# New sha1sum is : '38b20c5d8db9cc16f6275ecb260e53a94dbf98cf'
# Old sha256sum was: 'a6a0b4eeeb1d8262200d6194f15c6b674f797dd6347c5d1d2b4e7f66a1d517be'
# New sha256sum is : '1a4d0a67955bf237521c2c26c0bd4e900873c9da2c08888e7a057b519d245df9'
# Old modification time was: 'Tue Nov 24 09:15:41 2020', now it is 'Wed Nov 25 06:05:41 2020'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'a191a8fff34fd3c3b87cdbb000db9013'
# New md5sum is : 'd61646e6bc1c6ee8c1e9f570af5177b9'
# Old sha1sum was: '72ed7c7b0eeda4c2e06277b60adb2fd4e03e1b04'
# New sha1sum is : 'ae37bcf786ba7fa07858cfd97aec43117c6339e6'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '826d5f9dd64c4ef6e8ea0ab96e032d0a'
# New md5sum is : '5dfc15e499916ee3bbad1ae483b799b2'
# Old sha1sum was: '1b050776922570bff17f94ed542a9c83cac36ea2'
# New sha1sum is : 'e74b29b9aac0af38b6e8f2a17716eb60b9576bff'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '34072c579465c66426d8c979e61b01ca'
# New md5sum is : '35af7f26feb706026dcff38176937978'
# Old sha1sum was: 'caf7c7ef1e2a73a54c56d35c85b5e7c2e2920831'
# New sha1sum is : 'a9e7b44de793bc6226066e84a729961dddaa8246'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '101b6128a685e32974a62c63f7239dc2'
# New md5sum is : 'd1711f6232808646c09b501603291f55'
# Old sha1sum was: '81983f9554df2be780f6bd6b2a33b97d87a99c9b'
# New sha1sum is : '3faff2d8423e39afcd0a2a76940e8828b4f58f9e'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '4a384be895a45b66835ed8c44838df7b'
# New md5sum is : 'e8885e381f3403da0181c714d4ad7720'
# Old sha1sum was: '1fbfe5d732375428d56a18e8b0a7ba1f1384d441'
# ...
# New md5sum is : 'bd93255b08c0bd6fea6a3eca3b64207a'
# Old sha1sum was: 'b84a1d027b2adf406d2154d5806ba80c9937049b'
# New sha1sum is : 'dcb2497a02f785bab34f9e498dd87977153f2c7e'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'b9a6255cb0bee368b36cb351419a71a3'
# New md5sum is : '018bbc27d6d7293d672e793d57ab6198'
# Old sha1sum was: '4907ea55bbb74d392a46d242823f8a14ac996237'
# New sha1sum is : 'e9ea9f74e59256bd3b64600b8bd2cd4050eae21a'
#
#
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '6d1131e013d07054ba83adfe708469e0'
# New md5sum is : '8504244a540577deec33e4e2deca1567'
# Old sha1sum was: 'b343c58f0832653951df5b93a7a4b2233d4aeeb8'
# New sha1sum is : 'd16903689c25b0592be0e4644eb0c127b9e5c387'
#
#
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old modification time was: 'Sat Jun 27 15:20:34 2020', now it is 'Wed Nov 18 10:49:44 2020'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'ba04c01a6ca9a7283ce9c8fc6cc725b7'
# New md5sum is : '8ac987a74a7001861aae8201c39c18b9'
# Old sha1sum was: '32477cd2528e54e9ff976ae92cb12271349f633b'
# New sha1sum is : '54fae8d413a6f1bd7184579e65bd8a124187adbd'
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '7e62985d64f737354c7fad9746f17c46'
# New md5sum is : '65eb03ae9c10e265ff0aafc39247945e'
# Old sha1sum was: '6997ff787e41bc8005350a178b7e8efc6e6e9fe1'
# New sha1sum is : 'd9d411583777ae1d152181569f3b3e0d59320861'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'ac25f4b5f184a699b422a8acdb0e2c00'
# New md5sum is : 'a5905ecb36275ec25f5b07c5b6a2e8cb'
# Old sha1sum was: 'bc8028f57f1ef3f29559627d7fcd084f47e0e25f'
# New sha1sum is : 'bc4f4ae8fe5020d0215b008a70b25e50cdd3c1b4'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '9bc4ad0911afb13de84e2dfaa4fa7abb'
# New md5sum is : 'b81abd5b7dadf92cbacab913bc0697f4'
# Old sha1sum was: 'd005c6d8559886db6178af36e0c24d2dec9aadb6'
# New sha1sum is : '2b3fe6c5bb7c29b0911790b903af92297387c587'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'a75c2392b56de2d9333ad39ff0a8da3b'
# New md5sum is : 'e18b3c5a44eaaafcad4fe00ee2ca00e4'
# Old sha1sum was: 'b381206e6f9e8bc497e5312e0496f05d78fc1c37'
# New sha1sum is : 'af33088ed9ce59cb5490f3840fd1661cae658331'
# Old sha256sum was: 'dc11ced0df538c1f2185210c295dc3291e5add27db669180c95d152020a1774c'
# New sha256sum is : 'b0f0e680ae85336475aa9cc0b7307ae409d99e4492b38f0bfbb0e3c6e35fa70b'
# Old modification time was: 'Sat Nov 21 18:45:40 2020', now it is 'Sun Nov 22 15:35:40 2020'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'b7b78c2c0f16987d22b98f70dcbc6f10'
# New md5sum is : '5e6b2fa722e9eab8718ad228bc8b4901'
# Old sha1sum was: '98f68426a07fa15e3ffb705f1e57e3885d6ef7cc'
# New sha1sum is : '204b7f974312388f44b315373600ffb032b7ae33'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '59b9b62f32e02e1458c8c048a14ba2db'
# New md5sum is : 'b3641f1af170e6e1545c5929b106f545'
# Old sha1sum was: 'b0568af5c97f4f9f312f89381e3275618697e53f'
# New sha1sum is : 'b62ea54b16c4f1cfa08880579b3d6f0f8df042dd'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '6b43b97dbb8a3cd1c3800d723beb40b5'
# New md5sum is : '845929e56db72b29e7ba4df795ed25fa'
# Old sha1sum was: '5c5f49f0123c3b7ec81be64e619f9274e3c2434b'
# New sha1sum is : '1273d8cfc7946cb893aea8729260e388fe24b87e'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'e8b3f6570e2ac60f76a60fad1e28df32'
# New md5sum is : 'fc7aebda3d3096298d4170fb2367f396'
# Old sha1sum was: '0aaf20f5e0dbb28eb8a8e35c9642b0e5e22aba2b'
# New sha1sum is : '883b0d5ec4edc6dd71974f7c015643e028c31e39'
# Old sha256sum was: '29dde347adcd2ad6c8c4a8f6600d25aafe443d7090e8b7fd92b58baf372e1051'
# New sha256sum is : '96af3118464cbb65751f5b018311c82e911c2bf6076e85665c819d2403fb275e'
# Old modification time was: 'Sat Jun 27 15:20:18 2020', now it is 'Wed Nov 18 10:49:28 2020'
#
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '98d6e943f6a9d49174eb1e4f1c723f0f'
# New md5sum is : '8584dbc4d5c2ec65c8ec5538845aec3c'
# Old sha1sum was: '2949e398e1a10ee6c3d354069ca494e9a28b480a'
# New sha1sum is : 'b7848bd7f3e4c3ac627a7f9a2ce9ef475be107bd'
#
#
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'e9825da84e77bdb1ebe785424285f4ad'
# New md5sum is : '605f1a4c175d252a69d636f1846dd05f'
# Old sha1sum was: 'c7e56277b539553562202070286fbda0d1cdf9f2'
# New sha1sum is : 'f51a2aead22698f5784036d729fedd99d3228311'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '779ad9e81573218c15f475dd143e7263'
# New md5sum is : '1fd0dc10ef50bbf663fb64c15e747561'
# Old sha1sum was: '79d8b3c56a3956ba47a5f2065b955c031a7ecde3'
# New sha1sum is : 'f27bd8e798c9ac36d085e24f7cdc5c17745ced30'
#
#
# File <FILE> checksum changed.
# Size changed from '1500' to '1560'
# Old md5sum was: 'fb9921ac3707d7798578571f3b00c39f'
# New md5sum is : 'df7f427b07fd7057ee76d5e9af7f418c'
# Old sha1sum was: 'a333ddb993eb2c7b9b9a8f13d0aa96ca7f6cc166'
# New sha1sum is : 'f713b9441ac756066eaa6c32749f2d32ae019604'
# Old sha256sum was: 'b3c0ab98488da34268c7e0fe67fc76df8d7d8f04cd1c317cb49e968b20d56d58'
# New sha256sum is : '4429ea3f7f3698b5b8e88d4f72a0760a810055feb1785b57451440a545529e6a'
# Old modification time was: 'Mon Nov 16 14:50:37 2020', now it is 'Wed Nov 18 10:43:35 2020'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '844a888b8036d620f543bd1fcc60a655'
# New md5sum is : '37dd4b9517dcbbe879ffd0fee3a28eab'
# Old sha1sum was: '02bc0629f224a26827584c14df524cc80da67dda'
# New sha1sum is : 'e199f0989ae3a769f3d6817a0d565d7e8bcd77e6'
# Old sha256sum was: 'dd163782112c4b40fac8dbd3f2643621d0f61b518d6bd5c08b864b8365675a46'
# New sha256sum is : '73ca8e19cbe1e6a47292743edf2e207b60137b8e6854c590869120b8010dfb44'
# Old modification time was: 'Mon Nov 16 13:01:32 2020', now it is 'Thu Nov 19 08:55:06 2020'
# Old inode was: '143465', now it is '163930'
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '29f860e99da3a26213d3dde54284ccab'
# New md5sum is : 'e4c83a193ba2cad301cc589a0889ebf1'
# Old sha1sum was: '9278e683a46c9c445b414d9495548054448a95fb'
# New sha1sum is : '13e373f27ddf410baa080dd028431b812b3c8263'
#
#
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '59d55bad8c2aa50a749541e46c999c38'
# New md5sum is : '18721a8c9baa235ea4b17082c35d1380'
# Old sha1sum was: '748abc1cb80bdcfb75d6cbe0fc6a9d9c1e5a34a7'
# New sha1sum is : '877b8fb593c7fd8debacabb15f642c2b16e97556'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'fb85b10351d29572f117ffe8c5260f4c'
# New md5sum is : 'db174751838f5cb1ae70854a4d8e3704'
# Old sha1sum was: '0df3fcc0302fdd7607f6ffb5f9f69fbd2edd0046'
# New sha1sum is : 'a1b7ec3b7e9165bef58049ee2b5cc7abf2412be1'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '98161c81f3287d578502117e30d10d9a'
# New md5sum is : '4659fbe7b6da9a81a694bb990d6d9aa3'
# Old sha1sum was: 'a1b28f711c4e26f378c0d8f98dde7e3c2df668dc'
# New sha1sum is : '8e3014a05ddecfb2cff59528939551848c0bcd06'
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'e77ea05ecea820259d7dad1a57190bea'
# New md5sum is : '74797d63f71696d6e66f3092295c6814'
# Old sha1sum was: '68285fb131fe4e5ec728321a078e7b39b11900f3'
# New sha1sum is : '84cd113e4d3dc7d467dc92ea4a36e0de38d0e210'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '6a9ef7881bea4b1e2484c03495e2757a'
# New md5sum is : '86d55dcf1730c55b8fe0d6ab52c0f997'
# Old sha1sum was: 'b64d96e5657cac155457bec2d4e29e2eb3a25a18'
# New sha1sum is : 'abcd386e08adcd93ad029cd2116819f3f3137820'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'b8897b303647e9dd5347d40593a75262'
# New md5sum is : '9fa6e6ccfa0903d974826acffa753e64'
# Old sha1sum was: '28e3ec5843d656a199f0a2528b160eea9488d5db'
# New sha1sum is : '31b4267deab150b9a538c1a0fb876e115f9927e5'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '252748385f1fc9095145591fc06fb666'
# New md5sum is : '53fcebf639dec4276cc36c3a831830a0'
# Old sha1sum was: 'e7663c03e9bef2c023d58c22c5eab5840d82701e'
# New sha1sum is : '0b3a189900ed4892f7bfab9fe7b7c91545d4a70e'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '121f9eceed17c592d65e2ce8f018260c'
# New md5sum is : '9efa7754fbdc270b0c9599657b721079'
# Old sha1sum was: '56d25104f4e862eea3efb6e8df26b0f9434b4a0b'
# New sha1sum is : 'aa5ee82263a8c57e724fefae16b3330a6c9fea38'
#
#
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '301151066a9ada7a1547f52dd55561cd'
# New md5sum is : '52d833c13c69f3e4cec3daf318e4be82'
# Old sha1sum was: '08dfa8e3488e30039ae7db581ac636237c5c6fcd'
# New sha1sum is : '3aeaffdc8964157fa8e90df4b75fc08cc8431a3a'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: 'c85ccb4af4456fb823ce28a8f7cb7fb4'
# New md5sum is : 'a1e6c70b3d6a37e63b3cf64ae37a24f8'
# Old sha1sum was: 'f9a109a653785055fbab897155346e64fba14305'
# New sha1sum is : 'a40331b98d64965943faf5d339b408c2b5688659'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'b0ba6ecc543c2fde267bf2e8c2c53553'
# New md5sum is : '85942c7b991019f19b76b498cef09f27'
# Old sha1sum was: '06282038a04ccbe0cff4b5a1fe07631dfc55b595'
# New sha1sum is : 'f95d5f9ed5fe90d5edef37f048bf32de6fc95c14'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old modification time was: 'Mon Nov 16 13:01:32 2020', now it is 'Thu Nov 19 08:55:06 2020'
# Old inode was: '143466', now it is '163931'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'f34d04fd05bae09cdf2abe29d7ab43c5'
# New md5sum is : 'f98e87b674c6912dd360251fde179bb4'
# Old sha1sum was: 'bad6e8b57174b5fd52f09d2a420c35efe52d1585'
# New sha1sum is : 'ae2dbae1e42dd9254d5387a934ba43f19ae55c1c'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old modification time was: 'Sat Jun 27 15:09:44 2020', now it is 'Wed Nov 18 10:41:57 2020'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'f52b3b3a0f1fd6ed05813a8ebb8b28ce'
# New md5sum is : 'f57610c96f8d05ffe3de355554f6ac4c'
# Old sha1sum was: '70c11228668fe10eb64343279270ff07bab3f77c'
# New sha1sum is : '58be4998b8b73416bfbd9eb0cc722388cbb6cc4f'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '97ae50dbe462d29582810b2a38d4844d'
# New md5sum is : '6e6ccbd0210ac51fbed610f454a71555'
# Old sha1sum was: 'e0ee2efcd03d3e1dd3f01cc39d974ced90b05fc8'
# New sha1sum is : '69aace10b9121a7bef3d5b4cb68be8fde0149f4f'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '1473a47bedfe668af6e1f21558fa6d7c'
# New md5sum is : 'ba04c01a6ca9a7283ce9c8fc6cc725b7'
# Old sha1sum was: '23cc9a3c0c4190a463912530ce7a5d906b902718'
# New sha1sum is : '32477cd2528e54e9ff976ae92cb12271349f633b'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: '0a72335759ff61966366ea4a6b676c89'
# New md5sum is : '962efd5f4aa55760d1a5d8c6ec40dd95'
# Old sha1sum was: 'f0063804450bd2b7f91b1b90979a60ed6c5c0789'
# New sha1sum is : 'acdd8a0d79c7792c1b9ecf694f259fdb0fa77b9c'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Size changed from '785' to '846'
# Old md5sum was: 'f4b3ddeaab7f444b08b2afaa14a1978b'
# New md5sum is : 'def3791971ed0de1a185b9c41082004f'
# Old sha1sum was: '5b9fda005c8753875d66ba1c4af07f9cede72298'
# New sha1sum is : '6ebacf85d21f24048d1f88ecb397a77a4b9185cb'
# Old sha256sum was: 'b974f1c8d498cce8c0da667d9951dfece80ac709de9635e3bcf915d7248ea3cf'
# New sha256sum is : '5d038ad6d0dee0c76601a25ef47455b93a8e903037d60485e9feb08eac9bb872'
# Old modification time was: 'Thu Oct 22 09:28:32 2020', now it is 'Thu Oct 22 11:30:47 2020'
# Old inode was: '406275943', now it is '406144052'
#
#
# File <FILE> was added.
#
#
# File <FILE> checksum changed.
# Old md5sum was: '8fa680c104cbba54015752a2fe2c8c0b'
# New md5sum is : '11e821b295c7ab3bca963dcfb9a3a235'
# Old sha1sum was: '9a59f826b4dd7f5b5e97ec6d0ce7a47c18e78706'
# New sha1sum is : '21003c777c1097996e0dde735b7e7a60b1257d58'
#
#
# File <FILE> checksum changed.
# Old md5sum was: 'eadc0e4c16ccdd1cae078bb1d7dc8ca6'
# New md5sum is : '89d2766f93d6d10a88ddc01b337b100f'
# Old sha1sum was: 'c192bebc5546cbb023be1d848a8c2e6e35e6fc3b'
# New sha1sum is : 'd350b454cb2bfa7362182e9787025d7a774eab03'
# Old sha256sum was: '5dca49ce46bbed582680b57008817a7b0239227168e1cabe9e861d54efad3b35'
# New sha256sum is : 'e9bebca246de9fcd72bc60f07e3b28201957c44d638f506e8593ee71f41dd4dc'
# Old modification time was: 'Mon Nov 16 13:01:31 2020', now it is 'Thu Nov 19 08:55:06 2020'
# Old inode was: '143461', now it is '163928'
#
#
# File <FILE> checksum changed.
# Old modification time was: 'Wed Oct 21 11:35:21 2020', now it is 'Mon Dec 14 10:26:14 2020'
# Old inode was: '406241710', now it is '406518449'
#
#
# File <FILE> checksum changed.
# Old md5sum was: '74c58e6b0e341a8fa7b0c15bd181ed9f'
# New md5sum is : 'c639268bffa2c80242284070fa3b033f'
# Old sha1sum was: 'ab1cc2b17052f83ae8ed287e83d9124dfd86143f'
# New sha1sum is : 'e8900692eedf94aaa7da9a869978ba6257ae3ca0'
#
#
# File <FILE> is owned by root and has written permissions to anyone.
#
# File <FILE> checksum changed.
# Old md5sum was: 'ae01313fd6efa1a98506788c337c1d96'
# New md5sum is : 'ad3def95918d7b3f407b161af8fa280d'
# Old sha1sum was: '38d23589e65ebd60cd2d02f7fbbeefee651a8854'
# New sha1sum is : 'b596d3daa2d6eeefb348107154d84e7f1a4b3202'
#
#
# File <FILE> checksum changed.
# Size changed from '10425' to '10428'
# Old md5sum was: '8abf5e348f61fb1917230256060f3722'
# New md5sum is : 'd2f2e60af4cfc0c60a6b3fdaca6d49f1'
# Old sha1sum was: '37f4de349d206339e62679f89ee8a2d11560fe36'
# New sha1sum is : '310ee2088202b2c6456a44dda69dd63117dfe571'
# Old sha256sum was: 'f664f32deb735cdafc597fda3937d1cabae4174773135256af0b068171df5c61'
# New sha256sum is : '721ed702b9ba31e6da2667c50f3932228c337b0192bd3b8dcb72c2570e72c3e2'
# Old modification time was: 'Fri Sep 18 13:36:11 2020', now it is 'Tue Nov 17 16:55:15 2020'
# Old inode was: '138191424', now it is '141773393'
#
#
# File <FILE> was added.

# %%
log_file['log'] = log_file['full_log'].str.replace("(?<=File )'.+'", "<FILE>", regex=True)
log_file
# Out:
#         level                                           full_log first_word  \
# id
# 515         3  File 'HKEY_LOCAL_MACHINE\System\CurrentControl...       File
# 794         5  File '/var/www/html_update/management/hashconf...       File
# 1997        3           File '/usr/bin/elasticdump' was added.\n       File
# 2320        3  File 'HKEY_LOCAL_MACHINE\System\CurrentControl...       File
# 2858        5  File 'HKEY_LOCAL_MACHINE\System\CurrentControl...       File
# ...       ...                                                ...        ...
# 471343      5  File 'HKEY_LOCAL_MACHINE\System\CurrentControl...       File
# 471567      5  File '/var/www/html/management/hashbin.txt' is...       File
# 471822      5  File 'HKEY_LOCAL_MACHINE\System\CurrentControl...       File
# 472052      5  File '/var/esild/etc/ossec.conf' checksum chan...       File
# 472322      3  File 'HKEY_LOCAL_MACHINE\System\CurrentControl...       File
#
#                                                       log
# id
# 515                              File <FILE> was added.\n
# 794     File <FILE> is owned by root and has written p...
# 1997                             File <FILE> was added.\n
# 2320                             File <FILE> was added.\n
# 2858    File <FILE> checksum changed.\nOld md5sum was:...
# ...                                                   ...
# 471343  File <FILE> checksum changed.\nOld md5sum was:...
# 471567  File <FILE> is owned by root and has written p...
# 471822  File <FILE> checksum changed.\nOld md5sum was:...
# 472052  File <FILE> checksum changed.\nSize changed fr...
# 472322                           File <FILE> was added.\n
#
# [822 rows x 4 columns]

# %%
log_file['log'] = log_file['log'].str.extract("(.+)(?:\n|$)")
log_file['log'].value_counts()
# Out:
# File <FILE> checksum changed.                                          397
# File <FILE> is owned by root and has written permissions to anyone.    244
# File <FILE> was added.                                                 181
# Name: log, dtype: int64

# %%
log_file.pivot_table(values='full_log', index='log', columns='level', aggfunc='count', fill_value=0)
# Out:
# level                                                 3    5
# log
# File <FILE> checksum changed.                         0  397
# File <FILE> is owned by root and has written pe...    0  244
# File <FILE> was added.                              181    0

# %% [markdown]
# ## --MARK--:

# %%
groups.get_group('--MARK--:')
# Out:
#         level                                           full_log first_word
# id
# 9365        0  --MARK--: =?s_w*?!5u]7c/s?Z1(FATAl?o0khglYB]Q0...  --MARK--:
# 79217       0  --MARK--: Lnsb5;CD,&vN2!S_+!hlX0?4N9FCI%WFSD]D...  --MARK--:
# 88229       0  --MARK--: QhU7AXVHGsFdh,3wL4bR;,x&q1?1PQV2(ik?...  --MARK--:
# 127292      0  --MARK--: %&)Y,UK%AV1Q$*H_U!C1HyPwEtE?ox8@1xQO...  --MARK--:
# 180373      0  --MARK--: [kOlJY!(1OE83l7Rj,mQQvgoT&Cu!p_BAYrB...  --MARK--:
# 187935      0  --MARK--: 2k06(D+8h?6q;fFD34mn2lmfGI'(vl6K4Sh#...  --MARK--:
# 205605      0  --MARK--: N[$9H&R]stqazsx,D)'26MPV?C[E/AeRpf]+...  --MARK--:
# 263076      0  --MARK--: Bve5Z-oLF9#)LT;.snZlXJbizTDVmEOjQP86...  --MARK--:
# 326054      0  --MARK--: 0KY#u2STO^[TWE^uuL.+#a3!+;KeBpHtbuyJ...  --MARK--:
# 340462      0  --MARK--: Klq)#FqoV_]r_@[C!s.t)E!9xlY^M?^PWIM7...  --MARK--:
# 393979      0  --MARK--: O0&f0'%Um%j9[*Z=T]ti$)]6N'xX*L)sihfd...  --MARK--:
# 405156      0  --MARK--: PC8A$Siff!_zTYloi@Mon@;l&'/NL;3OhzX8...  --MARK--:

# %%
show_all('--MARK--:')
# Out:
# --MARK--: =?s_w*?!5u]7c/s?Z1(FATAl?o0khglYB]Q0OTwjGzB!nVlVSdiJnnN/VJJ#qi091Xao?iduzHEdkUw&rDtQQc2sV7(6a8$U#j0MC&wG,YRG$rbf+@1c0-n6E^.2Cv&3=T7mXZ$D]1nf9yl6@QER690Yup*5Zt48Lu'9gc65Ixx]B2'JMqv_qAY0=XEdVmW6NpRRFqy+3S&mKFPru+erp3d]mRJ;v@D*8nfRlrFu!1vU;pNsHl5524*pD)VOkSOf$62(&)J?E6FERs4KV;'y6cZxVcO6Rf/@+s?kK5LSVHo'D2](^l_zzD9]5o&m!&;Kw^@*.?tBL.,L.K))IKkU*6kD4+DmgYrYG9$WZn)hTf0ozna4wdJ&f5u]te.8&)vSJdMUuNU55H??J3LNru!T@PZja(b5h.atdRP6T/Kq5A5M)!dIL36c0h-_TPg3*%5d*+(*5H!?EU3_c/wEYGq
#
# --MARK--: Lnsb5;CD,&vN2!S_+!hlX0?4N9FCI%WFSD]Dh9rOuBt6yg+ljcZ_1RJuBBq+pll&V5vxRDYl)r1w*H9q6*;DGr/ul,$EN1Gw=w2h17iWBi+idDd)KxN.u=v'c%B,*v]B'qTD)W(!_l[PJb@@k.wSJj^euz[).+)B!&K&)qb.n+Xw,SiXNygqoVPLXLOS5,zkMY?!Ya-S$kw6pSKxc/XVdwmJ$78bQzpDF=QK,)Qt)&mj&$(fnnPpcW2UWt&L$v@8jWnut6D8glF*tgx5$5V3LNrD]x$Je[''+q3pBse]%n@'(XJMOcCGwI)Y]4G[2)?k08YRF*V1A6KuHuU1)2zqv^4rL52wf@erroRp_fy*pP+P(je7p/YP%8??ph1BR;a'O36VW!9oQtjV_s9Vo!9FKuwO/XWO--ZwTrpe-cEkg[X,$#@pBW1?,7Q^V,q,3*7utvb!^VDlYyRZ=dlJINCAfce(R6DyL;hrTneF#kXmkcsHq[a9!G%gq*?hYp@-Ui=-a;!iHJwwYa7z^W1@QT.Pg#qZAh^50qIaRz3t=a7hom^a2oDOBZpJ5kEo9k/4u0Z,dPeS@;e_2p51?0Z4*=6))MdA
#
# --MARK--: QhU7AXVHGsFdh,3wL4bR;,x&q1?1PQV2(ik?8I+bgH0$IbLf6GL7AtvG9G;5hNGKKxoL1r^W&!.u^A@C,oo6RRoFATaLt3'C,8*hkW*GP(DScftOl!Z-lFB1R[,gX!26.3S7R9MTF=UQVrY0btyC)Oq2n'M,!T
#
# --MARK--: %&)Y,UK%AV1Q$*H_U!C1HyPwEtE?ox8@1xQOHm*%YglknvkO-V$8JeugrDIbo/C.7^Qn2ZE%rhPbzErRort7-2Dz),mg%K;?y(MQ5yMC6#Nt2^fJyaRrph!83D1@jawDob9%TooFvx/q*FuL1Vz2'+*Y2qhA/@?8NdvwqDIHWv)7V6H/+R*.f^aw1Lmj9Rh@ir6yU=H#.AQsLG1R?d)Vn1Kh50Xa!?nik,CpaJ;#vF-fU%n]BebMAXe_aC'tn'w-Dnrub_Rv)n#@PlrD8TA,L/'EaJ3oADm?[OBE6;o36b6R4A3f'ECA,zDvQmdH*S#3Zl4Ahd$L;#;w871bsZ#N(HcXzFI[Pr#.B388)w;TIBm5_
#
# --MARK--: [kOlJY!(1OE83l7Rj,mQQvgoT&Cu!p_BAYrBsq0(@.mw1!Z'S0+3nYoDdnwO50%a[gw1Rp[_p'9?xLIHDi%u$w.GnupuQOzFN]cAuB&ZA;=keN_,wg/osvw5X_Q?B5A.k*pRyw)h_CF*,&sMQfs_.Wy&,]s1j*FICX5_DG@])5FvmvC&]Kji10?Rt^vlV6W/.AWW==,(#s!tpttuYQ7*Iy;?M$A1vjJFDC1G8t^X3]lP'tidtzD,iV/Xp!@B7?8=5[_r6oU-^-Iw#*;tQBIkiCja),bsPyY,-#t&uk)Yze1I_B8j!h5X9AvcpQpJew?wAe;eRRoRT@(lN%$-Mvpaq%*x@LiC6S(!9#*DmS!Md7t%v8Z+?TRv@nq&%h6Of%iNNXK%^t5vl?DoTC.a3s/IC6=K7UG-w]NqBE(*S1#bgMm?=t/[g93F[+Hm^mUsi6f4vy02(xfUglY)yaWz6BkTkqyKr/[2Hf![**YFBjyluuP+6O$!v3#);3^Bp+Uf!9*)ovEA=sv/&._nxS%&JaJ
#
# --MARK--: 2k06(D+8h?6q;fFD34mn2lmfGI'(vl6K4Sh##aw39pt_&iORKEzG_K!,,I&@AhO[D59PR3eG(7nFic.S#5P)b@niw,uB*_]n!&.fiy.aS*3st[/iLcFDn3&Y*$],W!FKh&i!Mwxs&zNJUIhyzLxCJ+*]RPMAzC5BKv7s/GM23J**owGveQJeKj1Uq?rHD=l88zP_.wUVrSCG'9w[DW2GeR-u-@1C4,-DdeRroR8^_$eHMS$ElzEmdZb$c-IqIu2N.]?yJnu(T)aE(4Kc9gP!VR9Y!'o).jM=,gkvOryu_vB)d5Oo4'3ctt?L[74'El6#fxla_RGK;!t^sV&_OH9$=7[Cl-[G7X)E]Q!UyvSd-h51@uAj//ZJfm/Y4PZRICu&o*u,%
#
# --MARK--: N[$9H&R]stqazsx,D)'26MPV?C[E/AeRpf]+FWTF7ujl&Ke'V9z_4uQWUV&%f;#fvq+F4pV/TQ&P;1N(BzoV3J(Q$+%t,ZOc-+tB)mKsLt^9Yf4lzJY!crBpP,_Y7Sz'ZkBc3ieY7f+aVVQDOvd&7%C!$!X)j6%8Q^!Jko8qbAOq]TM_^RxK^vW[]Bzm2PC3n8gDLKpUg[Q^-WzB-w3;Xttkn!;mgBz4%XMbNh4Mj$blLAUdkzff+OB58MjSbnd7qtP0,!!OUE^*wO[$N8ByFATALdQt.06=J&rB6pGdQkH0)rP#nH6ZSNlmxaSJ37F0e0$V8YnN,-H^AwO8]0sumJptU#[Lk--+Bky%BCn_D_iL[dUrO^P!R3a8YBeGRx*E&hn*]ENy6'O2LlDX3Rx(Z]IDOBRqfSvil(johqn)3^[hVHmB6EyU,hGIJX-Zf]+O)J2jKuq#%mviK8YrRrwE4bbCvX*D5878wPH&7N2x&&.jm8QDw9ng!;,)npJ%qf.WGkM@p#HW-3?uO![Mx;NMfRD@2#&$in)@g(s56EDz&4v/X8Z2'[ai)EX;a!RW[aLcR*h7e8%AL=G8#o+#1Rag?GS5t+[wL2BcVCAL+MW6n_bu148*YPpu0Kbir]YyYaibanwMw%Ts'J*6=c4'h&O=1l)+B,qi'O
#
# --MARK--: Bve5Z-oLF9#)LT;.snZlXJbizTDVmEOjQP86?i5;[k0Ir(w=u^M#G5PZVNtzL2N/aIA16bz;f6^(e962LkZjt_gIx(w]/sAoxENMgi3!!ql?&;yz53$'q#+#Hf_g$W/c9TR)jpB,4z_zc40reDUAx6xn?i*3nPu[01FZg)oGqKoq%2;3RKKw9zuFNpsjDqj_35c?VfE^vVE27MQ[5-PL/'Hl]5!];yKVNZWJH!i(pv$1AWrT$@[m5]Y=?]b/yRu17FroqeFrTg2!ErRoR-pJW5oqPotFmPyj*D&WS&sR%,YVsbS70HCHFjcynWpmYPW+@YTvO-$]&9s67rxW
#
# --MARK--: 0KY#u2STO^[TWE^uuL.+#a3!+;KeBpHtbuyJ.A&Q_ffa1PSJ]=OuJxVV.A*FuI#*3FBj)/4'ekCsGF3k!dg$56x%4'(5stFifpWDtxYnq]%BYiRjz3;w?/)Oh[U!S,^6Wd-'Iq5*4$h,_Is0RdURexeSl_O[H!KP;;?#q!BB,Jwtk19MpcPp!kh3nkFAtAlZdGh#-EsgnS9kW5Rd9Vet?TM-ejJpQv;QrD(wnVPK^vDR2D0!^CkI_dq82O?A#6o*=llR026#TolYPZ2p*/Wz@qkTkqD(.@BGT6w1d1FSVCz5+C5ehmz?ndyqC9@&BPa[QmY$vrT2&mmF3tEQ%HQL[J&?OS5+kZ8Du0t$[xNDN4!fl-oSt#gU[$@+0Z;0E'm.I)oZrZ]'
#
# --MARK--: Klq)#FqoV_]r_@[C!s.t)E!9xlY^M?^PWIM7om-)h4toOE0_#o!*_zI9#Vl**]3e[6RK^NEj$;1Dau%E';[1$,rCjVx7Z+em'pnq6PfBe9P/z'#02,p@ISWvGz2+;_-@5T6f2Q#N7s(AH+2TAmec,@//zTT@h$.H,vBY't!d9rwQcw(fLDZkZeAr+[;[k1v&_LPK.Error)[&[qdFcDEx$mMMmg]f=fscv-L1rubu-Wg^;pOb]N7?*ZsvFkZ9&D'b]t,SS+h5e'pKNs0MkJ)s/O+OxvXST0ei-NU=A[akPjcZuM-91MP#kO!N#C8*9rFBuM6APqT]#^g+qDq7*.NS_Ey]4*N])GN9r$A+[2Z#auuOhgo0dsVYuMoUCaDPC=WsZOK/tTtQ?h)ak#GK9B0;K3lsRz/U+)nZkf0m&Dk@VJd$EmU%(b2bYS4xLxQ#hwQmLhzlEWt;f[vf5V2LMgTC5n#G@$XWdG(triM?&*d98_G7B[&VGJgpB7ZP=f8BG;PVDtO!J@+$Boc?aOwd*IY?3I1x2S4FjxW=xfdHB&T6/^UwYV5;$VZ3C!3tm_IsA933(%)$Mi7ANLh/NcfFBr-%]MGRAA7H%DcZ)c4y@,*peyF,0^Zznj7L0&mc5F-DQA%JVmi[a7te4Zzup_G=b
#
# --MARK--: O0&f0'%Um%j9[*Z=T]ti$)]6N'xX*L)sihfd2n@-;EYi&@X=^.2ckUMNezx*wm;]y]4$VQA60&d3j3emx6W1tnTI2^UVq1W$Lf5&f;Old8A/qrHG]6R/p%iRU0yVNk=PHl+J7mIDCIdSW9V6FC'TwxaEykyV2&tZvY(9gA;6HXD#Nu?Mu;(1JTwiT2(TnqJExKHZ9Pp=amZYB,Gjml5qU?Vu-fl3ULv1DxlY8#BA[rzCe([[z@ddP4uKw6,p8N++-k=%j7LI;E=zp5&QX[OH.vrN+hV(QrJrQFaTAltDd?=;)i,STmr/]Tl[w4]Xf44eS7Mf9[u80j0-p$6n-R]rn]2Q1nE6Ux%?.&6)#DW,X2@ay)HkZOCG&x.+'bf+1r=l7,s+@J7)cm*'@d'x9SdTI4$Qgd%5*c^[hTDXz23a7v-H/+PS#t_Y_P37!kc'8(%cE&oJIxSbgT$1Dr%#8K(=-BuBX^c.=_3=s.zvsv0/TJ%MS$4l+hd
#
# --MARK--: PC8A$Siff!_zTYloi@Mon@;l&'/NL;3OhzX8V9Ipz3J'*4'/VQU^G&5lC@J)yD0cK7b).t&sicmI%JEd!h$IAZ);zY+[Pc';^-5@hO/VcynC=O!q0m+5;;(t0UzAwWDtYom^odrO!ltWrN8;d[_j0!3LbJp](HoZU@Qw[&*fZ*/@*Dd15=C(=,SnUnErrOrl73R?,+GihrY[)EE/Ln]2,5.hJHxGyb8%3J5HislVU=]?C5+]!;rm4ceFHA'PgnK2$FA30bJvdw)u$D;L/5SzM9WuUV(1ytiW_39z0[FRO+GfDi9=wNbAx1LL+ohc4Q/O/qPxqk2ZLIJqrKrL]Tkx=D+/_Rro)$S.qy9mCR%8AnW+sCT+P[HIu&?x+Hr9Ss_1Hfn/O&_l+kaVRYhzwdcE%j&@V.xfZDYzc2Px]Q+x5T-JwgbC5RQszl[KtTwuXnx*$J&N

# %% [markdown]
# ## E:

# %%
groups.get_group('E:')
# Out:
#         level                                           full_log first_word
# id
# 1642        0  E: probe_rpminfo: RPM: rpmdb: BDB0113 Thread/p...         E:
# 1701        0  E: probe_rpminfo: RPM: rpmdb: BDB0113 Thread/p...         E:
# 3256        0  E: probe_rpminfo: RPM: rpmdb: BDB0113 Thread/p...         E:
# 3862        0  E: probe_rpminfo: RPM: db5 error(-30973) from ...         E:
# 4318        0  E: probe_rpminfo: RPM: rpmdb: BDB0113 Thread/p...         E:
# ...       ...                                                ...        ...
# 468744      0  E: probe_rpmverifyfile: RPM: rpmdb: BDB0113 Th...         E:
# 469612      0  E: probe_rpminfo: RPM: rpmdb: BDB0113 Thread/p...         E:
# 469694      0  E: probe_rpminfo: RPM: rpmdb: BDB0113 Thread/p...         E:
# 471535      0  E: probe_rpminfo: RPM: rpmdb: BDB0113 Thread/p...         E:
# 471984      0  E: probe_rpminfo: RPM: rpmdb: BDB0113 Thread/p...         E:
#
# [297 rows x 3 columns]

# %%
groups.get_group('E:')['level'].value_counts()
# Out:
# 0    297
# Name: level, dtype: int64

# %%
groups.get_group('E:')['full_log'].value_counts()
# Out:
# E: probe_rpminfo: RPM: db5 error(-30973) from dbenv->failchk: BDB0087 DB_RUNRECOVERY: Fatal error, run database recovery               124
# E: probe_rpminfo: RPM: rpmdb: BDB0113 Thread/process 26357/140408208971520 failed: BDB1507 Thread died in Berkeley DB library          105
# E: probe_rpmverifyfile: RPM: db5 error(-30973) from dbenv->failchk: BDB0087 DB_RUNRECOVERY: Fatal error, run database recovery          23
# E: probe_rpmverifyfile: RPM: rpmdb: BDB0113 Thread/process 26357/140408208971520 failed: BDB1507 Thread died in Berkeley DB library     17
# E: probe_rpminfo: RPM: rpmdb: BDB0113 Thread/process 13362/139912875566848 failed: BDB1507 Thread died in Berkeley DB library           16
# E: probe_rpmverifyfile: RPM: rpmdb: BDB0113 Thread/process 13362/139912875566848 failed: BDB1507 Thread died in Berkeley DB library      7
# E: probe_rpminfo: RPM: rpmdb: BDB0113 Thread/process 22079/139845236422400 failed: BDB1507 Thread died in Berkeley DB library            2
# E: probe_rpminfo: RPM: rpmdb: BDB0113 Thread/process 30478/140432988804864 failed: BDB1507 Thread died in Berkeley DB library            2
# E: probe_rpmverifyfile: RPM: rpmdb: BDB0113 Thread/process 30478/140432988804864 failed: BDB1507 Thread died in Berkeley DB library      1
# Name: full_log, dtype: int64

# %% [markdown]
# ## oscap:

# %%
groups.get_group('oscap:')
# Out:
#         level                                           full_log first_word
# id
# 3396        3  oscap: msg: "xccdf-result", scan-id: "00016030...     oscap:
# 3661        3  oscap: msg: "xccdf-result", scan-id: "00016020...     oscap:
# 5658        5  oscap: msg: "xccdf-result", scan-id: "00016030...     oscap:
# 5695        5  oscap: msg: "xccdf-result", scan-id: "00016019...     oscap:
# 7206        3  oscap: msg: "xccdf-result", scan-id: "00016052...     oscap:
# ...       ...                                                ...        ...
# 466619      5  oscap: msg: "xccdf-result", scan-id: "00016007...     oscap:
# 467561      5  oscap: msg: "xccdf-result", scan-id: "00016019...     oscap:
# 468063      3  oscap: msg: "xccdf-result", scan-id: "00016020...     oscap:
# 468233      5  oscap: msg: "xccdf-result", scan-id: "00016080...     oscap:
# 471969      3  oscap: msg: "xccdf-result", scan-id: "00016022...     oscap:
#
# [366 rows x 3 columns]

# %%
groups.get_group('oscap:')['level'].value_counts()
# Out:
# 3    198
# 5    168
# Name: level, dtype: int64

# %%
show_all('oscap:')
# Out:
# oscap: msg: "xccdf-result", scan-id: "0001603070557", content: "ssg-centos-7-ds.xml", title: "Record Events that Modify the System's Discretionary Access Controls - setxattr", id: "xccdf_org.ssgproject.content_rule_audit_rules_dac_modification_setxattr", result: "fail", severity: "low", description: "At a minimum, the audit system should collect file permission changes for all users and root. If the auditd daemon is configured to use the augenrules program to read audit rules during daemon startup (the default), add the following line to a file with suffix .rules in the directory /etc/audit/rules.d: -a always,exit -F arch=b32 -S setxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the system is 64 bit then also add the following line: -a always,exit -F arch=b64 -S setxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the auditd daemon is configured to use the auditctl utility to read audit rules during daemon startup, add the following line to /etc/audit/audit.rules file: -a always,exit -F arch=b32 -S setxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the system is 64 bit then also add the following line: -a always,exit -F arch=b64 -S setxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod", rationale: "The changing of file permissions could indicate that a user is attempting to gain access to information that would otherwise be disallowed. Auditing DAC modifications can facilitate the identification of patterns of abuse among both authorized and unauthorized users." references: "AC-17(7) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-1(b) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(d) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), IR-5 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), 126 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), 172 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), Req-10.5.5 (https://www.pcisecuritystandards.org/documents/PCI_DSS_v3-1.pdf), 5.2.10 (https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf), SRG-OS-000064-GPOS-00033 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000392-GPOS-00172 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000458-GPOS-00203 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), 5.4.1.1 (https://www.fbi.gov/file-repository/cjis-security-policy-v5_5_20160601-2-1.pdf), 3.1.7 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-171.pdf)", identifiers: "", oval-id: "oval:ssg-audit_rules_dac_modification_setxattr:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_common", profile-title: "Common Profile for General-Purpose Systems".
#
# oscap: msg: "xccdf-result", scan-id: "0001602054310", content: "ssg-centos-7-ds.xml", title: "Record Events that Modify the System's Discretionary Access Controls - setxattr", id: "xccdf_org.ssgproject.content_rule_audit_rules_dac_modification_setxattr", result: "fail", severity: "low", description: "At a minimum, the audit system should collect file permission changes for all users and root. If the auditd daemon is configured to use the augenrules program to read audit rules during daemon startup (the default), add the following line to a file with suffix .rules in the directory /etc/audit/rules.d: -a always,exit -F arch=b32 -S setxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the system is 64 bit then also add the following line: -a always,exit -F arch=b64 -S setxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the auditd daemon is configured to use the auditctl utility to read audit rules during daemon startup, add the following line to /etc/audit/audit.rules file: -a always,exit -F arch=b32 -S setxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the system is 64 bit then also add the following line: -a always,exit -F arch=b64 -S setxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod", rationale: "The changing of file permissions could indicate that a user is attempting to gain access to information that would otherwise be disallowed. Auditing DAC modifications can facilitate the identification of patterns of abuse among both authorized and unauthorized users." references: "AC-17(7) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-1(b) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(d) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), IR-5 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), 126 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), 172 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), Req-10.5.5 (https://www.pcisecuritystandards.org/documents/PCI_DSS_v3-1.pdf), 5.2.10 (https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf), SRG-OS-000064-GPOS-00033 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000392-GPOS-00172 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000458-GPOS-00203 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), 5.4.1.1 (https://www.fbi.gov/file-repository/cjis-security-policy-v5_5_20160601-2-1.pdf), 3.1.7 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-171.pdf)", identifiers: "", oval-id: "oval:ssg-audit_rules_dac_modification_setxattr:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_common", profile-title: "Common Profile for General-Purpose Systems".
#
# oscap: msg: "xccdf-result", scan-id: "0001603070557", content: "ssg-centos-7-ds.xml", title: "Ensure auditd Collects Information on the Use of Privileged Commands", id: "xccdf_org.ssgproject.content_rule_audit_rules_privileged_commands", result: "fail", severity: "medium", description: "At a minimum, the audit system should collect the execution of privileged commands for all users and root. To find the relevant setuid / setgid programs, run the following command for each local partition PART: $ sudo find PART -xdev -type f -perm -4000 -o -type f -perm -2000 2>/dev/null If the auditd daemon is configured to use the augenrules program to read audit rules during daemon startup (the default), add a line of the following form to a file with suffix .rules in the directory /etc/audit/rules.d for each setuid / setgid program on the system, replacing the SETUID_PROG_PATH part with the full path of that setuid / setgid program in the list: -a always,exit -F path=SETUID_PROG_PATH -F perm=x -F auid>=1000 -F auid!=4294967295 -F key=privileged If the auditd daemon is configured to use the auditctl utility to read audit rules during daemon startup, add a line of the following form to /etc/audit/audit.rules for each setuid / setgid program on the system, replacing the SETUID_PROG_PATH part with the full path of that setuid / setgid program in the list: -a always,exit -F path=SETUID_PROG_PATH -F perm=x -F auid>=1000 -F auid!=4294967295 -F key=privileged", rationale: "Misuse of privileged functions, either intentionally or unintentionally by authorized users, or by unauthorized external entities that have compromised system accounts, is a serious and ongoing concern and can have significant adverse impacts on organizations. Auditing the use of privileged functions is one way to detect such misuse and identify the risk from insider and advanced persistent threast. Privileged programs are subject to escalation-of-privilege attacks, which attempt to subvert their normal role of providing some necessary but limited capability. As such, motivation exists to monitor these programs for unusual activity." references: "AC-17(7) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-1(b) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(d) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(4) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-6(9) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), IR-5 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), 2234 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), SRG-OS-000327-GPOS-00127 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), Req-10.2.2 (https://www.pcisecuritystandards.org/documents/PCI_DSS_v3-1.pdf), 5.2.10 (https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf), 5.4.1.1 (https://www.fbi.gov/file-repository/cjis-security-policy-v5_5_20160601-2-1.pdf), 3.1.7 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-171.pdf)", identifiers: "", oval-id: "oval:ssg-audit_rules_privileged_commands:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_common", profile-title: "Common Profile for General-Purpose Systems".
#
# oscap: msg: "xccdf-result", scan-id: "0001601964695", content: "ssg-centos-7-ds.xml", title: "Record Events that Modify the System's Discretionary Access Controls - fremovexattr", id: "xccdf_org.ssgproject.content_rule_audit_rules_dac_modification_fremovexattr", result: "fail", severity: "medium", description: "At a minimum, the audit system should collect file permission changes for all users and root. If the auditd daemon is configured to use the augenrules program to read audit rules during daemon startup (the default), add the following line to a file with suffix .rules in the directory /etc/audit/rules.d: -a always,exit -F arch=b32 -S fremovexattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the system is 64 bit then also add the following line: -a always,exit -F arch=b64 -S fremovexattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the auditd daemon is configured to use the auditctl utility to read audit rules during daemon startup, add the following line to /etc/audit/audit.rules file: -a always,exit -F arch=b32 -S fremovexattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the system is 64 bit then also add the following line: -a always,exit -F arch=b64 -S fremovexattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod", rationale: "The changing of file permissions could indicate that a user is attempting to gain access to information that would otherwise be disallowed. Auditing DAC modifications can facilitate the identification of patterns of abuse among both authorized and unauthorized users." references: "AC-17(7) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-1(b) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(d) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), IR-5 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), 172 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), Req-10.5.5 (https://www.pcisecuritystandards.org/documents/PCI_DSS_v3-1.pdf), 5.2.10 (https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf), SRG-OS-000064-GPOS-00033 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000392-GPOS-00172 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000458-GPOS-00203 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), 5.4.1.1 (https://www.fbi.gov/file-repository/cjis-security-policy-v5_5_20160601-2-1.pdf), 3.1.7 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-171.pdf)", identifiers: "", oval-id: "oval:ssg-audit_rules_dac_modification_fremovexattr:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_pci-dss", profile-title: "PCI-DSS v3 Control Baseline for Red Hat Enterprise Linux 7".
#
# oscap: msg: "xccdf-result", scan-id: "0001605230751", content: "ssg-centos-7-ds.xml", title: "Record Events that Modify the System's Discretionary Access Controls - setxattr", id: "xccdf_org.ssgproject.content_rule_audit_rules_dac_modification_setxattr", result: "fail", severity: "low", description: "At a minimum, the audit system should collect file permission changes for all users and root. If the auditd daemon is configured to use the augenrules program to read audit rules during daemon startup (the default), add the following line to a file with suffix .rules in the directory /etc/audit/rules.d: -a always,exit -F arch=b32 -S setxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the system is 64 bit then also add the following line: -a always,exit -F arch=b64 -S setxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the auditd daemon is configured to use the auditctl utility to read audit rules during daemon startup, add the following line to /etc/audit/audit.rules file: -a always,exit -F arch=b32 -S setxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the system is 64 bit then also add the following line: -a always,exit -F arch=b64 -S setxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod", rationale: "The changing of file permissions could indicate that a user is attempting to gain access to information that would otherwise be disallowed. Auditing DAC modifications can facilitate the identification of patterns of abuse among both authorized and unauthorized users." references: "AC-17(7) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-1(b) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(d) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), IR-5 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), 126 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), 172 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), Req-10.5.5 (https://www.pcisecuritystandards.org/documents/PCI_DSS_v3-1.pdf), 5.2.10 (https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf), SRG-OS-000064-GPOS-00033 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000392-GPOS-00172 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000458-GPOS-00203 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), 5.4.1.1 (https://www.fbi.gov/file-repository/cjis-security-policy-v5_5_20160601-2-1.pdf), 3.1.7 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-171.pdf)", identifiers: "", oval-id: "oval:ssg-audit_rules_dac_modification_setxattr:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_common", profile-title: "Common Profile for General-Purpose Systems".
#
# oscap: msg: "xccdf-result", scan-id: "0001602316806", content: "ssg-centos-7-ds.xml", title: "Install AIDE", id: "xccdf_org.ssgproject.content_rule_package_aide_installed", result: "fail", severity: "medium", description: "Install the AIDE package with the command: $ sudo yum install aide", rationale: "The AIDE package must be installed if it is to be available for integrity checking." references: "CM-3(d) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), CM-3(e) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), CM-6(d) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), CM-6(3) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), SC-28 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), SI-7 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf),  (http://iase.disa.mil/stigs/cci/Pages/index.aspx), Req-11.5 (https://www.pcisecuritystandards.org/documents/PCI_DSS_v3-1.pdf), 1.3.1 (https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf), 5.10.1.3 (https://www.fbi.gov/file-repository/cjis-security-policy-v5_5_20160601-2-1.pdf)", identifiers: "", oval-id: "oval:ssg-package_aide_installed:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_pci-dss", profile-title: "PCI-DSS v3 Control Baseline for Red Hat Enterprise Linux 7".
#
# oscap: msg: "xccdf-result", scan-id: "0001602504321", content: "ssg-centos-7-ds.xml", title: "Ensure /var/log Located On Separate Partition", id: "xccdf_org.ssgproject.content_rule_partition_for_var_log", result: "fail", severity: "low", description: "System logs are stored in the /var/log directory. Ensure that it has its own partition or logical volume at installation time, or migrate it using LVM.", rationale: "Placing /var/log in its own partition enables better separation between log files and other files in /var/." references: "AU-9 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), SC-32 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf),  (http://iase.disa.mil/stigs/cci/Pages/index.aspx), 1.1.11 (https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf)", identifiers: "", oval-id: "oval:ssg-partition_for_var_log:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_common", profile-title: "Common Profile for General-Purpose Systems".
#
# oscap: msg: "xccdf-result", scan-id: "0001602054310", content: "ssg-centos-7-ds.xml", title: "Record Attempts to Alter Time Through clock_settime", id: "xccdf_org.ssgproject.content_rule_audit_rules_time_clock_settime", result: "fail", severity: "low", description: "If the auditd daemon is configured to use the augenrules program to read audit rules during daemon startup (the default), add the following line to a file with suffix .rules in the directory /etc/audit/rules.d: -a always,exit -F arch=b32 -S clock_settime -F a0=0x0 -F key=time-change If the system is 64 bit then also add the following line: -a always,exit -F arch=b64 -S clock_settime -F a0=0x0 -F key=time-change If the auditd daemon is configured to use the auditctl utility to read audit rules during daemon startup, add the following line to /etc/audit/audit.rules file: -a always,exit -F arch=b32 -S clock_settime -F a0=0x0 -F key=time-change If the system is 64 bit then also add the following line: -a always,exit -F arch=b64 -S clock_settime -F a0=0x0 -F key=time-change The -k option allows for the specification of a key in string form that can be used for better reporting capability through ausearch and aureport. Multiple system calls can be defined on the same line to save space if desired, but is not required. See an example of multiple combined syscalls: -a always,exit -F arch=b64 -S adjtimex,settimeofday -F key=audit_time_rules", rationale: "Arbitrary changes to the system time can be used to obfuscate nefarious activities in log files, as well as to confuse network services that are highly dependent upon an accurate system time (such as sshd). All changes to the system time should be audited." references: "AC-17(7) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-1(b) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(d) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), IR-5 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), 5.2.4 (https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf), Req-10.4.2.b (https://www.pcisecuritystandards.org/documents/PCI_DSS_v3-1.pdf), 1487 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), 169 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), 5.4.1.1 (https://www.fbi.gov/file-repository/cjis-security-policy-v5_5_20160601-2-1.pdf), 3.1.7 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-171.pdf)", identifiers: "", oval-id: "oval:ssg-audit_rules_time_clock_settime:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_common", profile-title: "Common Profile for General-Purpose Systems".
#
# oscap: msg: "xccdf-result", scan-id: "0001602317054", content: "ssg-centos-7-ds.xml", title: "Record Events that Modify the System's Discretionary Access Controls - lsetxattr", id: "xccdf_org.ssgproject.content_rule_audit_rules_dac_modification_lsetxattr", result: "fail", severity: "low", description: "At a minimum, the audit system should collect file permission changes for all users and root. If the auditd daemon is configured to use the augenrules program to read audit rules during daemon startup (the default), add the following line to a file with suffix .rules in the directory /etc/audit/rules.d: -a always,exit -F arch=b32 -S lsetxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the system is 64 bit then also add the following line: -a always,exit -F arch=b64 -S lsetxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the auditd daemon is configured to use the auditctl utility to read audit rules during daemon startup, add the following line to /etc/audit/audit.rules file: -a always,exit -F arch=b32 -S lsetxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the system is 64 bit then also add the following line: -a always,exit -F arch=b64 -S lsetxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod", rationale: "The changing of file permissions could indicate that a user is attempting to gain access to information that would otherwise be disallowed. Auditing DAC modifications can facilitate the identification of patterns of abuse among both authorized and unauthorized users." references: "AC-17(7) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-1(b) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(d) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), IR-5 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), 126 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), 172 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), Req-10.5.5 (https://www.pcisecuritystandards.org/documents/PCI_DSS_v3-1.pdf), 5.2.10 (https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf), SRG-OS-000064-GPOS-00033 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000392-GPOS-00172 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000458-GPOS-00203 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000474-GPOS-00219 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), 5.4.1.1 (https://www.fbi.gov/file-repository/cjis-security-policy-v5_5_20160601-2-1.pdf), 3.1.7 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-171.pdf)", identifiers: "", oval-id: "oval:ssg-audit_rules_dac_modification_lsetxattr:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_common", profile-title: "Common Profile for General-Purpose Systems".
#
# oscap: msg: "xccdf-result", scan-id: "0001600739632", content: "ssg-centos-7-ds.xml", title: "Ensure auditd Collects File Deletion Events by User", id: "xccdf_org.ssgproject.content_rule_audit_rules_file_deletion_events", result: "fail", severity: "medium", description: "At a minimum the audit system should collect file deletion events for all users and root. If the auditd daemon is configured to use the augenrules program to read audit rules during daemon startup (the default), add the following line to a file with suffix .rules in the directory /etc/audit/rules.d, setting ARCH to either b32 or b64 as appropriate for your system: -a always,exit -F arch=ARCH -S rmdiri,unlink,unlinkat,rename,renameat -F auid>=1000 -F auid!=4294967295 -F key=delete If the auditd daemon is configured to use the auditctl utility to read audit rules during daemon startup, add the following line to /etc/audit/audit.rules file, setting ARCH to either b32 or b64 as appropriate for your system: -a always,exit -F arch=ARCH -S rmdir,unlink,unlinkat,rename -S renameat -F auid>=1000 -F auid!=4294967295 -F key=delete", rationale: "Auditing file deletions will create an audit trail for files that are removed from the system. The audit trail could aid in system troubleshooting, as well as, detecting malicious processes that attempt to delete log files to conceal their presence." references: "AC-17(7) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-1(b) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(d) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), IR-5 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), Req-10.2.7 (https://www.pcisecuritystandards.org/documents/PCI_DSS_v3-1.pdf), 5.2.14 (https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf), 366 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), 172 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), 2884 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), 5.4.1.1 (https://www.fbi.gov/file-repository/cjis-security-policy-v5_5_20160601-2-1.pdf), 3.1.7 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-171.pdf)", identifiers: "", oval-id: "oval:ssg-audit_rules_file_deletion_events:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_pci-dss", profile-title: "PCI-DSS v3 Control Baseline for Red Hat Enterprise Linux 7".
#
# oscap: msg: "xccdf-result", scan-id: "0001605230751", content: "ssg-centos-7-ds.xml", title: "Record Events that Modify the System's Mandatory Access Controls", id: "xccdf_org.ssgproject.content_rule_audit_rules_mac_modification", result: "fail", severity: "low", description: "If the auditd daemon is configured to use the augenrules program to read audit rules during daemon startup (the default), add the following line to a file with suffix .rules in the directory /etc/audit/rules.d: -w /etc/selinux/ -p wa -k MAC-policy If the auditd daemon is configured to use the auditctl utility to read audit rules during daemon startup, add the following line to /etc/audit/audit.rules file: -w /etc/selinux/ -p wa -k MAC-policy", rationale: "The system's mandatory access policy (SELinux) should not be arbitrarily changed by anything other than administrator action. All changes to MAC policy should be audited." references: "AC-17(7) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-1(b) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(d) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), IR-5 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), Req-10.5.5 (https://www.pcisecuritystandards.org/documents/PCI_DSS_v3-1.pdf), 5.2.7 (https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf), 5.4.1.1 (https://www.fbi.gov/file-repository/cjis-security-policy-v5_5_20160601-2-1.pdf), 3.1.8 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-171.pdf)", identifiers: "", oval-id: "oval:ssg-audit_rules_mac_modification:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_common", profile-title: "Common Profile for General-Purpose Systems".
#
# oscap: msg: "xccdf-result", scan-id: "0001605570931", content: "ssg-centos-7-ds.xml", title: "Record Events that Modify the System's Discretionary Access Controls - chown", id: "xccdf_org.ssgproject.content_rule_audit_rules_dac_modification_chown", result: "fail", severity: "low", description: "At a minimum, the audit system should collect file permission changes for all users and root. If the auditd daemon is configured to use the augenrules program to read audit rules during daemon startup (the default), add the following line to a file with suffix .rules in the directory /etc/audit/rules.d: -a always,exit -F arch=b32 -S chown -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the system is 64 bit then also add the following line: -a always,exit -F arch=b64 -S chown -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the auditd daemon is configured to use the auditctl utility to read audit rules during daemon startup, add the following line to /etc/audit/audit.rules file: -a always,exit -F arch=b32 -S chown -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the system is 64 bit then also add the following line: -a always,exit -F arch=b64 -S chown -F auid>=1000 -F auid!=4294967295 -F key=perm_mod", rationale: "The changing of file permissions could indicate that a user is attempting to gain access to information that would otherwise be disallowed. Auditing DAC modifications can facilitate the identification of patterns of abuse among both authorized and unauthorized users." references: "AC-17(7) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-1(b) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(d) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), IR-5 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), 126 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), 172 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), Req-10.5.5 (https://www.pcisecuritystandards.org/documents/PCI_DSS_v3-1.pdf), 5.2.10 (https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf), SRG-OS-000064-GPOS-00033 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000392-GPOS-00172 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000458-GPOS-00203 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000474-GPOS-00219 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), 5.4.1.1 (https://www.fbi.gov/file-repository/cjis-security-policy-v5_5_20160601-2-1.pdf), 3.1.7 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-171.pdf)", identifiers: "", oval-id: "oval:ssg-audit_rules_dac_modification_chown:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_common", profile-title: "Common Profile for General-Purpose Systems".
#
# oscap: msg: "xccdf-result", scan-id: "0001601964895", content: "ssg-centos-7-ds.xml", title: "Record Events that Modify the System's Discretionary Access Controls - setxattr", id: "xccdf_org.ssgproject.content_rule_audit_rules_dac_modification_setxattr", result: "fail", severity: "low", description: "At a minimum, the audit system should collect file permission changes for all users and root. If the auditd daemon is configured to use the augenrules program to read audit rules during daemon startup (the default), add the following line to a file with suffix .rules in the directory /etc/audit/rules.d: -a always,exit -F arch=b32 -S setxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the system is 64 bit then also add the following line: -a always,exit -F arch=b64 -S setxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the auditd daemon is configured to use the auditctl utility to read audit rules during daemon startup, add the following line to /etc/audit/audit.rules file: -a always,exit -F arch=b32 -S setxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the system is 64 bit then also add the following line: -a always,exit -F arch=b64 -S setxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod", rationale: "The changing of file permissions could indicate that a user is attempting to gain access to information that would otherwise be disallowed. Auditing DAC modifications can facilitate the identification of patterns of abuse among both authorized and unauthorized users." references: "AC-17(7) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-1(b) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(d) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), IR-5 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), 126 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), 172 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), Req-10.5.5 (https://www.pcisecuritystandards.org/documents/PCI_DSS_v3-1.pdf), 5.2.10 (https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf), SRG-OS-000064-GPOS-00033 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000392-GPOS-00172 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000458-GPOS-00203 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), 5.4.1.1 (https://www.fbi.gov/file-repository/cjis-security-policy-v5_5_20160601-2-1.pdf), 3.1.7 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-171.pdf)", identifiers: "", oval-id: "oval:ssg-audit_rules_dac_modification_setxattr:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_common", profile-title: "Common Profile for General-Purpose Systems".
#
# oscap: msg: "xccdf-result", scan-id: "0001602590405", content: "ssg-centos-7-ds.xml", title: "Ensure auditd Collects Information on the Use of Privileged Commands", id: "xccdf_org.ssgproject.content_rule_audit_rules_privileged_commands", result: "fail", severity: "medium", description: "At a minimum, the audit system should collect the execution of privileged commands for all users and root. To find the relevant setuid / setgid programs, run the following command for each local partition PART: $ sudo find PART -xdev -type f -perm -4000 -o -type f -perm -2000 2>/dev/null If the auditd daemon is configured to use the augenrules program to read audit rules during daemon startup (the default), add a line of the following form to a file with suffix .rules in the directory /etc/audit/rules.d for each setuid / setgid program on the system, replacing the SETUID_PROG_PATH part with the full path of that setuid / setgid program in the list: -a always,exit -F path=SETUID_PROG_PATH -F perm=x -F auid>=1000 -F auid!=4294967295 -F key=privileged If the auditd daemon is configured to use the auditctl utility to read audit rules during daemon startup, add a line of the following form to /etc/audit/audit.rules for each setuid / setgid program on the system, replacing the SETUID_PROG_PATH part with the full path of that setuid / setgid program in the list: -a always,exit -F path=SETUID_PROG_PATH -F perm=x -F auid>=1000 -F auid!=4294967295 -F key=privileged", rationale: "Misuse of privileged functions, either intentionally or unintentionally by authorized users, or by unauthorized external entities that have compromised system accounts, is a serious and ongoing concern and can have significant adverse impacts on organizations. Auditing the use of privileged functions is one way to detect such misuse and identify the risk from insider and advanced persistent threast. Privileged programs are subject to escalation-of-privilege attacks, which attempt to subvert their normal role of providing some necessary but limited capability. As such, motivation exists to monitor these programs for unusual activity." references: "AC-17(7) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-1(b) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(d) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(4) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-6(9) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), IR-5 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), 2234 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), SRG-OS-000327-GPOS-00127 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), Req-10.2.2 (https://www.pcisecuritystandards.org/documents/PCI_DSS_v3-1.pdf), 5.2.10 (https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf), 5.4.1.1 (https://www.fbi.gov/file-repository/cjis-security-policy-v5_5_20160601-2-1.pdf), 3.1.7 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-171.pdf)", identifiers: "", oval-id: "oval:ssg-audit_rules_privileged_commands:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_pci-dss", profile-title: "PCI-DSS v3 Control Baseline for Red Hat Enterprise Linux 7".
#
# oscap: msg: "xccdf-result", scan-id: "0001602230407", content: "ssg-centos-7-ds.xml", title: "Install AIDE", id: "xccdf_org.ssgproject.content_rule_package_aide_installed", result: "fail", severity: "medium", description: "Install the AIDE package with the command: $ sudo yum install aide", rationale: "The AIDE package must be installed if it is to be available for integrity checking." references: "CM-3(d) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), CM-3(e) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), CM-6(d) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), CM-6(3) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), SC-28 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), SI-7 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf),  (http://iase.disa.mil/stigs/cci/Pages/index.aspx), Req-11.5 (https://www.pcisecuritystandards.org/documents/PCI_DSS_v3-1.pdf), 1.3.1 (https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf), 5.10.1.3 (https://www.fbi.gov/file-repository/cjis-security-policy-v5_5_20160601-2-1.pdf)", identifiers: "", oval-id: "oval:ssg-package_aide_installed:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_pci-dss", profile-title: "PCI-DSS v3 Control Baseline for Red Hat Enterprise Linux 7".
#
# oscap: msg: "xccdf-result", scan-id: "0001600739632", content: "ssg-centos-7-ds.xml", title: "Set Password Strength Minimum Lowercase Characters", id: "xccdf_org.ssgproject.content_rule_accounts_password_pam_lcredit", result: "fail", severity: "medium", description: "The pam_pwquality module's lcredit parameter controls requirements for usage of lowercase letters in a password. When set to a negative number, any password will be required to contain that many lowercase characters. When set to a positive number, pam_pwquality will grant +1 additional length credit for each lowercase character. Modify the lcredit setting in /etc/security/pwquality.conf to require the use of a lowercase character in passwords.", rationale: "Use of a complex password helps to increase the time and resources required to compromise the password. Password complexity, or strength, is a measure of the effectiveness of a password in resisting attempts at guessing and brute-force attacks. Password complexity is one factor of several that determines how long it takes to crack a password. The more complex the password, the greater the number of possble combinations that need to be tested before the password is compromised. Requiring a minimum number of lowercase characters makes password guessing attacks more difficult by ensuring a larger search space." references: "IA-5(b) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), IA-5(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), IA-5(1)(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), 193 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), SRG-OS-000070-GPOS-00038 (), Req-8.2.3 (https://www.pcisecuritystandards.org/documents/PCI_DSS_v3-1.pdf)", identifiers: "", oval-id: "oval:ssg-accounts_password_pam_lcredit:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_pci-dss", profile-title: "PCI-DSS v3 Control Baseline for Red Hat Enterprise Linux 7".
#
# oscap: ERROR: Timeout expired.
#
# oscap: msg: "xccdf-result", scan-id: "0001602230710", content: "ssg-centos-7-ds.xml", title: "Record Events that Modify the System's Discretionary Access Controls - lsetxattr", id: "xccdf_org.ssgproject.content_rule_audit_rules_dac_modification_lsetxattr", result: "fail", severity: "low", description: "At a minimum, the audit system should collect file permission changes for all users and root. If the auditd daemon is configured to use the augenrules program to read audit rules during daemon startup (the default), add the following line to a file with suffix .rules in the directory /etc/audit/rules.d: -a always,exit -F arch=b32 -S lsetxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the system is 64 bit then also add the following line: -a always,exit -F arch=b64 -S lsetxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the auditd daemon is configured to use the auditctl utility to read audit rules during daemon startup, add the following line to /etc/audit/audit.rules file: -a always,exit -F arch=b32 -S lsetxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the system is 64 bit then also add the following line: -a always,exit -F arch=b64 -S lsetxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod", rationale: "The changing of file permissions could indicate that a user is attempting to gain access to information that would otherwise be disallowed. Auditing DAC modifications can facilitate the identification of patterns of abuse among both authorized and unauthorized users." references: "AC-17(7) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-1(b) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(d) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), IR-5 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), 126 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), 172 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), Req-10.5.5 (https://www.pcisecuritystandards.org/documents/PCI_DSS_v3-1.pdf), 5.2.10 (https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf), SRG-OS-000064-GPOS-00033 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000392-GPOS-00172 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000458-GPOS-00203 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000474-GPOS-00219 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), 5.4.1.1 (https://www.fbi.gov/file-repository/cjis-security-policy-v5_5_20160601-2-1.pdf), 3.1.7 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-171.pdf)", identifiers: "", oval-id: "oval:ssg-audit_rules_dac_modification_lsetxattr:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_common", profile-title: "Common Profile for General-Purpose Systems".
#
# ...
#
# oscap: msg: "xccdf-result", scan-id: "0001602054006", content: "ssg-centos-7-ds.xml", title: "Record Events that Modify the System's Mandatory Access Controls", id: "xccdf_org.ssgproject.content_rule_audit_rules_mac_modification", result: "fail", severity: "low", description: "If the auditd daemon is configured to use the augenrules program to read audit rules during daemon startup (the default), add the following line to a file with suffix .rules in the directory /etc/audit/rules.d: -w /etc/selinux/ -p wa -k MAC-policy If the auditd daemon is configured to use the auditctl utility to read audit rules during daemon startup, add the following line to /etc/audit/audit.rules file: -w /etc/selinux/ -p wa -k MAC-policy", rationale: "The system's mandatory access policy (SELinux) should not be arbitrarily changed by anything other than administrator action. All changes to MAC policy should be audited." references: "AC-17(7) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-1(b) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(d) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), IR-5 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), Req-10.5.5 (https://www.pcisecuritystandards.org/documents/PCI_DSS_v3-1.pdf), 5.2.7 (https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf), 5.4.1.1 (https://www.fbi.gov/file-repository/cjis-security-policy-v5_5_20160601-2-1.pdf), 3.1.8 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-171.pdf)", identifiers: "", oval-id: "oval:ssg-audit_rules_mac_modification:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_pci-dss", profile-title: "PCI-DSS v3 Control Baseline for Red Hat Enterprise Linux 7".
#
# oscap: msg: "xccdf-result", scan-id: "0001600739632", content: "ssg-centos-7-ds.xml", title: "Set Lockout Time For Failed Password Attempts", id: "xccdf_org.ssgproject.content_rule_accounts_passwords_pam_faillock_unlock_time", result: "fail", severity: "medium", description: "To configure the system to lock out accounts after a number of incorrect login attempts and require an administrator to unlock the account using pam_faillock.so, modify the content of both /etc/pam.d/system-auth and /etc/pam.d/password-auth as follows: add the following line immediately before the pam_unix.so statement in the AUTH section: auth required pam_faillock.so preauth silent deny= unlock_time= fail_interval= add the following line immediately after the pam_unix.so statement in the AUTH section: auth [default=die] pam_faillock.so authfail deny= unlock_time= fail_interval= add the following line immediately before the pam_unix.so statement in the ACCOUNT section: account required pam_faillock.so", rationale: "Locking out user accounts after a number of incorrect attempts prevents direct password guessing attacks. Ensuring that an administrator is involved in unlocking locked accounts draws appropriate attention to such situations." references: "AC-7(b) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), 002238 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), SRG-OS-000329-GPOS-00128 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000021-GPOS-00005 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), Req-8.1.7 (https://www.pcisecuritystandards.org/documents/PCI_DSS_v3-1.pdf), 6.3.3 (https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf), 5.5.3 (https://www.fbi.gov/file-repository/cjis-security-policy-v5_5_20160601-2-1.pdf), 3.1.8 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-171.pdf)", identifiers: "", oval-id: "oval:ssg-accounts_passwords_pam_faillock_unlock_time:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_pci-dss", profile-title: "PCI-DSS v3 Control Baseline for Red Hat Enterprise Linux 7".
#
# oscap: msg: "xccdf-result", scan-id: "0001601964695", content: "ssg-centos-7-ds.xml", title: "Set Password Strength Minimum Lowercase Characters", id: "xccdf_org.ssgproject.content_rule_accounts_password_pam_lcredit", result: "fail", severity: "medium", description: "The pam_pwquality module's lcredit parameter controls requirements for usage of lowercase letters in a password. When set to a negative number, any password will be required to contain that many lowercase characters. When set to a positive number, pam_pwquality will grant +1 additional length credit for each lowercase character. Modify the lcredit setting in /etc/security/pwquality.conf to require the use of a lowercase character in passwords.", rationale: "Use of a complex password helps to increase the time and resources required to compromise the password. Password complexity, or strength, is a measure of the effectiveness of a password in resisting attempts at guessing and brute-force attacks. Password complexity is one factor of several that determines how long it takes to crack a password. The more complex the password, the greater the number of possble combinations that need to be tested before the password is compromised. Requiring a minimum number of lowercase characters makes password guessing attacks more difficult by ensuring a larger search space." references: "IA-5(b) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), IA-5(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), IA-5(1)(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), 193 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), SRG-OS-000070-GPOS-00038 (), Req-8.2.3 (https://www.pcisecuritystandards.org/documents/PCI_DSS_v3-1.pdf)", identifiers: "", oval-id: "oval:ssg-accounts_password_pam_lcredit:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_pci-dss", profile-title: "PCI-DSS v3 Control Baseline for Red Hat Enterprise Linux 7".
#
# oscap: msg: "xccdf-result", scan-id: "0001602054310", content: "ssg-centos-7-ds.xml", title: "Record Events that Modify the System's Discretionary Access Controls - lsetxattr", id: "xccdf_org.ssgproject.content_rule_audit_rules_dac_modification_lsetxattr", result: "fail", severity: "low", description: "At a minimum, the audit system should collect file permission changes for all users and root. If the auditd daemon is configured to use the augenrules program to read audit rules during daemon startup (the default), add the following line to a file with suffix .rules in the directory /etc/audit/rules.d: -a always,exit -F arch=b32 -S lsetxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the system is 64 bit then also add the following line: -a always,exit -F arch=b64 -S lsetxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the auditd daemon is configured to use the auditctl utility to read audit rules during daemon startup, add the following line to /etc/audit/audit.rules file: -a always,exit -F arch=b32 -S lsetxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the system is 64 bit then also add the following line: -a always,exit -F arch=b64 -S lsetxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod", rationale: "The changing of file permissions could indicate that a user is attempting to gain access to information that would otherwise be disallowed. Auditing DAC modifications can facilitate the identification of patterns of abuse among both authorized and unauthorized users." references: "AC-17(7) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-1(b) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(d) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), IR-5 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), 126 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), 172 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), Req-10.5.5 (https://www.pcisecuritystandards.org/documents/PCI_DSS_v3-1.pdf), 5.2.10 (https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf), SRG-OS-000064-GPOS-00033 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000392-GPOS-00172 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000458-GPOS-00203 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000474-GPOS-00219 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), 5.4.1.1 (https://www.fbi.gov/file-repository/cjis-security-policy-v5_5_20160601-2-1.pdf), 3.1.7 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-171.pdf)", identifiers: "", oval-id: "oval:ssg-audit_rules_dac_modification_lsetxattr:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_common", profile-title: "Common Profile for General-Purpose Systems".
#
# oscap: msg: "xccdf-result", scan-id: "0001608093142", content: "ssg-centos-7-ds.xml", title: "Set Password Strength Minimum Uppercase Characters", id: "xccdf_org.ssgproject.content_rule_accounts_password_pam_ucredit", result: "fail", severity: "medium", description: "The pam_pwquality module's ucredit= parameter controls requirements for usage of uppercase letters in a password. When set to a negative number, any password will be required to contain that many uppercase characters. When set to a positive number, pam_pwquality will grant +1 additional length credit for each uppercase character. Modify the ucredit setting in /etc/security/pwquality.conf to require the use of an uppercase character in passwords.", rationale: "Use of a complex password helps to increase the time and resources reuiqred to compromise the password. Password complexity, or strength, is a measure of the effectiveness of a password in resisting attempts at guessing and brute-force attacks. Password complexity is one factor of several that determines how long it takes to crack a password. The more complex the password, the greater the number of possible combinations that need to be tested before the password is compromised." references: "IA-5(b) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), IA-5(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), IA-5(1)(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), 192 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), SRG-OS-000069-GPOS-00037 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), Req-8.2.3 (https://www.pcisecuritystandards.org/documents/PCI_DSS_v3-1.pdf), 6.3.2 (https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf)", identifiers: "", oval-id: "oval:ssg-accounts_password_pam_ucredit:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_pci-dss", profile-title: "PCI-DSS v3 Control Baseline for Red Hat Enterprise Linux 7".
#
# oscap: msg: "xccdf-result", scan-id: "0001602230407", content: "ssg-centos-7-ds.xml", title: "Record Events that Modify the System's Discretionary Access Controls - lsetxattr", id: "xccdf_org.ssgproject.content_rule_audit_rules_dac_modification_lsetxattr", result: "fail", severity: "low", description: "At a minimum, the audit system should collect file permission changes for all users and root. If the auditd daemon is configured to use the augenrules program to read audit rules during daemon startup (the default), add the following line to a file with suffix .rules in the directory /etc/audit/rules.d: -a always,exit -F arch=b32 -S lsetxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the system is 64 bit then also add the following line: -a always,exit -F arch=b64 -S lsetxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the auditd daemon is configured to use the auditctl utility to read audit rules during daemon startup, add the following line to /etc/audit/audit.rules file: -a always,exit -F arch=b32 -S lsetxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod If the system is 64 bit then also add the following line: -a always,exit -F arch=b64 -S lsetxattr -F auid>=1000 -F auid!=4294967295 -F key=perm_mod", rationale: "The changing of file permissions could indicate that a user is attempting to gain access to information that would otherwise be disallowed. Auditing DAC modifications can facilitate the identification of patterns of abuse among both authorized and unauthorized users." references: "AC-17(7) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-1(b) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-2(d) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(a) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), AU-12(c) (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), IR-5 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-53r4.pdf), 126 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), 172 (http://iase.disa.mil/stigs/cci/Pages/index.aspx), Req-10.5.5 (https://www.pcisecuritystandards.org/documents/PCI_DSS_v3-1.pdf), 5.2.10 (https://benchmarks.cisecurity.org/tools2/linux/CIS_Red_Hat_Enterprise_Linux_7_Benchmark_v1.1.0.pdf), SRG-OS-000064-GPOS-00033 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000392-GPOS-00172 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000458-GPOS-00203 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), SRG-OS-000474-GPOS-00219 (http://iase.disa.mil/stigs/srgs/Pages/index.aspx), 5.4.1.1 (https://www.fbi.gov/file-repository/cjis-security-policy-v5_5_20160601-2-1.pdf), 3.1.7 (http://nvlpubs.nist.gov/nistpubs/SpecialPublications/NIST.SP.800-171.pdf)", identifiers: "", oval-id: "oval:ssg-audit_rules_dac_modification_lsetxattr:def:1", benchmark-id: "xccdf_org.ssgproject.content_benchmark_RHEL-7", profile-id: "xccdf_org.ssgproject.content_profile_pci-dss", profile-title: "PCI-DSS v3 Control Baseline for Red Hat Enterprise Linux 7".

# %%
log_oscap = groups.get_group('oscap:').copy()

# %%
log_oscap['title'] = log_oscap['full_log'].str.extract('title: "(.+?)"')
log_oscap
# Out:
#         level                                           full_log first_word  \
# id
# 3396        3  oscap: msg: "xccdf-result", scan-id: "00016030...     oscap:
# 3661        3  oscap: msg: "xccdf-result", scan-id: "00016020...     oscap:
# 5658        5  oscap: msg: "xccdf-result", scan-id: "00016030...     oscap:
# 5695        5  oscap: msg: "xccdf-result", scan-id: "00016019...     oscap:
# 7206        3  oscap: msg: "xccdf-result", scan-id: "00016052...     oscap:
# ...       ...                                                ...        ...
# 466619      5  oscap: msg: "xccdf-result", scan-id: "00016007...     oscap:
# 467561      5  oscap: msg: "xccdf-result", scan-id: "00016019...     oscap:
# 468063      3  oscap: msg: "xccdf-result", scan-id: "00016020...     oscap:
# 468233      5  oscap: msg: "xccdf-result", scan-id: "00016080...     oscap:
# 471969      3  oscap: msg: "xccdf-result", scan-id: "00016022...     oscap:
#
#                                                     title
# id
# 3396    Record Events that Modify the System's Discret...
# 3661    Record Events that Modify the System's Discret...
# 5658    Ensure auditd Collects Information on the Use ...
# 5695    Record Events that Modify the System's Discret...
# 7206    Record Events that Modify the System's Discret...
# ...                                                   ...
# 466619      Set Lockout Time For Failed Password Attempts
# 467561  Set Password Strength Minimum Lowercase Charac...
# 468063  Record Events that Modify the System's Discret...
# 468233  Set Password Strength Minimum Uppercase Charac...
# 471969  Record Events that Modify the System's Discret...
#
# [366 rows x 4 columns]

# %%
log_oscap['title'].value_counts()
# Out:
# Record Events that Modify the System's Discretionary Access Controls - fchmod          16
# Ensure auditd Collects System Administrator Actions                                    15
# Ensure auditd Collects Information on the Use of Privileged Commands                   12
# Record Events that Modify the System's Discretionary Access Controls - setxattr        12
# Record Events that Modify the System's Network Environment                             11
# Record Events that Modify the System's Discretionary Access Controls - lchown          11
# Record attempts to alter time through settimeofday                                     11
# Record Events that Modify the System's Discretionary Access Controls - lsetxattr       10
# Record Events that Modify the System's Discretionary Access Controls - fremovexattr    10
# Record Attempts to Alter the localtime File                                            10
# Ensure auditd Collects Unauthorized Access Attempts to Files (unsuccessful)            10
# Ensure auditd Collects Information on Kernel Module Loading and Unloading              10
# Record Events that Modify the System's Discretionary Access Controls - fchown          10
# Ensure auditd Collects File Deletion Events by User                                     9
# Record Events that Modify the System's Discretionary Access Controls - fsetxattr        8
# Record Events that Modify the System's Discretionary Access Controls - removexattr      8
# Record Attempts to Alter Time Through clock_settime                                     8
# Set SSH Idle Timeout Interval                                                           7
# Record Events that Modify the System's Discretionary Access Controls - fchownat         7
# Record Events that Modify the System's Discretionary Access Controls - fchmodat         7
# Verify /boot/grub2/grub.cfg User Ownership                                              6
# Record Events that Modify the System's Discretionary Access Controls - chown            6
# Set Password Strength Minimum Uppercase Characters                                      6
# Set Password Maximum Age                                                                6
# Record Events that Modify User/Group Information                                        6
# Ensure auditd Collects Information on Exporting to Media (successful)                   6
# Enable GNOME3 Screensaver Lock After Idle Period                                        6
# Record Events that Modify the System's Mandatory Access Controls                        6
# Set Password Strength Minimum Lowercase Characters                                      6
# Record Events that Modify the System's Discretionary Access Controls - chmod            6
# Record attempts to alter time through adjtimex                                          6
# Enable Smart Card Login                                                                 6
# Configure auditd admin_space_left Action on Low Disk Space                              5
# Verify /boot/grub2/grub.cfg Group Ownership                                             5
# Set Password Minimum Length                                                             5
# Disable Automatic Bug Reporting Tool (abrtd)                                            5
# Enable GNOME3 Screensaver Idle Activation                                               5
# Record Events that Modify the System's Discretionary Access Controls - lremovexattr     5
# Configure Periodic Execution of AIDE                                                    5
# Set Password Strength Minimum Digit Characters                                          5
# Set GNOME3 Screensaver Inactivity Timeout                                               5
# Limit Password Reuse                                                                    4
# Implement Blank Screensaver                                                             4
# Make the auditd Configuration Immutable                                                 4
# Configure auditd to use audispd's syslog plugin                                         4
# Ensure Logrotate Runs Periodically                                                      4
# Configure auditd space_left Action on Low Disk Space                                    4
# Ensure /var/log/audit Located On Separate Partition                                     3
# Record Attempts to Alter Process and Session Initiation Information                     3
# Ensure /var/log Located On Separate Partition                                           3
# Install AIDE                                                                            2
# Common Profile for General-Purpose Systems                                              2
# Set Deny For Failed Password Attempts                                                   2
# Set Lockout Time For Failed Password Attempts                                           2
# Record Attempts to Alter Logon and Logout Events                                        2
# PCI-DSS v3 Control Baseline for Red Hat Enterprise Linux 7                              2
# Disable At Service (atd)                                                                1
# Name: title, dtype: int64

# %%
log_oscap.pivot_table(values='full_log', index='title', columns='level', aggfunc='count', fill_value=0)
# Out:
# level                                                3   5
# title
# Common Profile for General-Purpose Systems           0   2
# Configure Periodic Execution of AIDE                 0   5
# Configure auditd admin_space_left Action on Low...   0   5
# Configure auditd space_left Action on Low Disk ...   0   4
# Configure auditd to use audispd's syslog plugin      0   4
# Disable At Service (atd)                             1   0
# Disable Automatic Bug Reporting Tool (abrtd)         5   0
# Enable GNOME3 Screensaver Idle Activation            0   5
# Enable GNOME3 Screensaver Lock After Idle Period     0   6
# Enable Smart Card Login                              0   6
# Ensure /var/log Located On Separate Partition        3   0
# Ensure /var/log/audit Located On Separate Parti...   3   0
# Ensure Logrotate Runs Periodically                   4   0
# Ensure auditd Collects File Deletion Events by ...   0   9
# Ensure auditd Collects Information on Exporting...   0   6
# Ensure auditd Collects Information on Kernel Mo...   0  10
# Ensure auditd Collects Information on the Use o...   0  12
# Ensure auditd Collects System Administrator Act...  15   0
# Ensure auditd Collects Unauthorized Access Atte...   0  10
# Implement Blank Screensaver                          4   0
# Install AIDE                                         0   2
# Limit Password Reuse                                 0   4
# Make the auditd Configuration Immutable              0   4
# PCI-DSS v3 Control Baseline for Red Hat Enterpr...   2   0
# Record Attempts to Alter Logon and Logout Events     0   2
# Record Attempts to Alter Process and Session In...   3   0
# Record Attempts to Alter Time Through clock_set...   8   0
# Record Attempts to Alter the localtime File         10   0
# Record Events that Modify User/Group Information     6   0
# Record Events that Modify the System's Discreti...   6   0
# Record Events that Modify the System's Discreti...   6   0
# Record Events that Modify the System's Discreti...  16   0
# Record Events that Modify the System's Discreti...   7   0
# Record Events that Modify the System's Discreti...  10   0
# Record Events that Modify the System's Discreti...   7   0
# Record Events that Modify the System's Discreti...   0  10
# Record Events that Modify the System's Discreti...   8   0
# Record Events that Modify the System's Discreti...  11   0
# Record Events that Modify the System's Discreti...   0   5
# Record Events that Modify the System's Discreti...  10   0
# Record Events that Modify the System's Discreti...   0   8
# Record Events that Modify the System's Discreti...  12   0
# Record Events that Modify the System's Mandator...   6   0
# Record Events that Modify the System's Network ...  11   0
# Record attempts to alter time through adjtimex       6   0
# Record attempts to alter time through settimeofday  11   0
# Set Deny For Failed Password Attempts                0   2
# Set GNOME3 Screensaver Inactivity Timeout            0   5
# Set Lockout Time For Failed Password Attempts        0   2
# Set Password Maximum Age                             0   6
# Set Password Minimum Length                          0   5
# Set Password Strength Minimum Digit Characters       0   5
# Set Password Strength Minimum Lowercase Characters   0   6
# Set Password Strength Minimum Uppercase Characters   0   6
# Set SSH Idle Timeout Interval                        7   0
# Verify /boot/grub2/grub.cfg Group Ownership          0   5
# Verify /boot/grub2/grub.cfg User Ownership           0   6

# %% [markdown]
# ## error:

# %%
groups.get_group('error:')
# Out:
#         level                                           full_log first_word
# id
# 585         0  error: cannot open Packages index using db5 - ...     error:
# 871         0  error: cannot open Packages index using db5 - ...     error:
# 992         0  error: db5 error(-30973) from dbenv->failchk: ...     error:
# 2638        0           error: cannot open Packages database in      error:
# 3613        0  error: cannot open Packages index using db5 - ...     error:
# ...       ...                                                ...        ...
# 464123      0           error: cannot open Packages database in      error:
# 467463      0  error: rpmdb: BDB0113 Thread/process 26357/140...     error:
# 467518      0  error: rpmdb: BDB0113 Thread/process 26357/140...     error:
# 468068      0           error: cannot open Packages database in      error:
# 470271      0  error: rpmdb: BDB0113 Thread/process 26357/140...     error:
#
# [459 rows x 3 columns]

# %%
groups.get_group('error:')['level'].value_counts()
# Out:
# 0    459
# Name: level, dtype: int64

# %%
groups.get_group('error:')['full_log'].value_counts()
# Out:
# error: cannot open Packages database in                                                                          138
# error: db5 error(-30973) from dbenv->failchk: BDB0087 DB_RUNRECOVERY: Fatal error, run database recovery         132
# error: rpmdb: BDB0113 Thread/process 26357/140408208971520 failed: BDB1507 Thread died in Berkeley DB library    123
# error: cannot open Packages index using db5 -  (-30973)                                                           45
# error: rpmdb: BDB0113 Thread/process 13362/139912875566848 failed: BDB1507 Thread died in Berkeley DB library     18
# error: rpmdb: BDB0113 Thread/process 30478/140432988804864 failed: BDB1507 Thread died in Berkeley DB library      2
# error: rpmdb: BDB0113 Thread/process 22079/139845236422400 failed: BDB1507 Thread died in Berkeley DB library      1
# Name: full_log, dtype: int64

# %% [markdown]
# ## ossec:

# %%
groups.get_group('ossec:')
# Out:
#         level                                           full_log first_word
# id
# 590         5  ossec: output: 'netstat listening ports':\ntcp...     ossec:
# 621         5  ossec: output: 'netstat listening ports':\ntcp...     ossec:
# 870         5  ossec: output: 'netstat listening ports':\ntcp...     ossec:
# 1853        5  ossec: output: 'netstat listening ports':\ntcp...     ossec:
# 1877        5  ossec: output: 'netstat listening ports':\ntcp...     ossec:
# ...       ...                                                ...        ...
# 471468      5  ossec: output: 'netstat listening ports':\ntcp...     ossec:
# 471837      5  ossec: output: 'netstat listening ports':\ntcp...     ossec:
# 471864      5  ossec: output: 'netstat listening ports':\ntcp...     ossec:
# 472400      5  ossec: output: 'netstat listening ports':\ntcp...     ossec:
# 472662      5  ossec: output: 'netstat listening ports':\ntcp...     ossec:
#
# [1318 rows x 3 columns]

# %%
groups.get_group('ossec:')['level'].value_counts()
# Out:
# 5    1289
# 1      29
# Name: level, dtype: int64

# %%
log_ossec = groups.get_group('ossec:').copy()

# %%
log_ossec[log_ossec['level']==1]
# Out:
#         level                                           full_log first_word
# id
# 17817       1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 55922       1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 64931       1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 95525       1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 109160      1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 117075      1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 127872      1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 132274      1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 139846      1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 139915      1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 158117      1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 204852      1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 219273      1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 237806      1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 238067      1  ossec: Agent started: 'Solaris-46->192.168.0.46'.     ossec:
# 247533      1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 261631      1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 263417      1      ossec: Agent started: 'sjlee->192.168.0.189'.     ossec:
# 326077      1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 326379      1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 350395      1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 363981      1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 364235      1  ossec: Agent started: 'TTA_HP-UX11.31_Itanium-...     ossec:
# 371359      1      ossec: Agent started: 'tukim->192.168.0.181'.     ossec:
# 409562      1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 410161      1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 411699      1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 423675      1  ossec: File rotated (inode changed): '/var/log...     ossec:
# 445988      1  ossec: Agent started: 'Windows10->192.168.0.190'.     ossec:

# %%
log_ossec[log_ossec['level']==1]['full_log'].value_counts()
# Out:
# ossec: File rotated (inode changed): '/var/log/suricata/eve.json'.    8
# ossec: File rotated (inode changed): '/var/log/audit/audit.log'.      8
# ossec: File rotated (inode changed): '/var/log/maillog'.              3
# ossec: File rotated (inode changed): '/var/log/secure'.               3
# ossec: File rotated (inode changed): '/var/log/messages'.             2
# ossec: Agent started: 'Solaris-46->192.168.0.46'.                     1
# ossec: Agent started: 'TTA_HP-UX11.31_Itanium->211.253.243.71'.       1
# ossec: Agent started: 'sjlee->192.168.0.189'.                         1
# ossec: Agent started: 'Windows10->192.168.0.190'.                     1
# ossec: Agent started: 'tukim->192.168.0.181'.                         1
# Name: full_log, dtype: int64

# %%
log_ossec[log_ossec['level']==5]
# Out:
#         level                                           full_log first_word
# id
# 590         5  ossec: output: 'netstat listening ports':\ntcp...     ossec:
# 621         5  ossec: output: 'netstat listening ports':\ntcp...     ossec:
# 870         5  ossec: output: 'netstat listening ports':\ntcp...     ossec:
# 1853        5  ossec: output: 'netstat listening ports':\ntcp...     ossec:
# 1877        5  ossec: output: 'netstat listening ports':\ntcp...     ossec:
# ...       ...                                                ...        ...
# 471468      5  ossec: output: 'netstat listening ports':\ntcp...     ossec:
# 471837      5  ossec: output: 'netstat listening ports':\ntcp...     ossec:
# 471864      5  ossec: output: 'netstat listening ports':\ntcp...     ossec:
# 472400      5  ossec: output: 'netstat listening ports':\ntcp...     ossec:
# 472662      5  ossec: output: 'netstat listening ports':\ntcp...     ossec:
#
# [1289 rows x 3 columns]

# %%
log_ossec['full_log'].str.extract("output: '(.+?)'").value_counts()
# Out:
# netstat listening ports    1289
# dtype: int64

# %% [markdown]
# ## type=USER_AVC

# %%
groups.get_group('type=USER_AVC')
# Out:
#         level                                           full_log  \
# id
# 10516       1  type=USER_AVC msg=audit(1603070359.442:167): p...
# 110767      1  type=USER_AVC msg=audit(1605233330.597:600): p...
# 339998      1  type=USER_AVC msg=audit(1613363937.137:2481): ...
#
#            first_word
# id
# 10516   type=USER_AVC
# 110767  type=USER_AVC
# 339998  type=USER_AVC

# %%
show_all('type=USER_AVC')
# Out:
# type=USER_AVC msg=audit(1603070359.442:167): pid=820 uid=81 auid=4294967295 ses=4294967295 subj=system_u:system_r:system_dbusd_t:s0-s0:c0.c1023 msg='avc:  denied  { send_msg } for msgtype=method_return dest=:1.69 spid=815 tpid=7464 scontext=system_u:system_r:systemd_logind_t:s0 tcontext=system_u:system_r:httpd_t:s0 tclass=dbus  exe="/usr/bin/dbus-daemon" sauid=81 hostname=? addr=? terminal=?'
#
# type=USER_AVC msg=audit(1605233330.597:600): pid=831 uid=81 auid=4294967295 ses=4294967295 subj=system_u:system_r:system_dbusd_t:s0-s0:c0.c1023 msg='avc:  denied  { send_msg } for msgtype=method_return dest=:1.187 spid=890 tpid=10423 scontext=system_u:system_r:systemd_logind_t:s0 tcontext=system_u:system_r:httpd_t:s0 tclass=dbus  exe="/usr/bin/dbus-daemon" sauid=81 hostname=? addr=? terminal=?'
#
# type=USER_AVC msg=audit(1613363937.137:2481): pid=813 uid=81 auid=4294967295 ses=4294967295 subj=system_u:system_r:system_dbusd_t:s0-s0:c0.c1023 msg='avc:  denied  { send_msg } for msgtype=method_call interface=org.freedesktop.login1.Manager member=CreateSession dest=org.freedesktop.login1 spid=30614 tpid=860 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:system_r:systemd_logind_t:s0 tclass=dbus  exe="/usr/bin/dbus-daemon" sauid=81 hostname=? addr=? terminal=?'

# %% [markdown]
# ## type=AVC

# %%
groups.get_group('type=AVC')
# Out:
#         level                                           full_log first_word
# id
# 171         1  type=AVC msg=audit(1613366627.272:4960): avc: ...   type=AVC
# 205         1  type=AVC msg=audit(1608016269.687:144817): avc...   type=AVC
# 288         1  type=AVC msg=audit(1608012869.400:142921): avc...   type=AVC
# 365         1  type=AVC msg=audit(1613362948.863:2329): avc: ...   type=AVC
# 1490        1  type=AVC msg=audit(1608009012.412:140705): avc...   type=AVC
# ...       ...                                                ...        ...
# 463717      1  type=AVC msg=audit(1613364043.098:3757): avc: ...   type=AVC
# 467401      1  type=AVC msg=audit(1600740224.421:52502): avc:...   type=AVC
# 470305      1  type=AVC msg=audit(1602655801.484:113985): avc...   type=AVC
# 471284      1  type=AVC msg=audit(1610086680.367:53452): avc:...   type=AVC
# 471474      1  type=AVC msg=audit(1612255548.408:81): avc:  d...   type=AVC
#
# [369 rows x 3 columns]

# %%
groups.get_group('type=AVC')['level'].value_counts()
# Out:
# 1    369
# Name: level, dtype: int64

# %%
for log in groups.get_group('type=AVC')['full_log'][:100]:
    print(log, '\n')
# Out:
# type=AVC msg=audit(1613366627.272:4960): avc:  denied  { execute } for  pid=10016 comm="sudo" name="agent_control" dev="dm-0" ino=404839312 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=AVC msg=audit(1613366627.272:4960): avc:  denied  { read open } for  pid=10016 comm="sudo" path="/var/esild/bin/agent_control" dev="dm-0" ino=404839312 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=AVC msg=audit(1613366627.272:4960): avc:  denied  { execute_no_trans } for  pid=10016 comm="sudo" path="/var/esild/bin/agent_control" dev="dm-0" ino=404839312 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1613366627.272:4960): arch=c000003e syscall=59 success=yes exit=0 a0=55936cea74e8 a1=55936cea11d8 a2=55936cec57f0 a3=5 items=0 ppid=9939 pid=10016 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="agent_control" exe="/var/esild/bin/agent_control" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1613366627.272:4960): proctitle=2F7661722F6573696C642F62696E2F6167656E745F636F6E74726F6C002D6C630073656400732F4167656E74204E616D653A2F2F
#
# type=AVC msg=audit(1608016269.687:144817): avc:  denied  { getattr } for  pid=4667 comm="unix_chkpwd" path="/etc/shadow" dev="dm-0" ino=271194262 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:shadow_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1608016269.687:144817): arch=c000003e syscall=5 success=yes exit=0 a0=3 a1=7ffc57f0f0c0 a2=7ffc57f0f0c0 a3=0 items=0 ppid=4663 pid=4667 auid=4294967295 uid=0 gid=48 euid=0 suid=0 fsuid=0 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="unix_chkpwd" exe="/usr/sbin/unix_chkpwd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608016269.687:144817): proctitle=2F7573722F7362696E2F756E69785F63686B707764006170616368650063686B657870697279
#
# type=AVC msg=audit(1608012869.400:142921): avc:  denied  { name_connect } for  pid=17783 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1608012869.400:142921): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7f924669f190 a2=1c a3=a items=0 ppid=1270 pid=17783 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608012869.400:142921): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1613362948.863:2329): avc:  denied  { name_connect } for  pid=13304 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1613362948.863:2329): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7faf727f1190 a2=1c a3=a items=0 ppid=1465 pid=13304 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1613362948.863:2329): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1608009012.412:140705): avc:  denied  { name_connect } for  pid=29196 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1608009012.412:140705): arch=c000003e syscall=42 success=no exit=-115 a0=14 a1=7f923effa190 a2=1c a3=a items=0 ppid=1270 pid=29196 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608009012.412:140705): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1613366403.657:4879): avc:  denied  { execute } for  pid=5940 comm="sudo" name="agent_control" dev="dm-0" ino=404839312 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=AVC msg=audit(1613366403.657:4879): avc:  denied  { read open } for  pid=5940 comm="sudo" path="/var/esild/bin/agent_control" dev="dm-0" ino=404839312 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=AVC msg=audit(1613366403.657:4879): avc:  denied  { execute_no_trans } for  pid=5940 comm="sudo" path="/var/esild/bin/agent_control" dev="dm-0" ino=404839312 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1613366403.657:4879): arch=c000003e syscall=59 success=yes exit=0 a0=563b4115a4e8 a1=563b411541d8 a2=563b411787a0 a3=5 items=0 ppid=5918 pid=5940 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="agent_control" exe="/var/esild/bin/agent_control" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1613366403.657:4879): proctitle=7375646F002F7661722F6573696C642F62696E2F6167656E745F636F6E74726F6C002D6900303333
#
# type=AVC msg=audit(1608015394.408:143265): avc:  denied  { name_connect } for  pid=31265 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1608015394.408:143265): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7f923c7f5190 a2=1c a3=a items=0 ppid=1270 pid=31265 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608015394.408:143265): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1608018737.651:145391): avc:  denied  { nlmsg_relay } for  pid=10424 comm="sudo" scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:system_r:httpd_t:s0 tclass=netlink_audit_socket permissive=1 type=AVC msg=audit(1608018737.651:145391): avc:  denied  { audit_write } for  pid=10424 comm="sudo" capability=29  scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:system_r:httpd_t:s0 tclass=capability permissive=1
#
# type=AVC msg=audit(1608015994.427:143391): avc:  denied  { name_connect } for  pid=866 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1608015994.427:143391): arch=c000003e syscall=42 success=no exit=-115 a0=13 a1=7f923d7f7190 a2=1c a3=a items=0 ppid=1270 pid=866 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608015994.427:143391): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1603070359.334:161): avc:  denied  { getattr } for  pid=7471 comm="unix_chkpwd" path="/etc/shadow" dev="dm-0" ino=271194262 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:shadow_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1603070359.334:161): arch=c000003e syscall=5 success=yes exit=0 a0=3 a1=7ffc1b5b4780 a2=7ffc1b5b4780 a3=0 items=0 ppid=7464 pid=7471 auid=4294967295 uid=0 gid=48 euid=0 suid=0 fsuid=0 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="unix_chkpwd" exe="/usr/sbin/unix_chkpwd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1603070359.334:161): proctitle=2F7573722F7362696E2F756E69785F63686B707764006170616368650063686B657870697279
#
# type=AVC msg=audit(1600736999.389:51981): avc:  denied  { name_connect } for  pid=26185 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1600736999.389:51981): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7f8467aa0190 a2=1c a3=a items=0 ppid=4007 pid=26185 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1600736999.389:51981): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1610085436.666:53175): avc:  denied  { read } for  pid=19969 comm="unix_chkpwd" name="shadow" dev="dm-0" ino=271194262 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:shadow_t:s0 tclass=file permissive=1 type=AVC msg=audit(1610085436.666:53175): avc:  denied  { open } for  pid=19969 comm="unix_chkpwd" path="/etc/shadow" dev="dm-0" ino=271194262 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:shadow_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1610085436.666:53175): arch=c000003e syscall=2 success=yes exit=3 a0=7fc2d81b5573 a1=80000 a2=1b6 a3=24 items=0 ppid=19968 pid=19969 auid=4294967295 uid=0 gid=48 euid=0 suid=0 fsuid=0 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="unix_chkpwd" exe="/usr/sbin/unix_chkpwd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1610085436.666:53175): proctitle=2F7573722F7362696E2F756E69785F63686B707764006170616368650063686B657870697279
#
# type=AVC msg=audit(1602655732.305:111379): avc:  denied  { getattr } for  pid=5287 comm="unix_chkpwd" path="/etc/shadow" dev="dm-0" ino=271194262 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:shadow_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1602655732.305:111379): arch=c000003e syscall=5 success=yes exit=0 a0=3 a1=7ffd08a116e0 a2=7ffd08a116e0 a3=0 items=0 ppid=5283 pid=5287 auid=4294967295 uid=0 gid=48 euid=0 suid=0 fsuid=0 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="unix_chkpwd" exe="/usr/sbin/unix_chkpwd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1602655732.305:111379): proctitle=2F7573722F7362696E2F756E69785F63686B707764006170616368650063686B657870697279
#
# type=AVC msg=audit(1600411630.262:5917): avc:  denied  { nlmsg_relay } for  pid=3314 comm="sudo" scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:system_r:httpd_t:s0 tclass=netlink_audit_socket permissive=1 type=AVC msg=audit(1600411630.262:5917): avc:  denied  { audit_write } for  pid=3314 comm="sudo" capability=29  scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:system_r:httpd_t:s0 tclass=capability permissive=1
#
# type=AVC msg=audit(1613366705.881:5163): avc:  denied  { nlmsg_relay } for  pid=10888 comm="sudo" scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:system_r:httpd_t:s0 tclass=netlink_audit_socket permissive=1 type=AVC msg=audit(1613366705.881:5163): avc:  denied  { audit_write } for  pid=10888 comm="sudo" capability=29  scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:system_r:httpd_t:s0 tclass=capability permissive=1
#
# type=AVC msg=audit(1600661602.802:41313): avc:  denied  { name_connect } for  pid=26185 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1600661602.802:41313): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7f845cff6190 a2=1c a3=a items=0 ppid=4007 pid=26185 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1600661602.802:41313): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1608009147.118:140948): avc:  denied  { getattr } for  pid=18230 comm="sudo" path="/var/esild/bin/agent_control" dev="dm-0" ino=404839312 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1608009147.118:140948): arch=c000003e syscall=4 success=yes exit=0 a0=7ffffd3852b0 a1=5632d71c5200 a2=5632d71c5200 a3=7f6841239300 items=0 ppid=18229 pid=18230 auid=4294967295 uid=48 gid=48 euid=0 suid=0 fsuid=0 egid=0 sgid=48 fsgid=0 tty=(none) ses=4294967295 comm="sudo" exe="/usr/bin/sudo" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608009147.118:140948): proctitle=7375646F002F7661722F6573696C642F62696E2F6167656E745F636F6E74726F6C002D6900303233
#
# type=AVC msg=audit(1608016300.579:144832): avc:  denied  { read } for  pid=4758 comm="cat" name="ossec.conf" dev="dm-0" ino=138069976 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=AVC msg=audit(1608016300.579:144832): avc:  denied  { open } for  pid=4758 comm="cat" path="/var/esild/etc/ossec.conf" dev="dm-0" ino=138069976 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1608016300.579:144832): arch=c000003e syscall=2 success=yes exit=3 a0=7fff38f56ec1 a1=0 a2=1fffffffffff0000 a3=7fff38f56120 items=0 ppid=4756 pid=4758 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="cat" exe="/usr/bin/cat" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608016300.579:144832): proctitle=636174002F7661722F6573696C642F6574632F6F737365632E636F6E66
#
# type=AVC msg=audit(1608016474.426:144890): avc:  denied  { name_connect } for  pid=1663 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1608016474.426:144890): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7f9244e9c190 a2=1c a3=a items=0 ppid=1270 pid=1663 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608016474.426:144890): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1608009842.114:142441): avc:  denied  { sys_resource } for  pid=22236 comm="sudo" capability=24  scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:system_r:httpd_t:s0 tclass=capability permissive=1 type=SYSCALL msg=audit(1608009842.114:142441): arch=c000003e syscall=160 success=yes exit=0 a0=6 a1=7ffe44755880 a2=ffffffff a3=1 items=0 ppid=22235 pid=22236 auid=4294967295 uid=48 gid=48 euid=0 suid=0 fsuid=0 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="sudo" exe="/usr/bin/sudo" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608009842.114:142441): proctitle=7375646F002F7661722F6573696C642F62696E2F6167656E745F636F6E74726F6C002D6C630073656400732F4167656E74204E616D653A2F2F
#
# type=AVC msg=audit(1610503716.277:9844): avc:  denied  { name_connect } for  pid=25218 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1610503716.277:9844): arch=c000003e syscall=42 success=no exit=-115 a0=18 a1=7f0b6affa190 a2=1c a3=a items=0 ppid=1470 pid=25218 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1610503716.277:9844): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1600410341.886:5712): avc:  denied  { name_connect } for  pid=1049 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1600410341.886:5712): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7f845f7fb190 a2=1c a3=a items=0 ppid=4007 pid=1049 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1600410341.886:5712): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1605500057.072:2475): avc:  denied  { name_connect } for  pid=9817 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1605500057.072:2475): arch=c000003e syscall=42 success=no exit=-115 a0=16 a1=7fa66169e190 a2=1c a3=a items=0 ppid=1471 pid=9817 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1605500057.072:2475): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1603071048.712:327): avc:  denied  { getattr } for  pid=9049 comm="unix_chkpwd" path="/etc/shadow" dev="dm-0" ino=271194262 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:shadow_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1603071048.712:327): arch=c000003e syscall=5 success=yes exit=0 a0=3 a1=7fffe9086de0 a2=7fffe9086de0 a3=0 items=0 ppid=9042 pid=9049 auid=4294967295 uid=0 gid=48 euid=0 suid=0 fsuid=0 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="unix_chkpwd" exe="/usr/sbin/unix_chkpwd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1603071048.712:327): proctitle=2F7573722F7362696E2F756E69785F63686B707764006170616368650063686B657870697279
#
# type=AVC msg=audit(1611561255.880:107898): avc:  denied  { name_connect } for  pid=14029 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1611561255.880:107898): arch=c000003e syscall=42 success=no exit=-115 a0=16 a1=7f7f7b7f3190 a2=1c a3=a items=0 ppid=1435 pid=14029 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1611561255.880:107898): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1603071164.323:386): avc:  denied  { name_connect } for  pid=7384 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1603071164.323:386): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7f6e037fb190 a2=1c a3=a items=0 ppid=1458 pid=7384 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1603071164.323:386): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1608019039.551:146333): avc:  denied  { read } for  pid=14542 comm="cat" name="0020-syslog_rules.xml" dev="dm-0" ino=2620522 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=AVC msg=audit(1608019039.551:146333): avc:  denied  { open } for  pid=14542 comm="cat" path="/var/esild/ruleset/rules/0020-syslog_rules.xml" dev="dm-0" ino=2620522 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1608019039.551:146333): arch=c000003e syscall=2 success=yes exit=3 a0=7ffc6e512e97 a1=0 a2=1fffffffffff0000 a3=7ffc6e5108a0 items=0 ppid=14533 pid=14542 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="cat" exe="/usr/bin/cat" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608019039.551:146333): proctitle=636174002F7661722F6573696C642F72756C657365742F72756C65732F303032302D7379736C6F675F72756C65732E786D6C
#
# type=AVC msg=audit(1608009469.306:141043): avc:  denied  { getattr } for  pid=18903 comm="agent_control" path="/var/esild/lib/libwazuhext.so" dev="dm-0" ino=3373347 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1608009469.306:141043): arch=c000003e syscall=5 success=yes exit=0 a0=3 a1=7ffd4fa368f0 a2=7ffd4fa368f0 a3=786568757a617762 items=0 ppid=18886 pid=18903 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="agent_control" exe="/var/esild/bin/agent_control" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608009469.306:141043): proctitle=7375646F002F7661722F6573696C642F62696E2F6167656E745F636F6E74726F6C002D6900303233
#
# type=AVC msg=audit(1603071476.872:518): avc:  denied  { name_connect } for  pid=1743 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1603071476.872:518): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7f6dfbfec190 a2=1c a3=a items=0 ppid=1458 pid=1743 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1603071476.872:518): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1611549256.018:103534): avc:  denied  { name_connect } for  pid=12014 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1611549256.018:103534): arch=c000003e syscall=42 success=no exit=-115 a0=19 a1=7f7f7d7f7190 a2=1c a3=a items=0 ppid=1435 pid=12014 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1611549256.018:103534): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1610498881.991:9101): avc:  denied  { name_connect } for  pid=24950 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1610498881.991:9101): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7f0b6affa190 a2=1c a3=a items=0 ppid=1470 pid=24950 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1610498881.991:9101): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1608018769.679:145472): avc:  denied  { write } for  pid=10775 comm="agent_control" name="wdb" dev="dm-0" ino=406304757 scontext=system_u:system_r:httpd_t:s0 tcontext=unconfined_u:object_r:var_t:s0 tclass=sock_file permissive=1 type=AVC msg=audit(1608018769.679:145472): avc:  denied  { connectto } for  pid=10775 comm="agent_control" path="/var/esild/queue/db/wdb" scontext=system_u:system_r:httpd_t:s0 tcontext=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 tclass=unix_stream_socket permissive=1 type=SYSCALL msg=audit(1608018769.679:145472): arch=c000003e syscall=42 success=yes exit=0 a0=4 a1=7ffeefcdcd30 a2=f a3=7ffeefcdc860 items=0 ppid=10759 pid=10775 auid=4294967295 uid=986 gid=980 euid=986 suid=986 fsuid=986 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="agent_control" exe="/bin/agent_control" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608018769.679:145472): proctitle=2F7661722F6573696C642F62696E2F6167656E745F636F6E74726F6C002D69003030310073656400732F4167656E74204E616D653A2F2F
#
# type=AVC msg=audit(1608009842.123:142443): avc:  denied  { nlmsg_relay } for  pid=22236 comm="sudo" scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:system_r:httpd_t:s0 tclass=netlink_audit_socket permissive=1 type=AVC msg=audit(1608009842.123:142443): avc:  denied  { audit_write } for  pid=22236 comm="sudo" capability=29  scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:system_r:httpd_t:s0 tclass=capability permissive=1
#
# type=AVC msg=audit(1602655533.255:111312): avc:  denied  { name_connect } for  pid=13703 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1602655533.255:111312): arch=c000003e syscall=42 success=no exit=-115 a0=18 a1=7f71626a0190 a2=1c a3=a items=0 ppid=1455 pid=13703 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1602655533.255:111312): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1600661122.616:41242): avc:  denied  { name_connect } for  pid=26185 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1600661122.616:41242): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7f845dff8190 a2=1c a3=a items=0 ppid=4007 pid=26185 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1600661122.616:41242): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1608016327.947:144854): avc:  denied  { ioctl } for  pid=4850 comm="ossec-control" path="/var/esild/bin/ossec-control" dev="dm-0" ino=404839291 ioctlcmd=5401 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1608016327.947:144854): arch=c000003e syscall=16 success=no exit=-25 a0=3 a1=5401 a2=7fffc03be120 a3=7fffc03bdce0 items=0 ppid=4845 pid=4850 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="ossec-control" exe="/usr/bin/bash" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608016327.947:144854): proctitle=7375646F002F7661722F6573696C642F62696E2F6F737365632D636F6E74726F6C00737461747573
#
# type=AVC msg=audit(1611554042.415:106862): avc:  denied  { name_connect } for  pid=14029 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1611554042.415:106862): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7f7f787ed190 a2=1c a3=a items=0 ppid=1435 pid=14029 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1611554042.415:106862): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1608019102.189:147569): avc:  denied  { setrlimit } for  pid=16991 comm="sudo" scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:system_r:httpd_t:s0 tclass=process permissive=1 type=SYSCALL msg=audit(1608019102.189:147569): arch=c000003e syscall=160 success=yes exit=0 a0=6 a1=7ffcd2511260 a2=ffffffff a3=1 items=0 ppid=16990 pid=16991 auid=4294967295 uid=48 gid=48 euid=0 suid=0 fsuid=0 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="sudo" exe="/usr/bin/sudo" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608019102.189:147569): proctitle=7375646F00636174002F7661722F6573696C642F6574632F6F737365632E636F6E66
#
# type=AVC msg=audit(1610498086.142:8967): avc:  denied  { getattr } for  pid=24053 comm="postdrop" path="/var/spool/postfix/public/pickup" dev="dm-0" ino=269723680 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:postfix_public_t:s0 tclass=sock_file permissive=1 type=SYSCALL msg=audit(1610498086.142:8967): arch=c000003e syscall=4 success=yes exit=0 a0=556c7575fc00 a1=7fff7aa01550 a2=7fff7aa01550 a3=7fff7aa01060 items=0 ppid=24052 pid=24053 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=90 sgid=90 fsgid=90 tty=(none) ses=4294967295 comm="postdrop" exe="/usr/sbin/postdrop" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1610498086.142:8967): proctitle=2F7573722F7362696E2F706F737464726F70002D72
#
# type=AVC msg=audit(1608016209.053:143430): avc:  denied  { getattr } for  pid=1529 comm="sudo" path="/var/esild/bin/agent_control" dev="dm-0" ino=404839312 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1608016209.053:143430): arch=c000003e syscall=4 success=yes exit=0 a0=7ffd9b791dd0 a1=5593fdd29210 a2=5593fdd29210 a3=7fcfa8dab300 items=0 ppid=1528 pid=1529 auid=4294967295 uid=48 gid=48 euid=0 suid=0 fsuid=0 egid=0 sgid=48 fsgid=0 tty=(none) ses=4294967295 comm="sudo" exe="/usr/bin/sudo" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608016209.053:143430): proctitle=7375646F002F7661722F6573696C642F62696E2F6167656E745F636F6E74726F6C002D6C630073656400732F4167656E74204E616D653A2F2F
#
# type=AVC msg=audit(1600410165.264:5675): avc:  denied  { sys_resource } for  pid=1986 comm="sudo" capability=24  scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:system_r:httpd_t:s0 tclass=capability permissive=1 type=AVC msg=audit(1600410165.264:5675): avc:  denied  { setrlimit } for  pid=1986 comm="sudo" scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:system_r:httpd_t:s0 tclass=process permissive=1 type=SYSCALL msg=audit(1600410165.264:5675): arch=c000003e syscall=160 success=yes exit=0 a0=6 a1=7fff295df870 a2=ffffffff a3=1 items=0 ppid=1985 pid=1986 auid=4294967295 uid=48 gid=48 euid=0 suid=0 fsuid=0 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="sudo" exe="/usr/bin/sudo" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1600410165.264:5675): proctitle=7375646F002F7661722F6573696C642F62696E2F6167656E745F636F6E74726F6C002D6C630073656400732F4167656E74204E616D653A2F2F
#
# type=AVC msg=audit(1603071183.310:396): avc:  denied  { read } for  pid=9369 comm="unix_chkpwd" name="shadow" dev="dm-0" ino=271194262 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:shadow_t:s0 tclass=file permissive=1 type=AVC msg=audit(1603071183.310:396): avc:  denied  { open } for  pid=9369 comm="unix_chkpwd" path="/etc/shadow" dev="dm-0" ino=271194262 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:shadow_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1603071183.310:396): arch=c000003e syscall=2 success=yes exit=3 a0=7fa1f6caf573 a1=80000 a2=1b6 a3=24 items=0 ppid=9360 pid=9369 auid=4294967295 uid=0 gid=48 euid=0 suid=0 fsuid=0 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="unix_chkpwd" exe="/usr/sbin/unix_chkpwd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1603071183.310:396): proctitle=2F7573722F7362696E2F756E69785F63686B707764006170616368650063686B657870697279
#
# type=AVC msg=audit(1605637442.118:22223): avc:  denied  { getattr } for  pid=1471 comm="httpd" path="/etc/php.ini" dev="dm-0" ino=270152865 scontext=system_u:system_r:httpd_t:s0 tcontext=unconfined_u:object_r:admin_home_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1605637442.118:22223): arch=c000003e syscall=5 success=yes exit=0 a0=b a1=7fff2d40e910 a2=7fff2d40e910 a3=7fa68b2001c0 items=0 ppid=1 pid=1471 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1605637442.118:22223): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1605257797.892:4224): avc:  denied  { setrlimit } for  pid=29179 comm="sendmail" scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:system_r:httpd_t:s0 tclass=process permissive=1 type=SYSCALL msg=audit(1605257797.892:4224): arch=c000003e syscall=160 success=yes exit=0 a0=1 a1=7ffd188e1b00 a2=ffffffffffffffff a3=7ffd188e1620 items=0 ppid=1737 pid=29179 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="sendmail" exe="/usr/sbin/sendmail.postfix" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1605257797.892:4224): proctitle=2F7573722F7362696E2F73656E646D61696C002D74002D6900655369656D407365727665722E636F6D
#
# type=AVC msg=audit(1611635757.594:118531): avc:  denied  { name_connect } for  pid=11531 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1611635757.594:118531): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7f7f6cfee190 a2=1c a3=a items=0 ppid=1435 pid=11531 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1611635757.594:118531): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1610086020.141:53343): avc:  denied  { name_connect } for  pid=15920 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1610086020.141:53343): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7f6f4d7ef190 a2=1c a3=a items=0 ppid=1465 pid=15920 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1610086020.141:53343): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1608011539.960:142688): avc:  denied  { name_connect } for  pid=17783 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1608011539.960:142688): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7f923effa190 a2=1c a3=a items=0 ppid=1270 pid=17783 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608011539.960:142688): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1602724513.036:200): avc:  denied  { setrlimit } for  pid=8276 comm="sudo" scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:system_r:httpd_t:s0 tclass=process permissive=1 type=SYSCALL msg=audit(1602724513.036:200): arch=c000003e syscall=160 success=yes exit=0 a0=6 a1=7f4d90b70c20 a2=ffffffff a3=7f4d90fa0300 items=0 ppid=8274 pid=8276 auid=4294967295 uid=48 gid=48 euid=0 suid=0 fsuid=0 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="sudo" exe="/usr/bin/sudo" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1602724513.036:200): proctitle=7375646F002F7661722F6573696C642F62696E2F6167656E745F636F6E74726F6C002D6C6E0073656400732F4167656E74204E616D653A2F2F
#
# type=AVC msg=audit(1608007226.066:140157): avc:  denied  { name_connect } for  pid=3893 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1608007226.066:140157): arch=c000003e syscall=42 success=no exit=-115 a0=14 a1=7f923cff6190 a2=1c a3=a items=0 ppid=1270 pid=3893 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608007226.066:140157): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1602724643.574:1521): avc:  denied  { execute } for  pid=11754 comm="sudo" name="ossec-control" dev="dm-0" ino=404839291 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=AVC msg=audit(1602724643.574:1521): avc:  denied  { read open } for  pid=11754 comm="sudo" path="/var/esild/bin/ossec-control" dev="dm-0" ino=404839291 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=AVC msg=audit(1602724643.574:1521): avc:  denied  { execute_no_trans } for  pid=11754 comm="sudo" path="/var/esild/bin/ossec-control" dev="dm-0" ino=404839291 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1602724643.574:1521): arch=c000003e syscall=59 success=yes exit=0 a0=5614f9b174f8 a1=5614f9b111e8 a2=5614f9b357f0 a3=5 items=0 ppid=11750 pid=11754 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="ossec-control" exe="/usr/bin/bash" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1602724643.574:1521): proctitle=7375646F002F7661722F6573696C642F62696E2F6F737365632D636F6E74726F6C00737461747573
#
# type=AVC msg=audit(1610086062.705:53354): avc:  denied  { getattr } for  pid=20854 comm="unix_chkpwd" path="/etc/shadow" dev="dm-0" ino=271194262 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:shadow_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1610086062.705:53354): arch=c000003e syscall=5 success=yes exit=0 a0=3 a1=7ffd0060a630 a2=7ffd0060a630 a3=0 items=0 ppid=20845 pid=20854 auid=4294967295 uid=0 gid=48 euid=0 suid=0 fsuid=0 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="unix_chkpwd" exe="/usr/sbin/unix_chkpwd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1610086062.705:53354): proctitle=2F7573722F7362696E2F756E69785F63686B707764006170616368650063686B657870697279
#
# type=AVC msg=audit(1608011419.954:142672): avc:  denied  { name_connect } for  pid=17057 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1608011419.954:142672): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7f923aff2190 a2=1c a3=a items=0 ppid=1270 pid=17057 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608011419.954:142672): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1600410165.265:5676): avc:  denied  { getattr } for  pid=1986 comm="sudo" path="/var/esild/bin/agent_control" dev="dm-0" ino=404839312 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1600410165.265:5676): arch=c000003e syscall=4 success=yes exit=0 a0=7fff295de7e0 a1=56178567d220 a2=56178567d220 a3=7f6add4de300 items=0 ppid=1985 pid=1986 auid=4294967295 uid=48 gid=48 euid=0 suid=0 fsuid=0 egid=0 sgid=48 fsgid=0 tty=(none) ses=4294967295 comm="sudo" exe="/usr/bin/sudo" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1600410165.265:5676): proctitle=7375646F002F7661722F6573696C642F62696E2F6167656E745F636F6E74726F6C002D6C630073656400732F4167656E74204E616D653A2F2F
#
# type=AVC msg=audit(1612635662.145:33455): avc:  denied  { ioctl } for  pid=1474 comm="httpd" path="/etc/php.ini" dev="dm-0" ino=270152865 ioctlcmd=5401 scontext=system_u:system_r:httpd_t:s0 tcontext=unconfined_u:object_r:admin_home_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1612635662.145:33455): arch=c000003e syscall=16 success=no exit=-25 a0=b a1=5401 a2=7fff24911a00 a3=7fa8b64001c0 items=0 ppid=1 pid=1474 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1612635662.145:33455): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1608015064.448:143228): avc:  denied  { name_connect } for  pid=31189 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1608015064.448:143228): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7f9236fea190 a2=1c a3=a items=0 ppid=1270 pid=31189 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608015064.448:143228): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1613846101.664:73187): avc:  denied  { getattr } for  pid=1465 comm="httpd" path="/etc/php.ini" dev="dm-0" ino=270152865 scontext=system_u:system_r:httpd_t:s0 tcontext=unconfined_u:object_r:admin_home_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1613846101.664:73187): arch=c000003e syscall=5 success=yes exit=0 a0=b a1=7ffcffb0a130 a2=7ffcffb0a130 a3=7fafa7a001c0 items=0 ppid=1 pid=1465 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1613846101.664:73187): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1610498821.997:9100): avc:  denied  { name_connect } for  pid=1695 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1610498821.997:9100): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7f0b667f1190 a2=1c a3=a items=0 ppid=1470 pid=1695 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1610498821.997:9100): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1602655113.268:111206): avc:  denied  { name_connect } for  pid=31868 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1602655113.268:111206): arch=c000003e syscall=42 success=no exit=-115 a0=18 a1=7f71626a0190 a2=1c a3=a items=0 ppid=1455 pid=31868 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1602655113.268:111206): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1600648202.945:39398): avc:  denied  { name_connect } for  pid=1286 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1600648202.945:39398): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7f845aff2190 a2=1c a3=a items=0 ppid=4007 pid=1286 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1600648202.945:39398): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1608009147.131:140950): avc:  denied  { getattr } for  pid=18246 comm="unix_chkpwd" path="/etc/shadow" dev="dm-0" ino=271194262 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:shadow_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1608009147.131:140950): arch=c000003e syscall=5 success=yes exit=0 a0=3 a1=7ffc0c729e40 a2=7ffc0c729e40 a3=0 items=0 ppid=18230 pid=18246 auid=4294967295 uid=0 gid=48 euid=0 suid=0 fsuid=0 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="unix_chkpwd" exe="/usr/sbin/unix_chkpwd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608009147.131:140950): proctitle=2F7573722F7362696E2F756E69785F63686B707764006170616368650063686B657870697279
#
# type=AVC msg=audit(1608018737.667:145396): avc:  denied  { execute } for  pid=10442 comm="sudo" name="agent_control" dev="dm-0" ino=404839312 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=AVC msg=audit(1608018737.667:145396): avc:  denied  { read open } for  pid=10442 comm="sudo" path="/var/esild/bin/agent_control" dev="dm-0" ino=404839312 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=AVC msg=audit(1608018737.667:145396): avc:  denied  { execute_no_trans } for  pid=10442 comm="sudo" path="/var/esild/bin/agent_control" dev="dm-0" ino=404839312 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1608018737.667:145396): arch=c000003e syscall=59 success=yes exit=0 a0=555ab23f34e8 a1=555ab23ed1d8 a2=555ab24117a0 a3=5 items=0 ppid=10424 pid=10442 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="agent_control" exe="/var/esild/bin/agent_control" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608018737.667:145396): proctitle=2F7661722F6573696C642F62696E2F6167656E745F636F6E74726F6C002D6900303134
#
# type=AVC msg=audit(1611549064.257:102314): avc:  denied  { getattr } for  pid=8948 comm="unix_chkpwd" path="/etc/shadow" dev="dm-0" ino=271194262 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:shadow_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1611549064.257:102314): arch=c000003e syscall=5 success=yes exit=0 a0=3 a1=7ffd6c62ff10 a2=7ffd6c62ff10 a3=0 items=0 ppid=8945 pid=8948 auid=4294967295 uid=0 gid=48 euid=0 suid=0 fsuid=0 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="unix_chkpwd" exe="/usr/sbin/unix_chkpwd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1611549064.257:102314): proctitle=2F7573722F7362696E2F756E69785F63686B707764006170616368650063686B657870697279
#
# type=AVC msg=audit(1610504485.292:10145): avc:  denied  { setrlimit } for  pid=31440 comm="sudo" scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:system_r:httpd_t:s0 tclass=process permissive=1 type=SYSCALL msg=audit(1610504485.292:10145): arch=c000003e syscall=160 success=yes exit=0 a0=6 a1=7fff331fb030 a2=ffffffff a3=1 items=0 ppid=31437 pid=31440 auid=4294967295 uid=48 gid=48 euid=0 suid=0 fsuid=0 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="sudo" exe="/usr/bin/sudo" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1610504485.292:10145): proctitle=7375646F002F7661722F6573696C642F62696E2F6167656E745F636F6E74726F6C002D69003031320073656400732F4167656E74204E616D653A2F2F
#
# ...
#
# type=AVC msg=audit(1605501036.374:2619): avc:  denied  { name_connect } for  pid=21565 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1605501036.374:2619): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7fa6567f1190 a2=1c a3=a items=0 ppid=1471 pid=21565 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1605501036.374:2619): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1600405946.767:5072): avc:  denied  { name_connect } for  pid=4013 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1600405946.767:5072): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7f8465a9c190 a2=1c a3=a items=0 ppid=4007 pid=4013 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1600405946.767:5072): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1605637442.118:22222): avc:  denied  { ioctl } for  pid=1471 comm="httpd" path="/etc/php.ini" dev="dm-0" ino=270152865 ioctlcmd=5401 scontext=system_u:system_r:httpd_t:s0 tcontext=unconfined_u:object_r:admin_home_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1605637442.118:22222): arch=c000003e syscall=16 success=no exit=-25 a0=b a1=5401 a2=7fff2d40e880 a3=7fa68b2001c0 items=0 ppid=1 pid=1471 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1605637442.118:22222): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1610085696.182:53279): avc:  denied  { sys_resource } for  pid=20380 comm="sudo" capability=24  scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:system_r:httpd_t:s0 tclass=capability permissive=1 type=SYSCALL msg=audit(1610085696.182:53279): arch=c000003e syscall=160 success=yes exit=0 a0=6 a1=7fffb1dfa9b0 a2=ffffffff a3=8 items=0 ppid=20376 pid=20380 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="sudo" exe="/usr/bin/sudo" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1610085696.182:53279): proctitle=7375646F002F7661722F6573696C642F62696E2F6F737365632D636F6E74726F6C00737461747573
#
# type=AVC msg=audit(1603071104.311:378): avc:  denied  { name_connect } for  pid=1742 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1603071104.311:378): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7f6dfb7eb190 a2=1c a3=a items=0 ppid=1458 pid=1742 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1603071104.311:378): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1613366365.902:4718): avc:  denied  { write } for  pid=3763 comm="agent_control" name="wdb" dev="dm-0" ino=403548675 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=sock_file permissive=1 type=SYSCALL msg=audit(1613366365.902:4718): arch=c000003e syscall=42 success=yes exit=0 a0=4 a1=7ffde1abca50 a2=f a3=7ffde1abc560 items=0 ppid=3747 pid=3763 auid=4294967295 uid=986 gid=980 euid=986 suid=986 fsuid=986 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="agent_control" exe="/bin/agent_control" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1613366365.902:4718): proctitle=2F7661722F6573696C642F62696E2F6167656E745F636F6E74726F6C002D6900303333
#
# type=AVC msg=audit(1605486362.142:507): avc:  denied  { read } for  pid=1471 comm="httpd" name="php.ini" dev="dm-0" ino=270152865 scontext=system_u:system_r:httpd_t:s0 tcontext=unconfined_u:object_r:admin_home_t:s0 tclass=file permissive=1 type=AVC msg=audit(1605486362.142:507): avc:  denied  { open } for  pid=1471 comm="httpd" path="/etc/php.ini" dev="dm-0" ino=270152865 scontext=system_u:system_r:httpd_t:s0 tcontext=unconfined_u:object_r:admin_home_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1605486362.142:507): arch=c000003e syscall=2 success=yes exit=11 a0=7fa68b20a000 a1=0 a2=1b6 a3=24 items=0 ppid=1 pid=1471 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1605486362.142:507): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1613363937.229:2494): avc:  denied  { read } for  pid=30634 comm="cat" name="0010-rules_config.xml" dev="dm-0" ino=2620519 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=AVC msg=audit(1613363937.229:2494): avc:  denied  { open } for  pid=30634 comm="cat" path="/var/esild/ruleset/rules/0010-rules_config.xml" dev="dm-0" ino=2620519 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1613363937.229:2494): arch=c000003e syscall=2 success=yes exit=3 a0=7fff7a650e99 a1=0 a2=1fffffffffff0000 a3=7fff7a6501a0 items=0 ppid=30627 pid=30634 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="cat" exe="/usr/bin/cat" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1613363937.229:2494): proctitle=636174002F7661722F6573696C642F72756C657365742F72756C65732F303031302D72756C65735F636F6E6669672E786D6C
#
# type=AVC msg=audit(1608010826.049:142588): avc:  denied  { name_connect } for  pid=17783 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1608010826.049:142588): arch=c000003e syscall=42 success=no exit=-115 a0=16 a1=7f923effa190 a2=1c a3=a items=0 ppid=1270 pid=17783 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608010826.049:142588): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1608011479.964:142680): avc:  denied  { name_connect } for  pid=17057 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1608011479.964:142680): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7f923c7f5190 a2=1c a3=a items=0 ppid=1270 pid=17057 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608011479.964:142680): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1600933724.392:79815): avc:  denied  { name_connect } for  pid=5145 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1600933724.392:79815): arch=c000003e syscall=42 success=no exit=-115 a0=16 a1=7f84587ed190 a2=1c a3=a items=0 ppid=4007 pid=5145 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1600933724.392:79815): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1602724643.580:1522): avc:  denied  { ioctl } for  pid=11754 comm="ossec-control" path="/var/esild/bin/ossec-control" dev="dm-0" ino=404839291 ioctlcmd=5401 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1602724643.580:1522): arch=c000003e syscall=16 success=no exit=-25 a0=3 a1=5401 a2=7fffb5ff4c50 a3=7fffb5ff4820 items=0 ppid=11750 pid=11754 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="ossec-control" exe="/usr/bin/bash" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1602724643.580:1522): proctitle=7375646F002F7661722F6573696C642F62696E2F6F737365632D636F6E74726F6C00737461747573
#
# type=AVC msg=audit(1600410256.917:5704): avc:  denied  { name_connect } for  pid=1049 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1600410256.917:5704): arch=c000003e syscall=42 success=no exit=-115 a0=15 a1=7f845e7f9190 a2=1c a3=a items=0 ppid=4007 pid=1049 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1600410256.917:5704): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1610504483.742:9953): avc:  denied  { read } for  pid=30765 comm="unix_chkpwd" name="shadow" dev="dm-0" ino=271194262 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:shadow_t:s0 tclass=file permissive=1 type=AVC msg=audit(1610504483.742:9953): avc:  denied  { open } for  pid=30765 comm="unix_chkpwd" path="/etc/shadow" dev="dm-0" ino=271194262 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:shadow_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1610504483.742:9953): arch=c000003e syscall=2 success=yes exit=3 a0=7f124fc95573 a1=80000 a2=1b6 a3=24 items=0 ppid=30756 pid=30765 auid=4294967295 uid=0 gid=48 euid=0 suid=0 fsuid=0 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="unix_chkpwd" exe="/usr/sbin/unix_chkpwd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1610504483.742:9953): proctitle=2F7573722F7362696E2F756E69785F63686B707764006170616368650063686B657870697279
#
# type=AVC msg=audit(1608018225.250:145134): avc:  denied  { name_connect } for  pid=7150 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1608018225.250:145134): arch=c000003e syscall=42 success=no exit=-115 a0=1b a1=7f92377eb190 a2=1c a3=a items=0 ppid=1270 pid=7150 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1608018225.250:145134): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1608006764.370:140008): avc:  denied  { nlmsg_relay } for  pid=4852 comm="sudo" scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:system_r:httpd_t:s0 tclass=netlink_audit_socket permissive=1 type=AVC msg=audit(1608006764.370:140008): avc:  denied  { audit_write } for  pid=4852 comm="sudo" capability=29  scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:system_r:httpd_t:s0 tclass=capability permissive=1
#
# type=AVC msg=audit(1612253185.609:82): avc:  denied  { read } for  pid=1471 comm="httpd" name="php.ini" dev="dm-0" ino=270152865 scontext=system_u:system_r:httpd_t:s0 tcontext=unconfined_u:object_r:admin_home_t:s0 tclass=file permissive=1 type=AVC msg=audit(1612253185.609:82): avc:  denied  { open } for  pid=1471 comm="httpd" path="/etc/php.ini" dev="dm-0" ino=270152865 scontext=system_u:system_r:httpd_t:s0 tcontext=unconfined_u:object_r:admin_home_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1612253185.609:82): arch=c000003e syscall=2 success=yes exit=11 a0=7f50a1c0a000 a1=0 a2=1b6 a3=24 items=0 ppid=1 pid=1471 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1612253185.609:82): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1602655561.588:111314): avc:  denied  { getattr } for  pid=4870 comm="sudo" path="/var/esild/bin/agent_control" dev="dm-0" ino=404839312 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1602655561.588:111314): arch=c000003e syscall=4 success=yes exit=0 a0=7ffc0e245c90 a1=55d9e65c5210 a2=55d9e65c5210 a3=7fd5f3dd1300 items=0 ppid=4869 pid=4870 auid=4294967295 uid=48 gid=48 euid=0 suid=0 fsuid=0 egid=0 sgid=48 fsgid=0 tty=(none) ses=4294967295 comm="sudo" exe="/usr/bin/sudo" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1602655561.588:111314): proctitle=7375646F002F7661722F6573696C642F62696E2F6167656E745F636F6E74726F6C002D6C630073656400732F4167656E74204E616D653A2F2F
#
# type=AVC msg=audit(1606289644.786:115654): avc:  denied  { name_connect } for  pid=23767 comm="httpd" dest=9200 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:wap_wsp_port_t:s0 tclass=tcp_socket permissive=1 type=SYSCALL msg=audit(1606289644.786:115654): arch=c000003e syscall=42 success=no exit=-115 a0=16 a1=7fa6587f5190 a2=1c a3=a items=0 ppid=1471 pid=23767 auid=4294967295 uid=48 gid=48 euid=48 suid=48 fsuid=48 egid=48 sgid=48 fsgid=48 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1606289644.786:115654): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1615055701.571:243854): avc:  denied  { getattr } for  pid=1465 comm="httpd" path="/etc/php.ini" dev="dm-0" ino=270152865 scontext=system_u:system_r:httpd_t:s0 tcontext=unconfined_u:object_r:admin_home_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1615055701.571:243854): arch=c000003e syscall=5 success=yes exit=0 a0=b a1=7ffcffb0a130 a2=7ffcffb0a130 a3=7fafa7a001c0 items=0 ppid=1 pid=1465 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="httpd" exe="/usr/sbin/httpd" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1615055701.571:243854): proctitle=2F7573722F7362696E2F6874747064002D44464F524547524F554E44
#
# type=AVC msg=audit(1611549064.167:102303): avc:  denied  { read } for  pid=8927 comm="cat" name="0035-spamd_rules.xml" dev="dm-0" ino=2620525 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=AVC msg=audit(1611549064.167:102303): avc:  denied  { open } for  pid=8927 comm="cat" path="/var/esild/ruleset/rules/0035-spamd_rules.xml" dev="dm-0" ino=2620525 scontext=system_u:system_r:httpd_t:s0 tcontext=system_u:object_r:var_t:s0 tclass=file permissive=1 type=SYSCALL msg=audit(1611549064.167:102303): arch=c000003e syscall=2 success=yes exit=3 a0=7ffcd1ef9e99 a1=0 a2=1fffffffffff0000 a3=7ffcd1ef75e0 items=0 ppid=8916 pid=8927 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="cat" exe="/usr/bin/cat" subj=system_u:system_r:httpd_t:s0 key=(null) type=PROCTITLE msg=audit(1611549064.167:102303): proctitle=636174002F7661722F6573696C642F72756C657365742F72756C65732F303033352D7370616D645F72756C65732E786D6C

# %% [markdown]
# ## type=SYSCALL

# %%
groups.get_group('type=SYSCALL')
# Out:
#         level                                           full_log    first_word
# id
# 4           1  type=SYSCALL msg=audit(1603094402.016:52981): ...  type=SYSCALL
# 5           1  type=SYSCALL msg=audit(1611889244.855:247124):...  type=SYSCALL
# 10          1  type=SYSCALL msg=audit(1611895525.367:489785):...  type=SYSCALL
# 15          1  type=SYSCALL msg=audit(1603072847.573:38657): ...  type=SYSCALL
# 22          1  type=SYSCALL msg=audit(1603159410.494:164830):...  type=SYSCALL
# ...       ...                                                ...           ...
# 472945      1  type=SYSCALL msg=audit(1611893440.465:417650):...  type=SYSCALL
# 472951      1  type=SYSCALL msg=audit(1611890997.087:322803):...  type=SYSCALL
# 472953      1  type=SYSCALL msg=audit(1611895531.931:497276):...  type=SYSCALL
# 472955      1  type=SYSCALL msg=audit(1611887841.572:191604):...  type=SYSCALL
# 472968      1  type=SYSCALL msg=audit(1611890993.458:321827):...  type=SYSCALL
#
# [116496 rows x 3 columns]

# %%
groups.get_group('type=SYSCALL')['level'].value_counts()
# Out:
# 1    116496
# Name: level, dtype: int64

# %%
for log in groups.get_group('type=SYSCALL')['full_log'][:100]:
    print(log, '\n')
# Out:
# type=SYSCALL msg=audit(1603094402.016:52981): arch=c000003e syscall=2 success=yes exit=3 a0=7ff220e805a4 a1=80000 a2=1 a3=7ff2210864f8 items=1 ppid=5877 pid=5878 auid=0 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=45 comm="date" exe="/usr/bin/date" subj=system_u:system_r:sysstat_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1603094402.016:52981):  cwd="/root" type=PATH msg=audit(1603094402.016:52981): item=0 name="/etc/ld.so.cache" inode=69008420 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:ld_so_cache_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603094402.016:52981): proctitle=64617465002B2564
#
# type=SYSCALL msg=audit(1611889244.855:247124): arch=c000003e syscall=2 success=yes exit=3 a0=7f1c14d535a4 a1=80000 a2=1 a3=7f1c14f594f8 items=1 ppid=100038 pid=100039 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="ps" exe="/usr/bin/ps" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611889244.855:247124):  cwd="/" type=PATH msg=audit(1611889244.855:247124): item=0 name="/etc/ld.so.cache" inode=35395307 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:ld_so_cache_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611889244.855:247124): proctitle=2F62696E2F7073002D700032353336
#
# type=SYSCALL msg=audit(1611895525.367:489785): arch=c000003e syscall=59 success=yes exit=0 a0=14de250 a1=14de360 a2=14dd150 a3=7ffd3604d7a0 items=2 ppid=7383 pid=7384 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="ps" exe="/usr/bin/ps" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-x" type=EXECVE msg=audit(1611895525.367:489785): argc=3 a0="/bin/ps" a1="-p" a2="2514" type=CWD msg=audit(1611895525.367:489785):  cwd="/" type=PATH msg=audit(1611895525.367:489785): item=0 name="/bin/ps" inode=101254309 dev=fd:00 mode=0100755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:bin_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PATH msg=audit(1611895525.367:489785): item=1 name="/lib64/ld-linux-x86-64.so.2" inode=80122 dev=fd:00 mode=0100755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:ld_so_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611895525.367:489785): proctitle=2F62696E2F7073002D700032353134
#
# type=SYSCALL msg=audit(1603072847.573:38657): arch=c000003e syscall=2 success=yes exit=8 a0=7fa584948547 a1=80000 a2=1b6 a3=24 items=1 ppid=1 pid=30216 auid=0 uid=0 gid=985 euid=0 suid=0 fsuid=0 egid=985 sgid=985 fsgid=985 tty=(none) ses=1 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1603072847.573:38657):  cwd="/" type=PATH msg=audit(1603072847.573:38657): item=0 name="/etc/group" inode=68678689 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:passwd_file_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603072847.573:38657): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1603159410.494:164830): arch=c000003e syscall=2 success=yes exit=8 a0=6cbc60 a1=0 a2=1b6 a3=24 items=1 ppid=1 pid=30216 auid=0 uid=0 gid=985 euid=0 suid=0 fsuid=0 egid=985 sgid=985 fsgid=985 tty=(none) ses=1 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1603159410.494:164830):  cwd="/" type=PATH msg=audit(1603159410.494:164830): item=0 name="/bin/gucharmap" inode=1140299 dev=fd:00 mode=0100755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:bin_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603159410.494:164830): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1611897945.465:585420): arch=c000003e syscall=2 success=yes exit=3 a0=7f9ffab425a4 a1=80000 a2=1 a3=7f9ffad484f8 items=1 ppid=86518 pid=22400 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="sh" exe="/usr/bin/bash" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611897945.465:585420):  cwd="/" type=PATH msg=audit(1611897945.465:585420): item=0 name="/etc/ld.so.cache" inode=35395307 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:ld_so_cache_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611897945.465:585420): proctitle=7368002D63002F62696E2F7073202D70203231313020323E202F6465762F6E756C6C
#
# type=SYSCALL msg=audit(1611890308.627:297875): arch=c000003e syscall=2 success=yes exit=3 a0=7fcb48f0d5a4 a1=80000 a2=1 a3=7fcb490f93a8 items=1 ppid=86518 pid=107562 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="sh" exe="/usr/bin/bash" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611890308.627:297875):  cwd="/" type=PATH msg=audit(1611890308.627:297875): item=0 name="/etc/ld.so.cache" inode=35395307 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:ld_so_cache_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611890308.627:297875): proctitle=7368002D63002F62696E2F7073202D702032383138203E202F6465762F6E756C6C20323E2631
#
# type=SYSCALL msg=audit(1611890727.022:312143): arch=c000003e syscall=2 success=yes exit=6 a0=7fd42d94f552 a1=80000 a2=1b6 a3=24 items=1 ppid=109873 pid=109874 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="ps" exe="/usr/bin/ps" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611890727.022:312143):  cwd="/var/esild/bin" type=PATH msg=audit(1611890727.022:312143): item=0 name="/etc/passwd" inode=34361151 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:passwd_file_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611890727.022:312143): proctitle=7073002D6566
#
# type=SYSCALL msg=audit(1603139886.739:110607): arch=c000003e syscall=2 success=yes exit=11 a0=7f9b2c54dbf2 a1=80000 a2=1b6 a3=24 items=1 ppid=1 pid=16339 auid=0 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=1 comm="gvfs-udisks2-vo" exe="/usr/libexec/gvfs-udisks2-volume-monitor" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1603139886.739:110607):  cwd="/" type=PATH msg=audit(1603139886.739:110607): item=0 name="/etc/fstab" inode=67145794 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:etc_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603139886.739:110607): proctitle="/usr/libexec/gvfs-udisks2-volume-monitor"
#
# type=SYSCALL msg=audit(1603116097.993:82612): arch=c000003e syscall=2 success=yes exit=8 a0=93cab0 a1=0 a2=1b6 a3=24 items=1 ppid=1 pid=30216 auid=0 uid=0 gid=985 euid=0 suid=0 fsuid=0 egid=985 sgid=985 fsgid=985 tty=(none) ses=1 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1603116097.993:82612):  cwd="/" type=PATH msg=audit(1603116097.993:82612): item=0 name="/usr/bin/gnroff" inode=178227 dev=fd:00 mode=0100755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:bin_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603116097.993:82612): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1611887511.561:189816): arch=c000003e syscall=2 success=yes exit=3 a0=7f80297a70c0 a1=80000 a2=1b6 a3=24 items=1 ppid=86518 pid=90668 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="sh" exe="/usr/bin/bash" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611887511.561:189816):  cwd="/" type=PATH msg=audit(1611887511.561:189816): item=0 name="/etc/nsswitch.conf" inode=34183086 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:etc_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611887511.561:189816): proctitle=7368002D63002F62696E2F7073202D702032373638203E202F6465762F6E756C6C20323E2631
#
# type=SYSCALL msg=audit(1603144181.382:113835): arch=c000003e syscall=89 success=yes exit=9 a0=7ffff2aa32e0 a1=7ffff2aa5300 a2=1000 a3=7ffff2aa2c60 items=1 ppid=17098 pid=17251 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="urlgrabber-ext-" exe="/usr/bin/python2.7" subj=system_u:system_r:rpm_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1603144181.382:113835):  cwd="/" type=PATH msg=audit(1603144181.382:113835): item=0 name="/usr/bin/python2" inode=242089 dev=fd:00 mode=0120777 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:bin_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603144181.382:113835): proctitle=2F7573722F62696E2F707974686F6E002F7573722F6C6962657865632F75726C677261626265722D6578742D646F776E
#
# type=SYSCALL msg=audit(1611890992.794:319944): arch=c000003e syscall=2 success=yes exit=14 a0=7f89fd9c2430 a1=0 a2=0 a3=646f6d2f65766974 items=1 ppid=1 pid=86518 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611890992.794:319944):  cwd="/" type=PATH msg=audit(1611890992.794:319944): item=0 name="/etc/selinux/targeted/active/modules/100/tftp/lang_ext" inode=104884773 dev=fd:00 mode=0100600 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:semanage_store_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611890992.794:319944): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1611889201.768:244977): arch=c000003e syscall=2 success=yes exit=6 a0=7fc0c7ab5552 a1=80000 a2=1b6 a3=24 items=1 ppid=867 pid=99477 auid=4294967295 uid=999 gid=998 euid=999 suid=999 fsuid=999 egid=998 sgid=998 fsgid=998 tty=(none) ses=4294967295 comm="pkla-check-auth" exe="/usr/bin/pkla-check-authorization" subj=system_u:system_r:policykit_auth_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611889201.768:244977):  cwd="/" type=PATH msg=audit(1611889201.768:244977): item=0 name="/etc/passwd" inode=34361151 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:passwd_file_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611889201.768:244977): proctitle=2F7573722F62696E2F706B6C612D636865636B2D617574686F72697A6174696F6E00757365723100747275650074727565006F72672E667265656465736B746F702E7061636B6167656B69742E747269676765722D6F66666C696E652D757064617465
#
# type=SYSCALL msg=audit(1611891701.795:351643): arch=c000003e syscall=2 success=yes exit=3 a0=7fd38a8e45a4 a1=80000 a2=1 a3=7fd38aaea4f8 items=1 ppid=86518 pid=115867 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="sh" exe="/usr/bin/bash" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611891701.795:351643):  cwd="/" type=PATH msg=audit(1611891701.795:351643): item=0 name="/etc/ld.so.cache" inode=35395307 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:ld_so_cache_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611891701.795:351643): proctitle=7368002D63002F62696E2F7073202D702032373930203E202F6465762F6E756C6C20323E2631
#
# type=SYSCALL msg=audit(1611887499.078:183776): arch=c000003e syscall=257 success=yes exit=13 a0=ffffffffffffff9c a1=7f89fd9c3f30 a2=90800 a3=0 items=1 ppid=1 pid=86518 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611887499.078:183776):  cwd="/" type=PATH msg=audit(1611887499.078:183776): item=0 name="/etc/selinux/targeted/active/modules/100/ajaxterm" inode=3693775 dev=fd:00 mode=040700 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:semanage_store_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611887499.078:183776): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1603100553.760:55844): arch=c000003e syscall=59 success=yes exit=0 a0=1ea2da0 a1=1e9d8d0 a2=1e93b70 a3=7ffe01217e10 items=2 ppid=6994 pid=6998 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="awk" exe="/usr/bin/gawk" subj=system_u:system_r:ksmtuned_t:s0 key="audit-wazuh-x" type=EXECVE msg=audit(1603100553.760:55844): argc=2 a0="awk" a1=7B2073756D202B3D202431207D3B20454E44207B207072696E7420302B73756D207D type=CWD msg=audit(1603100553.760:55844):  cwd="/" type=PATH msg=audit(1603100553.760:55844): item=0 name="/usr/bin/awk" inode=167294 dev=fd:00 mode=0100755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:bin_t:s0 objtype=NORMAL type=PATH msg=audit(1603100553.760:55844): item=1 name="/lib64/ld-linux-x86-64.so.2" inode=33774210 dev=fd:00 mode=0100755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:ld_so_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603100553.760:55844): proctitle=61776B007B2073756D202B3D202431207D3B20454E44207B207072696E7420302B73756D207D
#
# type=SYSCALL msg=audit(1603144191.663:114729): arch=c000003e syscall=2 success=yes exit=7 a0=7f4da0179f01 a1=80000 a2=1b6 a3=24 items=1 ppid=17098 pid=17350 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="urlgrabber-ext-" exe="/usr/bin/python2.7" subj=system_u:system_r:rpm_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1603144191.663:114729):  cwd="/" type=PATH msg=audit(1603144191.663:114729): item=0 name="/etc/resolv.conf" inode=68533312 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:net_conf_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603144191.663:114729): proctitle=2F7573722F62696E2F707974686F6E002F7573722F6C6962657865632F75726C677261626265722D6578742D646F776E
#
# type=SYSCALL msg=audit(1603186201.541:179941): arch=c000003e syscall=2 success=yes exit=11 a0=7fea277c6432 a1=80000 a2=1b6 a3=24 items=1 ppid=1 pid=868 auid=4294967295 uid=999 gid=998 euid=999 suid=999 fsuid=999 egid=998 sgid=998 fsgid=998 tty=(none) ses=4294967295 comm="polkitd" exe="/usr/lib/polkit-1/polkitd" subj=system_u:system_r:policykit_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1603186201.541:179941):  cwd="/" type=PATH msg=audit(1603186201.541:179941): item=0 name="/etc/passwd" inode=68678693 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:passwd_file_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603186201.541:179941): proctitle=2F7573722F6C69622F706F6C6B69742D312F706F6C6B697464002D2D6E6F2D6465627567
#
# type=SYSCALL msg=audit(1611890296.622:293370): arch=c000003e syscall=257 success=yes exit=10 a0=ffffffffffffff9c a1=7f89fd9c9030 a2=90800 a3=0 items=1 ppid=1 pid=86518 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611890296.622:293370):  cwd="/" type=PATH msg=audit(1611890296.622:293370): item=0 name="/etc/skel/.mozilla/extensions" inode=100665252 dev=fd:00 mode=040755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:etc_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611890296.622:293370): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1611896567.987:534364): arch=c000003e syscall=2 success=yes exit=8 a0=7f89fd9cc630 a1=0 a2=0 a3=7f89fe522280 items=1 ppid=1 pid=86518 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611896567.987:534364):  cwd="/" type=PATH msg=audit(1611896567.987:534364): item=0 name="/usr/bin/lp.cups" inode=101555115 dev=fd:00 mode=0100755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:lpr_exec_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611896567.987:534364): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1611897237.755:556874): arch=c000003e syscall=59 success=yes exit=0 a0=7f89fe56ae69 a1=7f89fd9cad40 a2=7fff2ff97ca8 a3=7f89fd9ce9d0 items=2 ppid=86518 pid=17747 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="sh" exe="/usr/bin/bash" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-x" type=EXECVE msg=audit(1611897237.755:556874): argc=3 a0="sh" a1="-c" a2=2F62696E2F7073202D70203820323E202F6465762F6E756C6C type=CWD msg=audit(1611897237.755:556874):  cwd="/" type=PATH msg=audit(1611897237.755:556874): item=0 name="/bin/sh" inode=100674060 dev=fd:00 mode=0100755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:shell_exec_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PATH msg=audit(1611897237.755:556874): item=1 name="/lib64/ld-linux-x86-64.so.2" inode=80122 dev=fd:00 mode=0100755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:ld_so_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611897237.755:556874): proctitle=7368002D63002F62696E2F7073202D70203820323E202F6465762F6E756C6C
#
# type=SYSCALL msg=audit(1603159393.980:156779): arch=c000003e syscall=2 success=yes exit=8 a0=7fa584948552 a1=80000 a2=1b6 a3=24 items=1 ppid=1 pid=30216 auid=0 uid=0 gid=985 euid=0 suid=0 fsuid=0 egid=985 sgid=985 fsgid=985 tty=(none) ses=1 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1603159393.980:156779):  cwd="/" type=PATH msg=audit(1603159393.980:156779): item=0 name="/etc/passwd" inode=68678693 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:passwd_file_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603159393.980:156779): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1603116093.451:80887): arch=c000003e syscall=2 success=yes exit=9 a0=945b00 a1=0 a2=1b6 a3=24 items=1 ppid=1 pid=30216 auid=0 uid=0 gid=985 euid=0 suid=0 fsuid=0 egid=985 sgid=985 fsgid=985 tty=(none) ses=1 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1603116093.451:80887):  cwd="/" type=PATH msg=audit(1603116093.451:80887): item=0 name="/etc/brltty/kha.ttb" inode=678929 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:etc_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603116093.451:80887): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1611891687.057:342133): arch=c000003e syscall=2 success=yes exit=3 a0=7fda3d9740c0 a1=80000 a2=1b6 a3=24 items=1 ppid=86518 pid=114881 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="sh" exe="/usr/bin/bash" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611891687.057:342133):  cwd="/" type=PATH msg=audit(1611891687.057:342133): item=0 name="/etc/nsswitch.conf" inode=34183086 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:etc_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611891687.057:342133): proctitle=7368002D63002F62696E2F7073202D70203237373520323E202F6465762F6E756C6C
#
# type=SYSCALL msg=audit(1611887159.647:175793): arch=c000003e syscall=2 success=yes exit=3 a0=7f03f329e5a4 a1=80000 a2=1 a3=7f03f348a3a8 items=1 ppid=86518 pid=88317 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="sh" exe="/usr/bin/bash" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611887159.647:175793):  cwd="/" type=PATH msg=audit(1611887159.647:175793): item=0 name="/etc/ld.so.cache" inode=35395307 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:ld_so_cache_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611887159.647:175793): proctitle=7368002D63002F62696E2F7073202D702032373233203E202F6465762F6E756C6C20323E2631
#
# type=SYSCALL msg=audit(1611893445.026:418745): arch=c000003e syscall=2 success=yes exit=3 a0=7f672d0b65a4 a1=80000 a2=1 a3=7f672d2bc4f8 items=1 ppid=86518 pid=126243 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="sh" exe="/usr/bin/bash" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611893445.026:418745):  cwd="/" type=PATH msg=audit(1611893445.026:418745): item=0 name="/etc/ld.so.cache" inode=35395307 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:ld_so_cache_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611893445.026:418745): proctitle=7368002D63002F62696E2F7073202D702032373530203E202F6465762F6E756C6C20323E2631
#
# type=SYSCALL msg=audit(1611897249.590:565439): arch=c000003e syscall=2 success=yes exit=9 a0=7f89fd9cab30 a1=0 a2=0 a3=7f89fe522900 items=1 ppid=1 pid=86518 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611897249.590:565439):  cwd="/" type=PATH msg=audit(1611897249.590:565439): item=0 name="/etc/postfix/canonical" inode=69095599 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:postfix_etc_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611897249.590:565439): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1611884540.801:6387): arch=c000003e syscall=2 success=yes exit=15 a0=7fd5641bd547 a1=80000 a2=1b6 a3=24 items=1 ppid=1 pid=16168 auid=1000 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=1 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1611884540.801:6387):  cwd="/" type=PATH msg=audit(1611884540.801:6387): item=0 name="/etc/group" inode=33588799 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:passwd_file_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611884540.801:6387): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1611892740.365:389767): arch=c000003e syscall=59 success=yes exit=0 a0=24b1250 a1=24b1360 a2=24b0150 a3=7fff2507cc60 items=2 ppid=121555 pid=121556 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="ps" exe="/usr/bin/ps" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-x" type=EXECVE msg=audit(1611892740.365:389767): argc=3 a0="/bin/ps" a1="-p" a2="971" type=CWD msg=audit(1611892740.365:389767):  cwd="/" type=PATH msg=audit(1611892740.365:389767): item=0 name="/bin/ps" inode=101254309 dev=fd:00 mode=0100755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:bin_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PATH msg=audit(1611892740.365:389767): item=1 name="/lib64/ld-linux-x86-64.so.2" inode=80122 dev=fd:00 mode=0100755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:ld_so_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611892740.365:389767): proctitle=2F62696E2F7073002D7000393731
#
# type=SYSCALL msg=audit(1603116068.047:65519): arch=c000003e syscall=257 success=yes exit=8 a0=ffffffffffffff9c a1=93cab0 a2=90800 a3=0 items=1 ppid=1 pid=30216 auid=0 uid=0 gid=985 euid=0 suid=0 fsuid=0 egid=985 sgid=985 fsgid=985 tty=(none) ses=1 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1603116068.047:65519):  cwd="/" type=PATH msg=audit(1603116068.047:65519): item=0 name="/etc/default" inode=67165477 dev=fd:00 mode=040755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:etc_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603116068.047:65519): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1611884596.951:44274): arch=c000003e syscall=2 success=yes exit=8 a0=7fd5641bd552 a1=80000 a2=1b6 a3=24 items=1 ppid=1 pid=16168 auid=1000 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=1 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1611884596.951:44274):  cwd="/" type=PATH msg=audit(1611884596.951:44274): item=0 name="/etc/passwd" inode=35395316 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:passwd_file_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611884596.951:44274): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1605748916.740:90480): arch=c000003e syscall=2 success=yes exit=13 a0=7fce5e73e552 a1=80000 a2=1b6 a3=24 items=1 ppid=1 pid=15417 auid=0 uid=0 gid=985 euid=0 suid=0 fsuid=0 egid=985 sgid=985 fsgid=985 tty=(none) ses=115 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1605748916.740:90480):  cwd="/" type=PATH msg=audit(1605748916.740:90480): item=0 name="/etc/passwd" inode=68678693 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:passwd_file_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1605748916.740:90480): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1611886910.400:124160): arch=c000003e syscall=2 success=yes exit=3 a0=7fbd372ae5a4 a1=80000 a2=1 a3=7fbd374b44f8 items=1 ppid=73281 pid=85179 auid=0 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=pts1 ses=8 comm="hardlink" exe="/usr/sbin/hardlink" subj=unconfined_u:unconfined_r:rpm_script_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1611886910.400:124160):  cwd="/usr/src/kernels/3.10.0-1160.11.1.el7.x86_64" type=PATH msg=audit(1611886910.400:124160): item=0 name="/etc/ld.so.cache" inode=35395307 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:ld_so_cache_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611886910.400:124160): proctitle=
#
# type=SYSCALL msg=audit(1611887858.985:202445): arch=c000003e syscall=2 success=yes exit=3 a0=7f5815d1c5a4 a1=80000 a2=1 a3=7f5815f224f8 items=1 ppid=86518 pid=92574 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="sh" exe="/usr/bin/bash" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611887858.985:202445):  cwd="/" type=PATH msg=audit(1611887858.985:202445): item=0 name="/etc/ld.so.cache" inode=35395307 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:ld_so_cache_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611887858.985:202445): proctitle=7368002D63002F62696E2F7073202D702032353335203E202F6465762F6E756C6C20323E2631
#
# type=SYSCALL msg=audit(1603144170.129:112964): arch=c000003e syscall=2 success=yes exit=7 a0=7fc8ee48cf54 a1=80000 a2=1b6 a3=24 items=1 ppid=17098 pid=17142 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="urlgrabber-ext-" exe="/usr/bin/python2.7" subj=system_u:system_r:rpm_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1603144170.129:112964):  cwd="/" type=PATH msg=audit(1603144170.129:112964): item=0 name="/etc/host.conf" inode=67145913 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:etc_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603144170.129:112964): proctitle=2F7573722F62696E2F707974686F6E002F7573722F6C6962657865632F75726C677261626265722D6578742D646F776E
#
# type=SYSCALL msg=audit(1603116121.310:91125): arch=c000003e syscall=2 success=yes exit=8 a0=92eaf0 a1=0 a2=1b6 a3=24 items=1 ppid=1 pid=30216 auid=0 uid=0 gid=985 euid=0 suid=0 fsuid=0 egid=985 sgid=985 fsgid=985 tty=(none) ses=1 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1603116121.310:91125):  cwd="/" type=PATH msg=audit(1603116121.310:91125): item=0 name="/usr/sbin/lvmdiskscan" inode=34717951 dev=fd:00 mode=0100555 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:lvm_exec_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603116121.310:91125): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1605748960.982:113817): arch=c000003e syscall=2 success=yes exit=9 a0=7fce5e73e552 a1=80000 a2=1b6 a3=24 items=1 ppid=1 pid=15417 auid=0 uid=0 gid=985 euid=0 suid=0 fsuid=0 egid=985 sgid=985 fsgid=985 tty=(none) ses=115 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1605748960.982:113817):  cwd="/" type=PATH msg=audit(1605748960.982:113817): item=0 name="/etc/passwd" inode=68678693 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:passwd_file_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1605748960.982:113817): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1605748915.317:87969): arch=c000003e syscall=59 success=yes exit=0 a0=15c6010 a1=15c6150 a2=15c4690 a3=7ffcb46840e0 items=2 ppid=16359 pid=16360 auid=0 uid=0 gid=985 euid=0 suid=0 fsuid=0 egid=985 sgid=985 fsgid=985 tty=(none) ses=115 comm="ps" exe="/usr/bin/ps" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-x" type=EXECVE msg=audit(1605748915.317:87969): argc=3 a0="/bin/ps" a1="-p" a2="15436" type=CWD msg=audit(1605748915.317:87969):  cwd="/" type=PATH msg=audit(1605748915.317:87969): item=0 name="/bin/ps" inode=317956 dev=fd:00 mode=0100755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:bin_t:s0 objtype=NORMAL type=PATH msg=audit(1605748915.317:87969): item=1 name="/lib64/ld-linux-x86-64.so.2" inode=36395293 dev=fd:00 mode=0100755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:ld_so_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1605748915.317:87969): proctitle=2F62696E2F7073002D70003135343336
#
# type=SYSCALL msg=audit(1611887151.427:173833): arch=c000003e syscall=2 success=yes exit=3 a0=7fc696ca25a4 a1=80000 a2=1 a3=7fc696e8e3a8 items=1 ppid=86518 pid=87757 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="sh" exe="/usr/bin/bash" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611887151.427:173833):  cwd="/" type=PATH msg=audit(1611887151.427:173833): item=0 name="/etc/ld.so.cache" inode=35395307 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:ld_so_cache_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611887151.427:173833): proctitle=7368002D63002F62696E2F7073202D7020383431203E202F6465762F6E756C6C20323E2631
#
# type=SYSCALL msg=audit(1603159344.594:132644): arch=c000003e syscall=2 success=yes exit=13 a0=960c80 a1=0 a2=1b6 a3=24 items=1 ppid=1 pid=30216 auid=0 uid=0 gid=985 euid=0 suid=0 fsuid=0 egid=985 sgid=985 fsgid=985 tty=(none) ses=1 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1603159344.594:132644):  cwd="/" type=PATH msg=audit(1603159344.594:132644): item=0 name="/etc/pki/ca-trust/extracted/pem/email-ca-bundle.pem" inode=67294417 dev=fd:00 mode=0100444 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:cert_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603159344.594:132644): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1611897243.421:558897): arch=c000003e syscall=2 success=yes exit=3 a0=7fd803e4f5a4 a1=80000 a2=1 a3=7fd8040554f8 items=1 ppid=18323 pid=18324 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="ps" exe="/usr/bin/ps" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611897243.421:558897):  cwd="/" type=PATH msg=audit(1611897243.421:558897): item=0 name="/etc/ld.so.cache" inode=35395307 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:ld_so_cache_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611897243.421:558897): proctitle=2F62696E2F7073002D700032353833
#
# type=SYSCALL msg=audit(1611884542.702:9950): arch=c000003e syscall=2 success=yes exit=16 a0=7fd5639aeb30 a1=0 a2=0 a3=76 items=1 ppid=1 pid=16168 auid=1000 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=1 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1611884542.702:9950):  cwd="/" type=PATH msg=audit(1611884542.702:9950): item=0 name="/etc/rdma/ibacm_opts.cfg" inode=101374958 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:etc_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611884542.702:9950): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1603116118.229:90002): arch=c000003e syscall=2 success=yes exit=8 a0=7fa584948547 a1=80000 a2=1b6 a3=24 items=1 ppid=1 pid=30216 auid=0 uid=0 gid=985 euid=0 suid=0 fsuid=0 egid=985 sgid=985 fsgid=985 tty=(none) ses=1 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1603116118.229:90002):  cwd="/" type=PATH msg=audit(1603116118.229:90002): item=0 name="/etc/group" inode=68678689 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:passwd_file_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603116118.229:90002): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1603144211.946:116448): arch=c000003e syscall=89 success=yes exit=7 a0=a5ca10 a1=7fffbc004690 a2=1000 a3=0 items=1 ppid=17098 pid=17546 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="urlgrabber-ext-" exe="/usr/bin/python2.7" subj=system_u:system_r:rpm_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1603144211.946:116448):  cwd="/" type=PATH msg=audit(1603144211.946:116448): item=0 name="/usr/bin/python" inode=242088 dev=fd:00 mode=0120777 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:bin_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603144211.946:116448): proctitle=2F7573722F62696E2F707974686F6E002F7573722F6C6962657865632F75726C677261626265722D6578742D646F776E
#
# type=SYSCALL msg=audit(1603116063.657:63607): arch=c000003e syscall=2 success=yes exit=11 a0=7fa584948547 a1=80000 a2=1b6 a3=24 items=1 ppid=1 pid=30216 auid=0 uid=0 gid=985 euid=0 suid=0 fsuid=0 egid=985 sgid=985 fsgid=985 tty=(none) ses=1 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1603116063.657:63607):  cwd="/" type=PATH msg=audit(1603116063.657:63607): item=0 name="/etc/group" inode=68678689 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:passwd_file_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603116063.657:63607): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1603106067.056:58505): arch=c000003e syscall=2 success=yes exit=26 a0=7fbf8764fbf2 a1=80000 a2=1b6 a3=24 items=1 ppid=16106 pid=16406 auid=0 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=1 comm="gnome-settings-" exe="/usr/libexec/gnome-settings-daemon" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1603106067.056:58505):  cwd="/root" type=PATH msg=audit(1603106067.056:58505): item=0 name="/etc/fstab" inode=67145794 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:etc_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603106067.056:58505): proctitle="/usr/libexec/gnome-settings-daemon"
#
# type=SYSCALL msg=audit(1603072848.632:39837): arch=c000003e syscall=2 success=yes exit=8 a0=7fa584948552 a1=80000 a2=1b6 a3=24 items=1 ppid=1 pid=30216 auid=0 uid=0 gid=985 euid=0 suid=0 fsuid=0 egid=985 sgid=985 fsgid=985 tty=(none) ses=1 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1603072848.632:39837):  cwd="/" type=PATH msg=audit(1603072848.632:39837): item=0 name="/etc/passwd" inode=68678693 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:passwd_file_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603072848.632:39837): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1603072847.647:38860): arch=c000003e syscall=2 success=yes exit=8 a0=6cbc60 a1=0 a2=1b6 a3=24 items=1 ppid=1 pid=30216 auid=0 uid=0 gid=985 euid=0 suid=0 fsuid=0 egid=985 sgid=985 fsgid=985 tty=(none) ses=1 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1603072847.647:38860):  cwd="/" type=PATH msg=audit(1603072847.647:38860): item=0 name="/bin/wvdial" inode=1206085 dev=fd:00 mode=0100755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:bin_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603072847.647:38860): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1611896229.622:521339): arch=c000003e syscall=257 success=yes exit=8 a0=ffffffffffffff9c a1=7f89fd9cc630 a2=90800 a3=0 items=1 ppid=1 pid=86518 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611896229.622:521339):  cwd="/" type=PATH msg=audit(1611896229.622:521339): item=0 name="/etc/logrotate.d" inode=34153438 dev=fd:00 mode=040755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:etc_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611896229.622:521339): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1603144196.825:115149): arch=c000003e syscall=2 success=yes exit=9 a0=7f958af845a4 a1=80000 a2=1 a3=146d188 items=1 ppid=17098 pid=17404 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="urlgrabber-ext-" exe="/usr/bin/python2.7" subj=system_u:system_r:rpm_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1603144196.825:115149):  cwd="/" type=PATH msg=audit(1603144196.825:115149): item=0 name="/etc/ld.so.cache" inode=69008420 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:ld_so_cache_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603144196.825:115149): proctitle=2F7573722F62696E2F707974686F6E002F7573722F6C6962657865632F75726C677261626265722D6578742D646F776E
#
# type=SYSCALL msg=audit(1611897952.078:589197): arch=c000003e syscall=2 success=yes exit=8 a0=7f89fd9cc630 a1=0 a2=0 a3=7f89fe522900 items=1 ppid=1 pid=86518 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611897952.078:589197):  cwd="/" type=PATH msg=audit(1611897952.078:589197): item=0 name="/usr/bin/over" inode=102152591 dev=fd:00 mode=0100755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:bin_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611897952.078:589197): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1611897961.584:595701): arch=c000003e syscall=59 success=yes exit=0 a0=7f89fe56ae69 a1=7f89fd9cd070 a2=7fff2ff97ca8 a3=8 items=2 ppid=86518 pid=23606 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="sh" exe="/usr/bin/bash" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-x" type=EXECVE msg=audit(1611897961.584:595701): argc=3 a0="sh" a1="-c" a2=2F62696E2F7073202D702032353538203E202F6465762F6E756C6C20323E2631 type=CWD msg=audit(1611897961.584:595701):  cwd="/" type=PATH msg=audit(1611897961.584:595701): item=0 name="/bin/sh" inode=100674060 dev=fd:00 mode=0100755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:shell_exec_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PATH msg=audit(1611897961.584:595701): item=1 name="/lib64/ld-linux-x86-64.so.2" inode=80122 dev=fd:00 mode=0100755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:ld_so_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611897961.584:595701): proctitle=7368002D63002F62696E2F7073202D702032353538203E202F6465762F6E756C6C20323E2631
#
# type=SYSCALL msg=audit(1611897961.460:595667): arch=c000003e syscall=2 success=yes exit=3 a0=7f288e0535a4 a1=80000 a2=1 a3=7f288e2594f8 items=1 ppid=86518 pid=23596 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="sh" exe="/usr/bin/bash" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611897961.460:595667):  cwd="/" type=PATH msg=audit(1611897961.460:595667): item=0 name="/etc/ld.so.cache" inode=35395307 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:ld_so_cache_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611897961.460:595667): proctitle=7368002D63002F62696E2F7073202D702032353439203E202F6465762F6E756C6C20323E2631
#
# type=SYSCALL msg=audit(1603128981.757:105270): arch=c000003e syscall=2 success=yes exit=4 a0=7f81aebb35a4 a1=80000 a2=1 a3=7f81aedb94f8 items=1 ppid=30221 pid=14081 auid=0 uid=0 gid=985 euid=0 suid=0 fsuid=0 egid=985 sgid=985 fsgid=985 tty=(none) ses=1 comm="last" exe="/usr/bin/last" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1603128981.757:105270):  cwd="/" type=PATH msg=audit(1603128981.757:105270): item=0 name="/etc/ld.so.cache" inode=69008420 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:ld_so_cache_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603128981.757:105270): proctitle=7368002D63006C617374202D6E203230
#
# type=SYSCALL msg=audit(1611884584.165:34430): arch=c000003e syscall=2 success=yes exit=8 a0=7fd5641bd552 a1=80000 a2=1b6 a3=24 items=1 ppid=1 pid=16168 auid=1000 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=1 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1611884584.165:34430):  cwd="/" type=PATH msg=audit(1611884584.165:34430): item=0 name="/etc/passwd" inode=35395316 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:passwd_file_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611884584.165:34430): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1611888913.140:243740): arch=c000003e syscall=59 success=yes exit=0 a0=7f89fe56ae69 a1=7f89fd9cd070 a2=7fff2ff97ca8 a3=8 items=2 ppid=86518 pid=99160 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="sh" exe="/usr/bin/bash" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-x" type=EXECVE msg=audit(1611888913.140:243740): argc=3 a0="sh" a1="-c" a2=2F62696E2F7073202D702032373735203E202F6465762F6E756C6C20323E2631 type=CWD msg=audit(1611888913.140:243740):  cwd="/" type=PATH msg=audit(1611888913.140:243740): item=0 name="/bin/sh" inode=100674060 dev=fd:00 mode=0100755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:shell_exec_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PATH msg=audit(1611888913.140:243740): item=1 name="/lib64/ld-linux-x86-64.so.2" inode=80122 dev=fd:00 mode=0100755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:ld_so_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611888913.140:243740): proctitle=7368002D63002F62696E2F7073202D702032373735203E202F6465762F6E756C6C20323E2631
#
# type=SYSCALL msg=audit(1611895531.072:495515): arch=c000003e syscall=257 success=yes exit=13 a0=ffffffffffffff9c a1=7f89fd9c3f30 a2=90800 a3=0 items=1 ppid=1 pid=86518 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611895531.072:495515):  cwd="/" type=PATH msg=audit(1611895531.072:495515): item=0 name="/etc/selinux/targeted/active/modules/100/snmp" inode=3694074 dev=fd:00 mode=040700 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:semanage_store_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611895531.072:495515): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1611895869.254:501716): arch=c000003e syscall=2 success=yes exit=8 a0=7f89fd9cd660 a1=0 a2=1b6 a3=24 items=1 ppid=1 pid=86518 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611895869.254:501716):  cwd="/" type=PATH msg=audit(1611895869.254:501716): item=0 name="/usr/bin/mail" inode=101250429 dev=fd:00 mode=0100755 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:bin_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611895869.254:501716): proctitle="/var/esild/bin/ossec-syscheckd"
#
# ...
#
# type=SYSCALL msg=audit(1611889249.844:252561): arch=c000003e syscall=257 success=yes exit=13 a0=ffffffffffffff9c a1=7f89fd9c3f30 a2=90800 a3=0 items=1 ppid=1 pid=86518 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611889249.844:252561):  cwd="/" type=PATH msg=audit(1611889249.844:252561): item=0 name="/etc/selinux/targeted/active/modules/100/rkhunter" inode=69327653 dev=fd:00 mode=040700 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:semanage_store_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611889249.844:252561): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1611895523.981:489237): arch=c000003e syscall=2 success=yes exit=3 a0=7fa3e970d5a4 a1=80000 a2=1 a3=7fa3e98f93a8 items=1 ppid=86518 pid=7227 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="sh" exe="/usr/bin/bash" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611895523.981:489237):  cwd="/" type=PATH msg=audit(1611895523.981:489237): item=0 name="/etc/ld.so.cache" inode=35395307 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:ld_so_cache_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611895523.981:489237): proctitle=7368002D63002F62696E2F7073202D70203231303020323E202F6465762F6E756C6C
#
# type=SYSCALL msg=audit(1611893782.435:426256): arch=c000003e syscall=2 success=yes exit=14 a0=7f89fd9c2430 a1=0 a2=0 a3=646f6d2f65766974 items=1 ppid=1 pid=86518 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611893782.435:426256):  cwd="/" type=PATH msg=audit(1611893782.435:426256): item=0 name="/etc/selinux/targeted/active/modules/100/condor/hll" inode=69327198 dev=fd:00 mode=0100600 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:semanage_store_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611893782.435:426256): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1603159344.079:132220): arch=c000003e syscall=2 success=yes exit=3 a0=7f11f0e6f5a4 a1=80000 a2=1 a3=7f11f10754f8 items=1 ppid=30216 pid=21525 auid=0 uid=0 gid=985 euid=0 suid=0 fsuid=0 egid=985 sgid=985 fsgid=985 tty=(none) ses=1 comm="sh" exe="/usr/bin/bash" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1603159344.079:132220):  cwd="/" type=PATH msg=audit(1603159344.079:132220): item=0 name="/etc/ld.so.cache" inode=69008420 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:ld_so_cache_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603159344.079:132220): proctitle=7368002D63002F62696E2F7073202D70203134323720323E202F6465762F6E756C6C
#
# type=SYSCALL msg=audit(1611895527.663:490663): arch=c000003e syscall=2 success=yes exit=3 a0=7fd4eb9705a4 a1=80000 a2=1 a3=7fd4ebb764f8 items=1 ppid=86518 pid=7635 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="sh" exe="/usr/bin/bash" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611895527.663:490663):  cwd="/" type=PATH msg=audit(1611895527.663:490663): item=0 name="/etc/ld.so.cache" inode=35395307 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:ld_so_cache_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611895527.663:490663): proctitle=7368002D63002F62696E2F7073202D70203237343920323E202F6465762F6E756C6C
#
# type=SYSCALL msg=audit(1603144202.523:115576): arch=c000003e syscall=2 success=yes exit=7 a0=7fc2cad66f01 a1=80000 a2=1b6 a3=24 items=1 ppid=17098 pid=17448 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="urlgrabber-ext-" exe="/usr/bin/python2.7" subj=system_u:system_r:rpm_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1603144202.523:115576):  cwd="/" type=PATH msg=audit(1603144202.523:115576): item=0 name="/etc/resolv.conf" inode=68533312 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:net_conf_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603144202.523:115576): proctitle=2F7573722F62696E2F707974686F6E002F7573722F6C6962657865632F75726C677261626265722D6578742D646F776E
#
# type=SYSCALL msg=audit(1611892380.416:367115): arch=c000003e syscall=2 success=yes exit=3 a0=7f670d103552 a1=80000 a2=1b6 a3=24 items=1 ppid=86518 pid=118529 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="sh" exe="/usr/bin/bash" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611892380.416:367115):  cwd="/" type=PATH msg=audit(1611892380.416:367115): item=0 name="/etc/passwd" inode=34361151 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:passwd_file_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611892380.416:367115): proctitle=7368002D63002F62696E2F7073202D70203133323620323E202F6465762F6E756C6C
#
# type=SYSCALL msg=audit(1611896973.499:556510): arch=c000003e syscall=2 success=yes exit=3 a0=7fa233d0e5a4 a1=80000 a2=1 a3=7fa233f144f8 items=1 ppid=13270 pid=17676 auid=0 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=pts1 ses=28 comm="grep" exe="/usr/bin/grep" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1611896973.499:556510):  cwd="/home/Diamorphine" type=PATH msg=audit(1611896973.499:556510): item=0 name="/etc/ld.so.cache" inode=35395307 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:ld_so_cache_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611896973.499:556510): proctitle=67726570002D2D636F6C6F723D6175746F00727379736C6F67
#
# type=SYSCALL msg=audit(1611889947.112:278475): arch=c000003e syscall=2 success=yes exit=14 a0=7f89fd9c2430 a1=0 a2=0 a3=646f6d2f65766974 items=1 ppid=1 pid=86518 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611889947.112:278475):  cwd="/" type=PATH msg=audit(1611889947.112:278475): item=0 name="/etc/selinux/targeted/active/modules/100/apache/cil" inode=69651207 dev=fd:00 mode=0100600 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:semanage_store_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611889947.112:278475): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1611890992.810:320054): arch=c000003e syscall=2 success=yes exit=14 a0=7f89fd9c2430 a1=0 a2=0 a3=646f6d2f65766974 items=1 ppid=1 pid=86518 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611890992.810:320054):  cwd="/" type=PATH msg=audit(1611890992.810:320054): item=0 name="/etc/selinux/targeted/active/modules/100/vhostmd/cil" inode=104884799 dev=fd:00 mode=0100600 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:semanage_store_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611890992.810:320054): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1611892736.838:388671): arch=c000003e syscall=2 success=yes exit=10 a0=7f89fd9c9030 a1=0 a2=0 a3=7f89fe522900 items=1 ppid=1 pid=86518 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611892736.838:388671):  cwd="/" type=PATH msg=audit(1611892736.838:388671): item=0 name="/boot/grub2/i386-pc/mmap.mod" inode=1575496 dev=08:01 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:boot_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611892736.838:388671): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1611884594.697:38959): arch=c000003e syscall=2 success=yes exit=8 a0=7fd5641bd547 a1=80000 a2=1b6 a3=24 items=1 ppid=1 pid=16168 auid=1000 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=1 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1611884594.697:38959):  cwd="/" type=PATH msg=audit(1611884594.697:38959): item=0 name="/etc/group" inode=33588799 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:passwd_file_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611884594.697:38959): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1603149001.806:126455): arch=c000003e syscall=2 success=yes exit=3 a0=7f26649cae44 a1=0 a2=1b6 a3=24 items=1 ppid=17920 pid=19301 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="crond" exe="/usr/sbin/crond" subj=system_u:system_r:crond_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1603149001.806:126455):  cwd="/" type=PATH msg=audit(1603149001.806:126455): item=0 name="/etc/login.defs" inode=67542024 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:etc_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603149001.806:126455): proctitle=2F7573722F7362696E2F63726F6E64002D6E
#
# type=SYSCALL msg=audit(1603072815.548:20851): arch=c000003e syscall=2 success=yes exit=14 a0=7fa584948552 a1=80000 a2=1b6 a3=24 items=1 ppid=1 pid=30216 auid=0 uid=0 gid=985 euid=0 suid=0 fsuid=0 egid=985 sgid=985 fsgid=985 tty=(none) ses=1 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1603072815.548:20851):  cwd="/" type=PATH msg=audit(1603072815.548:20851): item=0 name="/etc/passwd" inode=68678693 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:passwd_file_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603072815.548:20851): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1611897954.954:594129): arch=c000003e syscall=2 success=yes exit=3 a0=7fd07092e552 a1=80000 a2=1b6 a3=24 items=1 ppid=86518 pid=23156 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="sh" exe="/usr/bin/bash" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611897954.954:594129):  cwd="/" type=PATH msg=audit(1611897954.954:594129): item=0 name="/etc/passwd" inode=34361151 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:passwd_file_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611897954.954:594129): proctitle=7368002D63002F62696E2F7073202D7020343733203E202F6465762F6E756C6C20323E2631
#
# type=SYSCALL msg=audit(1603116070.233:66212): arch=c000003e syscall=2 success=yes exit=14 a0=972c90 a1=0 a2=1b6 a3=24 items=1 ppid=1 pid=30216 auid=0 uid=0 gid=985 euid=0 suid=0 fsuid=0 egid=985 sgid=985 fsgid=985 tty=(none) ses=1 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1603116070.233:66212):  cwd="/" type=PATH msg=audit(1603116070.233:66212): item=0 name="/etc/selinux/targeted/active/modules/100/auditadm/lang_ext" inode=1195976 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:semanage_store_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603116070.233:66212): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1611886715.831:50647): arch=c000003e syscall=2 success=yes exit=3 a0=7f8774ee75a4 a1=80000 a2=1 a3=7f87750ed4f8 items=1 ppid=71652 pid=71656 auid=4294967295 uid=0 gid=0 euid=0 suid=0 fsuid=0 egid=0 sgid=0 fsgid=0 tty=(none) ses=4294967295 comm="unix_chkpwd" exe="/usr/sbin/unix_chkpwd" subj=system_u:system_r:chkpwd_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1611886715.831:50647):  cwd="/" type=PATH msg=audit(1611886715.831:50647): item=0 name="/etc/ld.so.cache" inode=35395307 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:ld_so_cache_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611886715.831:50647): proctitle=2F7573722F7362696E2F756E69785F63686B70776400726F6F740063686B657870697279
#
# type=SYSCALL msg=audit(1611893777.486:421721): arch=c000003e syscall=2 success=yes exit=3 a0=7fe348fc65a4 a1=80000 a2=1 a3=7fe3491cc4f8 items=1 ppid=127108 pid=127109 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="ps" exe="/usr/bin/ps" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611893777.486:421721):  cwd="/" type=PATH msg=audit(1611893777.486:421721): item=0 name="/etc/ld.so.cache" inode=35395307 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=unconfined_u:object_r:ld_so_cache_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611893777.486:421721): proctitle=2F62696E2F7073002D700032353335
#
# type=SYSCALL msg=audit(1603072819.906:22720): arch=c000003e syscall=2 success=yes exit=8 a0=7fa584948552 a1=80000 a2=1b6 a3=24 items=1 ppid=1 pid=30216 auid=0 uid=0 gid=985 euid=0 suid=0 fsuid=0 egid=985 sgid=985 fsgid=985 tty=(none) ses=1 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=unconfined_u:unconfined_r:unconfined_t:s0-s0:c0.c1023 key="audit-wazuh-r" type=CWD msg=audit(1603072819.906:22720):  cwd="/" type=PATH msg=audit(1603072819.906:22720): item=0 name="/etc/passwd" inode=68678693 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:passwd_file_t:s0 objtype=NORMAL type=PROCTITLE msg=audit(1603072819.906:22720): proctitle="/var/esild/bin/ossec-syscheckd"
#
# type=SYSCALL msg=audit(1611893783.146:428970): arch=c000003e syscall=2 success=yes exit=9 a0=7f89fd9cab30 a1=0 a2=0 a3=7f89fe522280 items=1 ppid=1 pid=86518 auid=4294967295 uid=0 gid=980 euid=0 suid=0 fsuid=0 egid=980 sgid=980 fsgid=980 tty=(none) ses=4294967295 comm="ossec-syscheckd" exe="/var/esild/bin/ossec-syscheckd" subj=system_u:system_r:unconfined_service_t:s0 key="audit-wazuh-r" type=CWD msg=audit(1611893783.146:428970):  cwd="/" type=PATH msg=audit(1611893783.146:428970): item=0 name="/etc/sane.d/qcam.conf" inode=68842580 dev=fd:00 mode=0100644 ouid=0 ogid=0 rdev=00:00 obj=system_u:object_r:etc_t:s0 objtype=NORMAL cap_fp=0000000000000000 cap_fi=0000000000000000 cap_fe=0 cap_fver=0 type=PROCTITLE msg=audit(1611893783.146:428970): proctitle="/var/esild/bin/ossec-syscheckd"

# %% [markdown]
# # 한글 포함

# %%
korean = train_df[train_df['full_log'].str.contains('[가-힣]')]
korean
# Out:
#         level                                           full_log first_word
# id
# 7           0  Jan 19 09:19:14 localhost logstash: [2021-01-1...        Jan
# 12          0  Dec 28 14:48:52 localhost logstash: [2020-12-2...        Dec
# 59          0  Jan 28 04:40:05 localhost logstash: [2021-01-2...        Jan
# 60          0  Jan 15 06:01:11 localhost logstash: [2021-01-1...        Jan
# 61          0  Jan  4 10:53:32 localhost logstash: [2021-01-0...        Jan
# ...       ...                                                ...        ...
# 472919      0  Jan 18 08:21:00 localhost logstash: [2021-01-1...        Jan
# 472925      0  Sep 24 01:52:01 localhost logstash: [2020-09-2...        Sep
# 472954      0  Jan 18 10:54:00 localhost logstash: [2021-01-1...        Jan
# 472956      0  Jan 20 00:20:01 localhost logstash: [2021-01-2...        Jan
# 472963      0  Nov  9 09:10:03 localhost logstash: [2020-11-0...        Nov
#
# [50027 rows x 3 columns]

# %%
korean['first_word'].value_counts()
# Out:
# Jan    36284
# Dec     4644
# Nov     3124
# Sep     2847
# Oct     2806
# Feb      322
# Name: first_word, dtype: int64

# %%
korean['level'].value_counts()
# Out:
# 0    50027
# Name: level, dtype: int64

# %%
korean['full_log'].str.extract('([가-힣].*[가-힣])').nunique()
# Out:
# 0    22
# dtype: int64

# %%
for kor in korean['full_log'].str.extract('([가-힣].*[가-힣])')[0].unique():
    print(kor, '\n')
# Out:
# 연결이 거부됨
#
# 호스트로 갈 루트가 없음
#
# 네트워크가 접근 불가능합니다
#
# 구매 오더 ( PO-5674967 ).zip\",\"sample-sha1\":\"\",\"sample-type\":\"unknown\",\"tlp\":\"GREEN\",\"path\":\"/var/esild/ctas/migration/B_악성코드
#
# 악성코드
#
# 열린 파일이 너무 많음
#
# 경로 /org/gnome/Shell의 객체에 'org.gnome.Shell' 인터페이스가 없습니다
#
# 연결이 거부됨 (Connection refused) {:url=>http://localhost:9200/, :error_message=>"Elasticsearch Unreachable: [http://localhost:9200/][Manticore::SocketException] 연결이 거부됨
#
# 파이프가 깨어짐 (Write failed) {:url=>http://localhost:9200/, :error_message=>"Elasticsearch Unreachable: [http://localhost:9200/][Manticore::SocketException] 파이프가 깨어짐
#
# 파일 “/var/lib/gdm/.local/share/icc/edid-ce8e43f2db967b9a8fd3e14110146a62.icc” 열기 실패: 허가 거부
#
# 악성코드-HASH/202005/2020-05-29.csv\",\"confidence\":\"Low\",\"host\":\"localhost.localdomain\",\"sample-name\":\"전산 및 비전산자료 보존 요청서
#
# 연결이 거부됨 (Connection refused) {:url=>http://127.0.0.1:9200/, :error_message=>"Elasticsearch Unreachable: [http://127.0.0.1:9200/][Manticore::SocketException] 연결이 거부됨
#
# 파이프가 깨어짐
#
# 잠글 수 없습니다: 프로그램이 잠금을 막았습니다
#
# 전산 및 비전산자료 보존 요청서.zip\",\"date\":\"2020-05-25 13:01:08\",\"sample-sha256\":\"\",\"sample-type\":\"unknown\",\"@timestamp\":\"2020-05-25T04:01:08.000Z\",\"path\":\"/var/esild/ctas/migration/B_악성코드
#
# 그런 파일이나 디렉터리가 없습니다
#
# 키 파일에 들어 있는 “        file:///media/cdrom/” 줄은 키-값 쌍도 아니고, 그룹도 아니고, 주석도 아닙니다
#
# 연결이 닫혔습니다
#
# 시간 제한을 넘었습니다
#
# 웹해킹 의심 탐지
#
# 악성메일 의심
#
# 파일을 여는 중 오류: 그런 파일이나 디렉터리가 없습니다

# %%
korean['full_log'].str.extract('([가-힣].*[가-힣])').value_counts()
# Out:
# 연결이 거부됨                                                                                                                                                                                                45386
# 호스트로 갈 루트가 없음                                                                                                                                                                                           4269
# 악성코드                                                                                                                                                                                                     113
# 네트워크가 접근 불가능합니다                                                                                                                                                                                          100
# 열린 파일이 너무 많음                                                                                                                                                                                              42
# 연결이 거부됨 (Connection refused) {:url=>http://localhost:9200/, :error_message=>"Elasticsearch Unreachable: [http://localhost:9200/][Manticore::SocketException] 연결이 거부됨                                      32
# 구매 오더 ( PO-5674967 ).zip\",\"sample-sha1\":\"\",\"sample-type\":\"unknown\",\"tlp\":\"GREEN\",\"path\":\"/var/esild/ctas/migration/B_악성코드                                                                 30
# 경로 /org/gnome/Shell의 객체에 'org.gnome.Shell' 인터페이스가 없습니다                                                                                                                                                    20
# 파이프가 깨어짐                                                                                                                                                                                                   9
# 파이프가 깨어짐 (Write failed) {:url=>http://localhost:9200/, :error_message=>"Elasticsearch Unreachable: [http://localhost:9200/][Manticore::SocketException] 파이프가 깨어짐                                           8
# 연결이 거부됨 (Connection refused) {:url=>http://127.0.0.1:9200/, :error_message=>"Elasticsearch Unreachable: [http://127.0.0.1:9200/][Manticore::SocketException] 연결이 거부됨                                       3
# 잠글 수 없습니다: 프로그램이 잠금을 막았습니다                                                                                                                                                                                 3
# 악성코드-HASH/202005/2020-05-29.csv\",\"confidence\":\"Low\",\"host\":\"localhost.localdomain\",\"sample-name\":\"전산 및 비전산자료 보존 요청서                                                                            2
# 시간 제한을 넘었습니다                                                                                                                                                                                               2
# 악성메일 의심                                                                                                                                                                                                    1
# 그런 파일이나 디렉터리가 없습니다                                                                                                                                                                                         1
# 웹해킹 의심 탐지                                                                                                                                                                                                  1
# 전산 및 비전산자료 보존 요청서.zip\",\"date\":\"2020-05-25 13:01:08\",\"sample-sha256\":\"\",\"sample-type\":\"unknown\",\"@timestamp\":\"2020-05-25T04:01:08.000Z\",\"path\":\"/var/esild/ctas/migration/B_악성코드        1
# 키 파일에 들어 있는 “        file:///media/cdrom/” 줄은 키-값 쌍도 아니고, 그룹도 아니고, 주석도 아닙니다                                                                                                                                1
# 파일 “/var/lib/gdm/.local/share/icc/edid-ce8e43f2db967b9a8fd3e14110146a62.icc” 열기 실패: 허가 거부                                                                                                                  1
# 파일을 여는 중 오류: 그런 파일이나 디렉터리가 없습니다                                                                                                                                                                            1
# 연결이 닫혔습니다                                                                                                                                                                                                  1
# dtype: int64
